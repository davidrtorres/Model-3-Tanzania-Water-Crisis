# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

import missingno as msno 

dashes = dashes='---'*20

# %%
"""
amount_tsh : Total static head (amount water available to waterpoint)
date_recorded : The date the row was entered
funder : Who funded the well
gps_height : Altitude of the well
installer : Organization that installed the well
longitude : GPS coordinate
latitude : GPS coordinate
wpt_name : Name of the waterpoint if there is one
num_private :Private use or not
basin : Geographic water basin
subvillage : Geographic location
region : Geographic location
region_code : Geographic location (coded)
district_code : Geographic location (coded)
lga : Geographic location
ward : Geographic location
population : Population around the well
public_meeting : True/False
recorded_by : Group entering this row of data
scheme_management : Who operates the waterpoint
scheme_name : Who operates the waterpoint
permit : If the waterpoint is permitted
construction_year : Year the waterpoint was constructed
extraction_type : The kind of extraction the waterpoint uses
extraction_type_group : The kind of extraction the waterpoint uses
extraction_type_class : The kind of extraction the waterpoint uses
management : How the waterpoint is managed
management_group : How the waterpoint is managed
payment : What the water costs
payment_type : What the water costs
water_quality : The quality of the water
quality_group : The quality of the water
quantity : The quantity of water
quantity_group : The quantity of water
source : The source of the water
source_type : The source of the water
source_class : The source of the water
waterpoint_type : The kind of waterpoint
waterpoint_type_group : The kind of waterpoint"""

#Goal build a model that predicts the functionality of water points

#pd.set_option('display.max_columns', None)  
df = pd.read_csv('data/water_table.csv')
labels = pd.read_csv('data/water_table_labels.csv')

# %%
labels
# Out:
#           id    status_group
# 0      69572      functional
# 1       8776      functional
# 2      34310      functional
# 3      67743  non functional
# 4      19728      functional
# ...      ...             ...
# 59395  60739      functional
# 59396  27263      functional
# 59397  37057      functional
# 59398  31282      functional
# 59399  26348      functional
#
# [59400 rows x 2 columns]

# %%
df['target']= labels['status_group']

# %%
df.head()
# Out:
#       id  amount_tsh date_recorded        funder  gps_height     installer  \
# 0  69572      6000.0    2011-03-14         Roman        1390         Roman
# 1   8776         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2  34310        25.0    2013-02-25  Lottery Club         686  World vision
# 3  67743         0.0    2013-01-28        Unicef         263        UNICEF
# 4  19728         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  \
# 0  34.938093  -9.856322                  none            0
# 1  34.698766  -2.147466              Zahanati            0
# 2  37.460664  -3.821329           Kwa Mahundi            0
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4  31.130847  -1.825359               Shuleni            0
#
#                      basin  subvillage   region  region_code  district_code  \
# 0               Lake Nyasa    Mnyusi B   Iringa           11              5
# 1            Lake Victoria     Nyamara     Mara           20              2
# 2                  Pangani     Majengo  Manyara           21              4
# 3  Ruvuma / Southern Coast  Mahakamani   Mtwara           90             63
# 4            Lake Victoria  Kyanyamisa   Kagera           18              1
#
#          lga        ward  population public_meeting              recorded_by  \
# 0     Ludewa    Mundindi         109           True  GeoData Consultants Ltd
# 1  Serengeti       Natta         280            NaN  GeoData Consultants Ltd
# 2  Simanjiro     Ngorika         250           True  GeoData Consultants Ltd
# 3   Nanyumbu    Nanyumbu          58           True  GeoData Consultants Ltd
# 4    Karagwe  Nyakasimbi           0           True  GeoData Consultants Ltd
#
#   scheme_management                  scheme_name permit  construction_year  \
# 0               VWC                        Roman  False               1999
# 1             Other                          NaN   True               2010
# 2               VWC  Nyumba ya mungu pipe scheme   True               2009
# 3               VWC                          NaN   True               1986
# 4               NaN                          NaN   True                  0
#
#   extraction_type extraction_type_group extraction_type_class management  \
# 0         gravity               gravity               gravity        vwc
# 1         gravity               gravity               gravity        wug
# 2         gravity               gravity               gravity        vwc
# 3     submersible           submersible           submersible        vwc
# 4         gravity               gravity               gravity      other
#
#   management_group         payment payment_type water_quality quality_group  \
# 0       user-group    pay annually     annually          soft          good
# 1       user-group       never pay    never pay          soft          good
# 2       user-group  pay per bucket   per bucket          soft          good
# 3       user-group       never pay    never pay          soft          good
# 4            other       never pay    never pay          soft          good
#
#        quantity quantity_group                source           source_type  \
# 0        enough         enough                spring                spring
# 1  insufficient   insufficient  rainwater harvesting  rainwater harvesting
# 2        enough         enough                   dam                   dam
# 3           dry            dry           machine dbh              borehole
# 4      seasonal       seasonal  rainwater harvesting  rainwater harvesting
#
#   source_class              waterpoint_type waterpoint_type_group  \
# 0  groundwater           communal standpipe    communal standpipe
# 1      surface           communal standpipe    communal standpipe
# 2      surface  communal standpipe multiple    communal standpipe
# 3  groundwater  communal standpipe multiple    communal standpipe
# 4      surface           communal standpipe    communal standpipe
#
#            target
# 0      functional
# 1      functional
# 2      functional
# 3  non functional
# 4      functional

# %%
#convert sex column to binary encoding
#dictionary t oreplace values
df['target'] = df['target'].map({'functional':0,'non functional':1,'functional needs repair':2})
df.head()
df.drop('id',axis=1, inplace=True)

# %%
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    amount_tsh date_recorded        funder  gps_height     installer  \
# 0      6000.0    2011-03-14         Roman        1390         Roman
# 1         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2        25.0    2013-02-25  Lottery Club         686  World vision
# 3         0.0    2013-01-28        Unicef         263        UNICEF
# 4         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  \
# 0  34.938093  -9.856322                  none            0
# 1  34.698766  -2.147466              Zahanati            0
# 2  37.460664  -3.821329           Kwa Mahundi            0
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4  31.130847  -1.825359               Shuleni            0
#
#                      basin  subvillage   region  region_code  district_code  \
# 0               Lake Nyasa    Mnyusi B   Iringa           11              5
# 1            Lake Victoria     Nyamara     Mara           20              2
# 2                  Pangani     Majengo  Manyara           21              4
# 3  Ruvuma / Southern Coast  Mahakamani   Mtwara           90             63
# 4            Lake Victoria  Kyanyamisa   Kagera           18              1
#
#          lga        ward  population public_meeting              recorded_by  \
# 0     Ludewa    Mundindi         109           True  GeoData Consultants Ltd
# 1  Serengeti       Natta         280            NaN  GeoData Consultants Ltd
# 2  Simanjiro     Ngorika         250           True  GeoData Consultants Ltd
# 3   Nanyumbu    Nanyumbu          58           True  GeoData Consultants Ltd
# 4    Karagwe  Nyakasimbi           0           True  GeoData Consultants Ltd
#
#   scheme_management                  scheme_name permit  construction_year  \
# 0               VWC                        Roman  False               1999
# 1             Other                          NaN   True               2010
# 2               VWC  Nyumba ya mungu pipe scheme   True               2009
# 3               VWC                          NaN   True               1986
# 4               NaN                          NaN   True                  0
#
#   extraction_type extraction_type_group extraction_type_class management  \
# 0         gravity               gravity               gravity        vwc
# 1         gravity               gravity               gravity        wug
# 2         gravity               gravity               gravity        vwc
# 3     submersible           submersible           submersible        vwc
# 4         gravity               gravity               gravity      other
#
#   management_group         payment payment_type water_quality quality_group  \
# 0       user-group    pay annually     annually          soft          good
# 1       user-group       never pay    never pay          soft          good
# 2       user-group  pay per bucket   per bucket          soft          good
# 3       user-group       never pay    never pay          soft          good
# 4            other       never pay    never pay          soft          good
#
#        quantity quantity_group                source           source_type  \
# 0        enough         enough                spring                spring
# 1  insufficient   insufficient  rainwater harvesting  rainwater harvesting
# 2        enough         enough                   dam                   dam
# 3           dry            dry           machine dbh              borehole
# 4      seasonal       seasonal  rainwater harvesting  rainwater harvesting
#
#   source_class              waterpoint_type waterpoint_type_group  target
# 0  groundwater           communal standpipe    communal standpipe       0
# 1      surface           communal standpipe    communal standpipe       0
# 2      surface  communal standpipe multiple    communal standpipe       0
# 3  groundwater  communal standpipe multiple    communal standpipe       1
# 4      surface           communal standpipe    communal standpipe       0

# %%
# cols_drop = ['wpt_name','subvillage','ward','scheme_name','date_recorded']
# df = df.drop(cols_drop,axis=1)

# %%
df.shape
# Out:
# (59400, 40)

# %%
df['region'].value_counts()
# Out:
# Iringa           5294
# Shinyanga        4982
# Mbeya            4639
# Kilimanjaro      4379
# Morogoro         4006
# Arusha           3350
# Kagera           3316
# Mwanza           3102
# Kigoma           2816
# Ruvuma           2640
# Pwani            2635
# Tanga            2547
# Dodoma           2201
# Singida          2093
# Mara             1969
# Tabora           1959
# Rukwa            1808
# Mtwara           1730
# Manyara          1583
# Lindi            1546
# Dar es Salaam     805
# Name: region, dtype: int64

# %% [markdown]
# ### Data Visualization

# %% [markdown]
# #### Target
# The column 'target' is a multiclass label.  0 stands for functioning, 1 means non-functioning and 2 means functioning but in need of repair.  54% of the wells are functioning.  38% of the wells are not functioning and 7% are functioning but in need of repair.<br>
# The column is imbalanced.

# %%
def feature_distribution(data, col = None,ticklabels=None, figsize=None):
    """
    plots a seaborn distplot for column w/customization
    Args
    df (df)
    col (int)
    hist_kws (dict)
    figsize (dict)
    
    """
    print(data[col].value_counts(dropna=False))
    print('\n')
    print(round(data[col].value_counts(normalize=True),3))
    dashes = dashes='---'*15
    print(dashes)
    
#     if hist_kws == None:
#         {'alpha':0.5,'edgecolor':'black'}

    #order = pd.crosstab(data[col].sort_values('Classic', ascending=False).index

    fig,ax = plt.subplots(figsize=figsize)
    sns.countplot(data[col], ax=ax)

    label_font = {'weight':'bold','size':15}
    ax.set_ylabel('Counts',fontdict=label_font)
    ax.set_xlabel(col,fontdict=label_font)
    ax.set_title(f'Distribution of {col.title()}',fontdict=label_font)
    ax.set_xticklabels(ticklabels)

# %%
feature_distribution(df, col='target', ticklabels=['functional / 0','non-functional / 1','functional needs repair / 2'],figsize=(8,5))
# Out:
# 0    32259
# 1    22824
# 2     4317
# Name: target, dtype: int64
#
#
# 0    0.543
# 1    0.384
# 2    0.073
# Name: target, dtype: float64
# ---------------------------------------------
# /Users/davidtorres/opt/anaconda3/envs/learn-env/lib/python3.6/site-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %% [markdown]
# #### date_recorded / construction_year
# date_recorded : The date the row was entered<br>
# construction_year : Year the waterpoint was constructed<br>

# %%
"""
NaN: 0 
'0': 0
"""
df['date_recorded'].value_counts(dropna=False)
# Out:
# 2011-03-15    572
# 2011-03-17    558
# 2013-02-03    546
# 2011-03-14    520
# 2011-03-16    513
#              ...
# 2004-04-05      1
# 2011-09-08      1
# 2011-09-09      1
# 2011-09-20      1
# 2004-01-07      1
# Name: date_recorded, Length: 356, dtype: int64

# %%
df['date_recorded'].isna().sum()
# Out:
# 0

# %%
df[df['date_recorded']=='0']
# Out:
# Empty DataFrame
# Columns: [amount_tsh, date_recorded, funder, gps_height, installer, longitude, latitude, wpt_name, num_private, basin, subvillage, region, region_code, district_code, lga, ward, population, public_meeting, recorded_by, scheme_management, scheme_name, permit, construction_year, extraction_type, extraction_type_group, extraction_type_class, management, management_group, payment, payment_type, water_quality, quality_group, quantity, quantity_group, source, source_type, source_class, waterpoint_type, waterpoint_type_group, target]
# Index: []

# %%
print(df['date_recorded'].min())
print(df['date_recorded'].max())
# Out:
# 2002-10-14
# 2013-12-03

# %%
df['construction_year'].value_counts(dropna=False)
# Out:
# 0       20709
# 2010     2645
# 2008     2613
# 2009     2533
# 2000     2091
# 2007     1587
# 2006     1471
# 2003     1286
# 2011     1256
# 2004     1123
# 2012     1084
# 2002     1075
# 1978     1037
# 1995     1014
# 2005     1011
# 1999      979
# 1998      966
# 1990      954
# 1985      945
# 1980      811
# 1996      811
# 1984      779
# 1982      744
# 1994      738
# 1972      708
# 1974      676
# 1997      644
# 1992      640
# 1993      608
# 2001      540
# 1988      521
# 1983      488
# 1975      437
# 1986      434
# 1976      414
# 1970      411
# 1991      324
# 1989      316
# 1987      302
# 1981      238
# 1977      202
# 1979      192
# 1973      184
# 2013      176
# 1971      145
# 1960      102
# 1967       88
# 1963       85
# 1968       77
# 1969       59
# 1964       40
# 1962       30
# 1961       21
# 1965       19
# 1966       17
# Name: construction_year, dtype: int64

# %%
"""
34% of feature is 0 value
2010 is 4%.

NaN: 0
"""
df['construction_year'].value_counts(normalize=True)
# Out:
# 0       0.348636
# 2010    0.044529
# 2008    0.043990
# 2009    0.042643
# 2000    0.035202
# 2007    0.026717
# 2006    0.024764
# 2003    0.021650
# 2011    0.021145
# 2004    0.018906
# 2012    0.018249
# 2002    0.018098
# 1978    0.017458
# 1995    0.017071
# 2005    0.017020
# 1999    0.016481
# 1998    0.016263
# 1990    0.016061
# 1985    0.015909
# 1980    0.013653
# 1996    0.013653
# 1984    0.013114
# 1982    0.012525
# 1994    0.012424
# 1972    0.011919
# 1974    0.011380
# 1997    0.010842
# 1992    0.010774
# 1993    0.010236
# 2001    0.009091
# 1988    0.008771
# 1983    0.008215
# 1975    0.007357
# 1986    0.007306
# 1976    0.006970
# 1970    0.006919
# 1991    0.005455
# 1989    0.005320
# 1987    0.005084
# 1981    0.004007
# 1977    0.003401
# 1979    0.003232
# 1973    0.003098
# 2013    0.002963
# 1971    0.002441
# 1960    0.001717
# 1967    0.001481
# 1963    0.001431
# 1968    0.001296
# 1969    0.000993
# 1964    0.000673
# 1962    0.000505
# 1961    0.000354
# 1965    0.000320
# 1966    0.000286
# Name: construction_year, dtype: float64

# %%
df['construction_year'].isna().sum()
# Out:
# 0

# %% [markdown]
# #### Target and Basins
# different classes of pumps in different basins<br>

# %%
df['basin'].value_counts(dropna=False)
# Out:
# Lake Victoria              10248
# Pangani                     8940
# Rufiji                      7976
# Internal                    7785
# Lake Tanganyika             6432
# Wami / Ruvu                 5987
# Lake Nyasa                  5085
# Ruvuma / Southern Coast     4493
# Lake Rukwa                  2454
# Name: basin, dtype: int64

# %%
df['basin'].isna().sum()
# Out:
# 0

# %%
df['construction_year'].value_counts()
# Out:
# 0       20709
# 2010     2645
# 2008     2613
# 2009     2533
# 2000     2091
# 2007     1587
# 2006     1471
# 2003     1286
# 2011     1256
# 2004     1123
# 2012     1084
# 2002     1075
# 1978     1037
# 1995     1014
# 2005     1011
# 1999      979
# 1998      966
# 1990      954
# 1985      945
# 1980      811
# 1996      811
# 1984      779
# 1982      744
# 1994      738
# 1972      708
# 1974      676
# 1997      644
# 1992      640
# 1993      608
# 2001      540
# 1988      521
# 1983      488
# 1975      437
# 1986      434
# 1976      414
# 1970      411
# 1991      324
# 1989      316
# 1987      302
# 1981      238
# 1977      202
# 1979      192
# 1973      184
# 2013      176
# 1971      145
# 1960      102
# 1967       88
# 1963       85
# 1968       77
# 1969       59
# 1964       40
# 1962       30
# 1961       21
# 1965       19
# 1966       17
# Name: construction_year, dtype: int64

# %%
#df_pivot = pd.concat([df, df['target']], axis=1)
#piv_df= df[['basin','target','construction_year']]
piv_df= df[['basin','target','construction_year']]
piv_table = piv_df.pivot_table(index='basin',
                           columns='target', aggfunc='count')
piv_table
# Out:
#                         construction_year
# target                                  0     1    2
# basin
# Internal                             4482  2746  557
# Lake Nyasa                           3324  1511  250
# Lake Rukwa                           1000  1184  270
# Lake Tanganyika                      3107  2583  742
# Lake Victoria                        5100  4159  989
# Pangani                              5372  3091  477
# Rufiji                               5068  2471  437
# Ruvuma / Southern Coast              1670  2497  326
# Wami / Ruvu                          3136  2582  269

# %%
"""
checking the functionality against the type of water:
"""
#df_pivot = pd.concat([df_train_features, df_train_labels], axis=1)
piv_df= df[['water_quality','target','basin']]
piv_table = piv_df.pivot_table(index='water_quality',
                           columns='target', aggfunc='count')
piv_table
# Out:
#                       basin
# target                    0        1       2
# water_quality
# coloured              246.0    190.0    54.0
# fluoride              151.0     36.0    13.0
# fluoride abandoned      6.0     11.0     NaN
# milky                 438.0    352.0    14.0
# salty                2220.0   2411.0   225.0
# salty abandoned       174.0     93.0    72.0
# soft                28760.0  18154.0  3904.0
# unknown               264.0   1577.0    35.0

# %%
"""
0: 20709

"""
df[df['construction_year']==0]
# Out:
#        amount_tsh date_recorded                  funder  gps_height  \
# 4             0.0    2011-07-13             Action In A           0
# 6             0.0    2012-10-01                    Dwsp           0
# 7             0.0    2012-10-09                   Rwssp           0
# 8             0.0    2012-11-03                Wateraid           0
# 9             0.0    2011-08-03             Isingiro Ho           0
# ...           ...           ...                     ...         ...
# 59384         0.0    2011-07-10                 Concern           0
# 59392         0.0    2011-04-15  Government Of Tanzania           0
# 59393         0.0    2012-10-27                 Private           0
# 59397         0.0    2011-04-11                     NaN           0
# 59398         0.0    2011-03-08                   Malec           0
#
#         installer  longitude  latitude           wpt_name  num_private  \
# 4         Artisan  31.130847 -1.825359            Shuleni            0
# 6            DWSP  33.362410 -3.766365         Kwa Ngomho            0
# 7             DWE  32.620617 -4.226198       Tushirikiane            0
# 8       Water Aid  32.711100 -5.146712  Kwa Ramadhan Musa            0
# 9         Artisan  30.626991 -1.257051            Kwapeto            0
# ...           ...        ...       ...                ...          ...
# 59384     CONCERN  30.667805 -2.483710           Chamkube            0
# 59392  Government  33.009440 -8.520888     Benard Charles            0
# 59393     Private  33.866852 -4.287410          Kwa Peter            0
# 59397         NaN  34.017087 -8.750434            Mashine            0
# 59398        Musa  35.861315 -6.378573             Mshoro            0
#
#                  basin       subvillage     region  region_code  \
# 4        Lake Victoria       Kyanyamisa     Kagera           18
# 6             Internal    Ishinabulandi  Shinyanga           17
# 7      Lake Tanganyika  Nyawishi Center  Shinyanga           17
# 8      Lake Tanganyika       Imalauduki     Tabora           14
# 9        Lake Victoria         Mkonomre     Kagera           18
# ...                ...              ...        ...          ...
# 59384    Lake Victoria       Songambele     Kagera           18
# 59392       Lake Rukwa        Mbuyuni A      Mbeya           12
# 59393         Internal          Masanga     Tabora           14
# 59397           Rufiji        Madungulu      Mbeya           12
# 59398           Rufiji           Mwinyi     Dodoma            1
#
#        district_code              lga          ward  population  \
# 4                  1          Karagwe    Nyakasimbi           0
# 6                  3  Shinyanga Rural        Samuye           0
# 7                  3           Kahama        Chambo           0
# 8                  6     Tabora Urban      Itetemia           0
# 9                  1          Karagwe        Kaisho           0
# ...              ...              ...           ...         ...
# 59384             30            Ngara     Nyamiyaga           0
# 59392              1           Chunya       Mbuyuni           0
# 59393              2           Igunga        Igunga           0
# 59397              7          Mbarali       Chimala           0
# 59398              4         Chamwino  Mvumi Makulu           0
#
#       public_meeting              recorded_by scheme_management scheme_name  \
# 4               True  GeoData Consultants Ltd               NaN         NaN
# 6               True  GeoData Consultants Ltd               VWC         NaN
# 7               True  GeoData Consultants Ltd               NaN         NaN
# 8               True  GeoData Consultants Ltd               VWC         NaN
# 9               True  GeoData Consultants Ltd               NaN         NaN
# ...              ...                      ...               ...         ...
# 59384           True  GeoData Consultants Ltd               VWC         NaN
# 59392           True  GeoData Consultants Ltd               VWC         NaN
# 59393          False  GeoData Consultants Ltd   Water authority         NaN
# 59397           True  GeoData Consultants Ltd               VWC         NaN
# 59398           True  GeoData Consultants Ltd               VWC         NaN
#
#       permit  construction_year extraction_type extraction_type_group  \
# 4       True                  0         gravity               gravity
# 6       True                  0          swn 80                swn 80
# 7       True                  0     nira/tanira           nira/tanira
# 8       True                  0   india mark ii         india mark ii
# 9       True                  0     nira/tanira           nira/tanira
# ...      ...                ...             ...                   ...
# 59384  False                  0         gravity               gravity
# 59392   True                  0         gravity               gravity
# 59393  False                  0         gravity               gravity
# 59397  False                  0          swn 80                swn 80
# 59398   True                  0     nira/tanira           nira/tanira
#
#       extraction_type_class        management management_group  \
# 4                   gravity             other            other
# 6                  handpump               vwc       user-group
# 7                  handpump               wug       user-group
# 8                  handpump               vwc       user-group
# 9                  handpump               vwc       user-group
# ...                     ...               ...              ...
# 59384               gravity               vwc       user-group
# 59392               gravity               vwc       user-group
# 59393               gravity  private operator       commercial
# 59397              handpump               vwc       user-group
# 59398              handpump               vwc       user-group
#
#               payment payment_type water_quality quality_group      quantity  \
# 4           never pay    never pay          soft          good      seasonal
# 6           never pay    never pay          soft          good        enough
# 7             unknown      unknown         milky         milky        enough
# 8           never pay    never pay         salty         salty      seasonal
# 9           never pay    never pay          soft          good        enough
# ...               ...          ...           ...           ...           ...
# 59384       never pay    never pay          soft          good  insufficient
# 59392       never pay    never pay          soft          good        enough
# 59393  pay per bucket   per bucket          soft          good  insufficient
# 59397     pay monthly      monthly      fluoride      fluoride        enough
# 59398       never pay    never pay          soft          good  insufficient
#
#       quantity_group                source           source_type source_class  \
# 4           seasonal  rainwater harvesting  rainwater harvesting      surface
# 6             enough           machine dbh              borehole  groundwater
# 7             enough          shallow well          shallow well  groundwater
# 8           seasonal           machine dbh              borehole  groundwater
# 9             enough          shallow well          shallow well  groundwater
# ...              ...                   ...                   ...          ...
# 59384   insufficient                spring                spring  groundwater
# 59392         enough                spring                spring  groundwater
# 59393   insufficient                   dam                   dam      surface
# 59397         enough           machine dbh              borehole  groundwater
# 59398   insufficient          shallow well          shallow well  groundwater
#
#           waterpoint_type waterpoint_type_group  target
# 4      communal standpipe    communal standpipe       0
# 6               hand pump             hand pump       1
# 7               hand pump             hand pump       1
# 8               hand pump             hand pump       1
# 9               hand pump             hand pump       0
# ...                   ...                   ...     ...
# 59384  communal standpipe    communal standpipe       1
# 59392  communal standpipe    communal standpipe       1
# 59393               other                 other       0
# 59397           hand pump             hand pump       0
# 59398           hand pump             hand pump       0
#
# [20709 rows x 40 columns]

# %%
print(df['construction_year'].min())
print(df['construction_year'].max())
# Out:
# 0
# 2013

# %%
"""
df_pivot = pd.concat([df_train_features, df_train_labels], axis=1)
piv_df= df_pivot[['basin','status_group','construction_year']]
piv_table = piv_df.pivot_table(index='basin',
                           columns='status_group', aggfunc='count')
piv_table
"""
df_pivot = pd.concat([df_train_features, df_train_labels], axis=1)
piv_df= df_pivot[['basin','status_group','construction_year']]
piv_table = piv_df.pivot_table(index='basin',
                           columns='status_group', aggfunc='count')
piv_table

# %% [markdown]
# #### Quantity
# Quantity is defined as the quantity of water.  Based on the below, wells with enough water had the most functioning wells.  However, the wells with enough water also had the highest number of non-functioning wells. <br>

# %%
def plot_top_n(df):
    fig,ax = plt.subplots()
    sns.countplot(data=df, x='quantity', hue='target');
    
plot_top_n(df)

# %% [markdown]
# ### Water_Quality
# water_quality is defined as the quality of the water.

# %%
df['water_quality'].value_counts(dropna=False)
# Out:
# soft                  50818
# salty                  4856
# unknown                1876
# milky                   804
# coloured                490
# salty abandoned         339
# fluoride                200
# fluoride abandoned       17
# Name: water_quality, dtype: int64

# %%
def plot_top_n(df, x_lab, hue_lab, title='Regions with Permit Status'):
#plt.figure(figsize=(12,12))
    fig,ax = plt.subplots(figsize=(12,12))
    sns.countplot(x=x_lab, hue=hue_lab, data=df, palette="muted",ax=ax)

    #set the xtick labels to rotate
    #fixed rotation of axis labels
    ax.set_xticklabels(ax.get_xticklabels(), fontdict={'rotation':40,'ha':'right'});

    #set the title/ax labels
    #created dictionary that had properties for axis labels
    axlabels = dict(fontsize=14, fontweight='semibold')
    
    ax.set_ylabel('Count', fontdict=axlabels)
    ax.set_xlabel('Powers',fontdict=axlabels)
    
    ax.set_title(title, fontdict=dict(fontsize=15,weight='bold',color='red'))

    fig = ax.get_figure()
    
    return fig, ax

# %%
fig,ax = plot_top_n(df,x_lab='region', hue_lab='permit',title='See')

# %%
#fig,ax = plot_top_n(df)

# %%
df.groupby('water_quality').get_group('soft')[df.columns].sum()
# Out:
# amount_tsh                                                      1.7732e+07
# date_recorded            2011-03-142013-03-062013-02-252013-01-282011-0...
# gps_height                                                        36011883
# longitude                                                      1.73331e+06
# latitude                                                           -292396
# wpt_name                 noneZahanatiKwa MahundiZahanati Ya NanyumbuShu...
# num_private                                                          25222
# basin                    Lake NyasaLake VictoriaPanganiRuvuma / Souther...
# region                   IringaMaraManyaraMtwaraKageraShinyangaKageraRu...
# region_code                                                         745149
# district_code                                                       275081
# lga                      LudewaSerengetiSimanjiroNanyumbuKaragweShinyan...
# ward                     MundindiNattaNgorikaNanyumbuNyakasimbiSamuyeKa...
# population                                                         8877453
# public_meeting                                                       44231
# recorded_by              GeoData Consultants LtdGeoData Consultants Ltd...
# permit                                                               34132
# construction_year                                                 66898742
# extraction_type          gravitygravitygravitysubmersiblegravityswn 80n...
# extraction_type_group    gravitygravitygravitysubmersiblegravityswn 80n...
# extraction_type_class    gravitygravitygravitysubmersiblegravityhandpum...
# management               vwcwugvwcvwcothervwcvwcwugwugwater boardwugvwc...
# management_group         user-groupuser-groupuser-groupuser-groupotheru...
# payment                  pay annuallynever paypay per bucketnever payne...
# payment_type             annuallynever payper bucketnever paynever payn...
# water_quality            softsoftsoftsoftsoftsoftsoftsoftsoftsoftsoftso...
# quality_group            goodgoodgoodgoodgoodgoodgoodgoodgoodgoodgoodgo...
# quantity                 enoughinsufficientenoughdryseasonalenoughenoug...
# quantity_group           enoughinsufficientenoughdryseasonalenoughenoug...
# source                   springrainwater harvestingdammachine dbhrainwa...
# source_type              springrainwater harvestingdamboreholerainwater...
# source_class             groundwatersurfacesurfacegroundwatersurfacegro...
# waterpoint_type          communal standpipecommunal standpipecommunal s...
# waterpoint_type_group    communal standpipecommunal standpipecommunal s...
# target                                                               25962
# dtype: object

# %%
df.groupby(['funder','installer']).count()
# Out:
#                                          amount_tsh  date_recorded  \
# funder              installer
# 0                   0                           777            777
# A/co Germany        TPP TRUSTMOSHI               15             15
# Aar                 AAR                           4              4
#                     COCANE                       27             27
#                     FOLAC                         1              1
# ...                                             ...            ...
# Zao                 Zao                           1              1
# Zao Water Spring    Zao water spring              3              3
# Zao Water Spring X  Zao water spring X            1              1
# Zinduka             ZINDUKA                       1              1
# Zingibali Secondary Zingibali Secondary           1              1
#
#                                          gps_height  longitude  latitude  \
# funder              installer
# 0                   0                           777        777       777
# A/co Germany        TPP TRUSTMOSHI               15         15        15
# Aar                 AAR                           4          4         4
#                     COCANE                       27         27        27
#                     FOLAC                         1          1         1
# ...                                             ...        ...       ...
# Zao                 Zao                           1          1         1
# Zao Water Spring    Zao water spring              3          3         3
# Zao Water Spring X  Zao water spring X            1          1         1
# Zinduka             ZINDUKA                       1          1         1
# Zingibali Secondary Zingibali Secondary           1          1         1
#
#                                          wpt_name  num_private  basin  \
# funder              installer
# 0                   0                         777          777    777
# A/co Germany        TPP TRUSTMOSHI             15           15     15
# Aar                 AAR                         4            4      4
#                     COCANE                     27           27     27
#                     FOLAC                       1            1      1
# ...                                           ...          ...    ...
# Zao                 Zao                         1            1      1
# Zao Water Spring    Zao water spring            3            3      3
# Zao Water Spring X  Zao water spring X          1            1      1
# Zinduka             ZINDUKA                     1            1      1
# Zingibali Secondary Zingibali Secondary         1            1      1
#
#                                          subvillage  region  region_code  \
# funder              installer
# 0                   0                           777     777          777
# A/co Germany        TPP TRUSTMOSHI               15      15           15
# Aar                 AAR                           4       4            4
#                     COCANE                       27      27           27
#                     FOLAC                         1       1            1
# ...                                             ...     ...          ...
# Zao                 Zao                           1       1            1
# Zao Water Spring    Zao water spring              3       3            3
# Zao Water Spring X  Zao water spring X            1       1            1
# Zinduka             ZINDUKA                       1       1            1
# Zingibali Secondary Zingibali Secondary           1       1            1
#
#                                          district_code  lga  ward  population  \
# funder              installer
# 0                   0                              777  777   777         777
# A/co Germany        TPP TRUSTMOSHI                  15   15    15          15
# Aar                 AAR                              4    4     4           4
#                     COCANE                          27   27    27          27
#                     FOLAC                            1    1     1           1
# ...                                                ...  ...   ...         ...
# Zao                 Zao                              1    1     1           1
# Zao Water Spring    Zao water spring                 3    3     3           3
# Zao Water Spring X  Zao water spring X               1    1     1           1
# Zinduka             ZINDUKA                          1    1     1           1
# Zingibali Secondary Zingibali Secondary              1    1     1           1
#
#                                          public_meeting  recorded_by  \
# funder              installer
# 0                   0                               344          777
# A/co Germany        TPP TRUSTMOSHI                   15           15
# Aar                 AAR                               4            4
#                     COCANE                           27           27
#                     FOLAC                             1            1
# ...                                                 ...          ...
# Zao                 Zao                               1            1
# Zao Water Spring    Zao water spring                  3            3
# Zao Water Spring X  Zao water spring X                0            1
# Zinduka             ZINDUKA                           1            1
# Zingibali Secondary Zingibali Secondary               1            1
#
#                                          scheme_management  scheme_name  \
# funder              installer
# 0                   0                                  771          112
# A/co Germany        TPP TRUSTMOSHI                      15           15
# Aar                 AAR                                  4            0
#                     COCANE                              27            0
#                     FOLAC                                1            0
# ...                                                    ...          ...
# Zao                 Zao                                  0            0
# Zao Water Spring    Zao water spring                     0            0
# Zao Water Spring X  Zao water spring X                   0            0
# Zinduka             ZINDUKA                              1            0
# Zingibali Secondary Zingibali Secondary                  1            1
#
#                                          permit  construction_year  \
# funder              installer
# 0                   0                       777                777
# A/co Germany        TPP TRUSTMOSHI           15                 15
# Aar                 AAR                       4                  4
#                     COCANE                   27                 27
#                     FOLAC                     1                  1
# ...                                         ...                ...
# Zao                 Zao                       1                  1
# Zao Water Spring    Zao water spring          3                  3
# Zao Water Spring X  Zao water spring X        1                  1
# Zinduka             ZINDUKA                   1                  1
# Zingibali Secondary Zingibali Secondary       1                  1
#
#                                          extraction_type  \
# funder              installer
# 0                   0                                777
# A/co Germany        TPP TRUSTMOSHI                    15
# Aar                 AAR                                4
#                     COCANE                            27
#                     FOLAC                              1
# ...                                                  ...
# Zao                 Zao                                1
# Zao Water Spring    Zao water spring                   3
# Zao Water Spring X  Zao water spring X                 1
# Zinduka             ZINDUKA                            1
# Zingibali Secondary Zingibali Secondary                1
#
#                                          extraction_type_group  \
# funder              installer
# 0                   0                                      777
# A/co Germany        TPP TRUSTMOSHI                          15
# Aar                 AAR                                      4
#                     COCANE                                  27
#                     FOLAC                                    1
# ...                                                        ...
# Zao                 Zao                                      1
# Zao Water Spring    Zao water spring                         3
# Zao Water Spring X  Zao water spring X                       1
# Zinduka             ZINDUKA                                  1
# Zingibali Secondary Zingibali Secondary                      1
#
#                                          extraction_type_class  management  \
# funder              installer
# 0                   0                                      777         777
# A/co Germany        TPP TRUSTMOSHI                          15          15
# Aar                 AAR                                      4           4
#                     COCANE                                  27          27
#                     FOLAC                                    1           1
# ...                                                        ...         ...
# Zao                 Zao                                      1           1
# Zao Water Spring    Zao water spring                         3           3
# Zao Water Spring X  Zao water spring X                       1           1
# Zinduka             ZINDUKA                                  1           1
# Zingibali Secondary Zingibali Secondary                      1           1
#
#                                          management_group  payment  \
# funder              installer
# 0                   0                                 777      777
# A/co Germany        TPP TRUSTMOSHI                     15       15
# Aar                 AAR                                 4        4
#                     COCANE                             27       27
#                     FOLAC                               1        1
# ...                                                   ...      ...
# Zao                 Zao                                 1        1
# Zao Water Spring    Zao water spring                    3        3
# Zao Water Spring X  Zao water spring X                  1        1
# Zinduka             ZINDUKA                             1        1
# Zingibali Secondary Zingibali Secondary                 1        1
#
#                                          payment_type  water_quality  \
# funder              installer
# 0                   0                             777            777
# A/co Germany        TPP TRUSTMOSHI                 15             15
# Aar                 AAR                             4              4
#                     COCANE                         27             27
#                     FOLAC                           1              1
# ...                                               ...            ...
# Zao                 Zao                             1              1
# Zao Water Spring    Zao water spring                3              3
# Zao Water Spring X  Zao water spring X              1              1
# Zinduka             ZINDUKA                         1              1
# Zingibali Secondary Zingibali Secondary             1              1
#
#                                          quality_group  quantity  \
# funder              installer
# 0                   0                              777       777
# A/co Germany        TPP TRUSTMOSHI                  15        15
# Aar                 AAR                              4         4
#                     COCANE                          27        27
#                     FOLAC                            1         1
# ...                                                ...       ...
# Zao                 Zao                              1         1
# Zao Water Spring    Zao water spring                 3         3
# Zao Water Spring X  Zao water spring X               1         1
# Zinduka             ZINDUKA                          1         1
# Zingibali Secondary Zingibali Secondary              1         1
#
#                                          quantity_group  source  source_type  \
# funder              installer
# 0                   0                               777     777          777
# A/co Germany        TPP TRUSTMOSHI                   15      15           15
# Aar                 AAR                               4       4            4
#                     COCANE                           27      27           27
#                     FOLAC                             1       1            1
# ...                                                 ...     ...          ...
# Zao                 Zao                               1       1            1
# Zao Water Spring    Zao water spring                  3       3            3
# Zao Water Spring X  Zao water spring X                1       1            1
# Zinduka             ZINDUKA                           1       1            1
# Zingibali Secondary Zingibali Secondary               1       1            1
#
#                                          source_class  waterpoint_type  \
# funder              installer
# 0                   0                             777              777
# A/co Germany        TPP TRUSTMOSHI                 15               15
# Aar                 AAR                             4                4
#                     COCANE                         27               27
#                     FOLAC                           1                1
# ...                                               ...              ...
# Zao                 Zao                             1                1
# Zao Water Spring    Zao water spring                3                3
# Zao Water Spring X  Zao water spring X              1                1
# Zinduka             ZINDUKA                         1                1
# Zingibali Secondary Zingibali Secondary             1                1
#
#                                          waterpoint_type_group  target
# funder              installer
# 0                   0                                      777     777
# A/co Germany        TPP TRUSTMOSHI                          15      15
# Aar                 AAR                                      4       4
#                     COCANE                                  27      27
#                     FOLAC                                    1       1
# ...                                                        ...     ...
# Zao                 Zao                                      1       1
# Zao Water Spring    Zao water spring                         3       3
# Zao Water Spring X  Zao water spring X                       1       1
# Zinduka             ZINDUKA                                  1       1
# Zingibali Secondary Zingibali Secondary                      1       1
#
# [3697 rows x 38 columns]

# %%
#fig,ax = plot_top_n(df,x_lab='installer', hue_lab='target',title='See')

# %%
df_3 = pd.DataFrame({'A': ['foo', 'bar', 'foo', 'bar',
                             'foo', 'bar', 'foo', 'foo'],
                       'B': ['one', 'one', 'two', 'three',
                             'two', 'two', 'one', 'three'],
                       'C': np.random.randn(8),
                       'D': np.random.randn(8)})

# %%
df_3
# Out:
#      A      B         C         D
# 0  foo    one -0.331052  0.109757
# 1  bar    one  0.013786 -0.450453
# 2  foo    two  0.425553 -0.446061
# 3  bar  three  1.171010  0.237241
# 4  foo    two -0.947486 -0.683027
# 5  bar    two -0.557447 -0.444505
# 6  foo    one  1.286862 -0.715719
# 7  foo  three -0.144935  0.022869

# %%
df_3.groupby(['A','B']).count()
# Out:
#            C  D
# A   B
# bar one    1  1
#     three  1  1
#     two    1  1
# foo one    2  2
#     three  1  1
#     two    2  2

# %%
arrays = [['Falcon', 'Falcon', 'Parrot', 'Parrot'],
          ['Captive', 'Wild', 'Captive', 'Wild']]
#index = pd.MultiIndex.from_arrays(arrays, names=('Animal', 'Type'))
birds = pd.DataFrame({'Birds': ['Falcon', 'Falcon', 'Parrot', 'Parrot'],
          'status':['Captive', 'Wild', 'Captive', 'Wild'],'Max Speed': [390., 350., 30., 20.]})

# %%
birds
# Out:
#     Birds   status  Max Speed
# 0  Falcon  Captive      390.0
# 1  Falcon     Wild      350.0
# 2  Parrot  Captive       30.0
# 3  Parrot     Wild       20.0

# %%
birds.groupby('Birds').count()
# Out:
#         status  Max Speed
# Birds
# Falcon       2          2
# Parrot       2          2

# %%
df.head()
# Out:
#    amount_tsh date_recorded        funder  gps_height     installer  \
# 0      6000.0    2011-03-14         Roman        1390         Roman
# 1         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2        25.0    2013-02-25  Lottery Club         686  World vision
# 3         0.0    2013-01-28        Unicef         263        UNICEF
# 4         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  \
# 0  34.938093  -9.856322                  none            0
# 1  34.698766  -2.147466              Zahanati            0
# 2  37.460664  -3.821329           Kwa Mahundi            0
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4  31.130847  -1.825359               Shuleni            0
#
#                      basin  subvillage   region  region_code  district_code  \
# 0               Lake Nyasa    Mnyusi B   Iringa           11              5
# 1            Lake Victoria     Nyamara     Mara           20              2
# 2                  Pangani     Majengo  Manyara           21              4
# 3  Ruvuma / Southern Coast  Mahakamani   Mtwara           90             63
# 4            Lake Victoria  Kyanyamisa   Kagera           18              1
#
#          lga        ward  population public_meeting              recorded_by  \
# 0     Ludewa    Mundindi         109           True  GeoData Consultants Ltd
# 1  Serengeti       Natta         280            NaN  GeoData Consultants Ltd
# 2  Simanjiro     Ngorika         250           True  GeoData Consultants Ltd
# 3   Nanyumbu    Nanyumbu          58           True  GeoData Consultants Ltd
# 4    Karagwe  Nyakasimbi           0           True  GeoData Consultants Ltd
#
#   scheme_management                  scheme_name permit  construction_year  \
# 0               VWC                        Roman  False               1999
# 1             Other                          NaN   True               2010
# 2               VWC  Nyumba ya mungu pipe scheme   True               2009
# 3               VWC                          NaN   True               1986
# 4               NaN                          NaN   True                  0
#
#   extraction_type extraction_type_group extraction_type_class management  \
# 0         gravity               gravity               gravity        vwc
# 1         gravity               gravity               gravity        wug
# 2         gravity               gravity               gravity        vwc
# 3     submersible           submersible           submersible        vwc
# 4         gravity               gravity               gravity      other
#
#   management_group         payment payment_type water_quality quality_group  \
# 0       user-group    pay annually     annually          soft          good
# 1       user-group       never pay    never pay          soft          good
# 2       user-group  pay per bucket   per bucket          soft          good
# 3       user-group       never pay    never pay          soft          good
# 4            other       never pay    never pay          soft          good
#
#        quantity quantity_group                source           source_type  \
# 0        enough         enough                spring                spring
# 1  insufficient   insufficient  rainwater harvesting  rainwater harvesting
# 2        enough         enough                   dam                   dam
# 3           dry            dry           machine dbh              borehole
# 4      seasonal       seasonal  rainwater harvesting  rainwater harvesting
#
#   source_class              waterpoint_type waterpoint_type_group  target
# 0  groundwater           communal standpipe    communal standpipe       0
# 1      surface           communal standpipe    communal standpipe       0
# 2      surface  communal standpipe multiple    communal standpipe       0
# 3  groundwater  communal standpipe multiple    communal standpipe       1
# 4      surface           communal standpipe    communal standpipe       0

# %%
select_cols = df[['amount_tsh','gps_height','population','target']]
#sns.pairplot(select_cols);
select_cols.head()
# Out:
#    amount_tsh  gps_height  population  target
# 0      6000.0        1390         109       0
# 1         0.0        1399         280       0
# 2        25.0         686         250       0
# 3         0.0         263          58       1
# 4         0.0           0           0       0

# %% [markdown]
# #### Construction Year / Year Recorded

# %%
df_2 = df.copy()

# %%
df_2.isna().sum()
# Out:
# amount_tsh                   0
# date_recorded                0
# funder                    3635
# gps_height                   0
# installer                 3655
# longitude                    0
# latitude                     0
# wpt_name                     0
# num_private                  0
# basin                        0
# subvillage                 371
# region                       0
# region_code                  0
# district_code                0
# lga                          0
# ward                         0
# population                   0
# public_meeting            3334
# recorded_by                  0
# scheme_management         3877
# scheme_name              28166
# permit                    3056
# construction_year            0
# extraction_type              0
# extraction_type_group        0
# extraction_type_class        0
# management                   0
# management_group             0
# payment                      0
# payment_type                 0
# water_quality                0
# quality_group                0
# quantity                     0
# quantity_group               0
# source                       0
# source_type                  0
# source_class                 0
# waterpoint_type              0
# waterpoint_type_group        0
# target                       0
# dtype: int64

# %%
#Nan: 0
print(df_2['construction_year'].isna().sum())
print(df_2['construction_year'].dtype)
print(df_2['date_recorded'].dtype)
# Out:
# 0
# int64
# object

# %%
#0: 20709
df_2['construction_year'].value_counts(dropna=False)
# Out:
# 0       20709
# 2010     2645
# 2008     2613
# 2009     2533
# 2000     2091
# 2007     1587
# 2006     1471
# 2003     1286
# 2011     1256
# 2004     1123
# 2012     1084
# 2002     1075
# 1978     1037
# 1995     1014
# 2005     1011
# 1999      979
# 1998      966
# 1990      954
# 1985      945
# 1980      811
# 1996      811
# 1984      779
# 1982      744
# 1994      738
# 1972      708
# 1974      676
# 1997      644
# 1992      640
# 1993      608
# 2001      540
# 1988      521
# 1983      488
# 1975      437
# 1986      434
# 1976      414
# 1970      411
# 1991      324
# 1989      316
# 1987      302
# 1981      238
# 1977      202
# 1979      192
# 1973      184
# 2013      176
# 1971      145
# 1960      102
# 1967       88
# 1963       85
# 1968       77
# 1969       59
# 1964       40
# 1962       30
# 1961       21
# 1965       19
# 1966       17
# Name: construction_year, dtype: int64

# %%
df_2.replace(0, np.nan, inplace=True)

# %%
df_2['construction_year'].isna().sum()
# Out:
# 20709

# %%
#Nan: 20709
df_2['construction_year'].value_counts(dropna=False)
# Out:
# NaN       20709
# 2010.0     2645
# 2008.0     2613
# 2009.0     2533
# 2000.0     2091
# 2007.0     1587
# 2006.0     1471
# 2003.0     1286
# 2011.0     1256
# 2004.0     1123
# 2012.0     1084
# 2002.0     1075
# 1978.0     1037
# 1995.0     1014
# 2005.0     1011
# 1999.0      979
# 1998.0      966
# 1990.0      954
# 1985.0      945
# 1980.0      811
# 1996.0      811
# 1984.0      779
# 1982.0      744
# 1994.0      738
# 1972.0      708
# 1974.0      676
# 1997.0      644
# 1992.0      640
# 1993.0      608
# 2001.0      540
# 1988.0      521
# 1983.0      488
# 1975.0      437
# 1986.0      434
# 1976.0      414
# 1970.0      411
# 1991.0      324
# 1989.0      316
# 1987.0      302
# 1981.0      238
# 1977.0      202
# 1979.0      192
# 1973.0      184
# 2013.0      176
# 1971.0      145
# 1960.0      102
# 1967.0       88
# 1963.0       85
# 1968.0       77
# 1969.0       59
# 1964.0       40
# 1962.0       30
# 1961.0       21
# 1965.0       19
# 1966.0       17
# Name: construction_year, dtype: int64

# %%
df_2['date_recorded'].value_counts(dropna=False)
# Out:
# 2011-03-15    572
# 2011-03-17    558
# 2013-02-03    546
# 2011-03-14    520
# 2011-03-16    513
#              ...
# 2011-09-21      1
# 2011-09-17      1
# 2011-09-26      1
# 2004-06-01      1
# 2011-09-11      1
# Name: date_recorded, Length: 356, dtype: int64

# %%
df_2.loc[df_2['date_recorded']=='0']
# Out:
# Empty DataFrame
# Columns: [amount_tsh, date_recorded, funder, gps_height, installer, longitude, latitude, wpt_name, num_private, basin, subvillage, region, region_code, district_code, lga, ward, population, public_meeting, recorded_by, scheme_management, scheme_name, permit, construction_year, extraction_type, extraction_type_group, extraction_type_class, management, management_group, payment, payment_type, water_quality, quality_group, quantity, quantity_group, source, source_type, source_class, waterpoint_type, waterpoint_type_group, target]
# Index: []

# %%
df_2['date_recorded'].isna().sum()
# Out:
# 0

# %%
# def impute_missing_values(table):
#     my_list=[]
#     for column in table:
#         table.loc[:,column] = np.where(table[column] == 0, table[column] == 'OK', table[column])
#         my_list.append(column)
#     return my_list

# %%
#impute_missing_values(df_1)

# %%
# funder    55765 non-null  object 
df_1['funder'].value_counts(dropna=False)
# Out:
# Government Of Tanzania    9084
# NaN                       3635
# Danida                    3114
# Hesawa                    2202
# Rwssp                     1374
#                           ...
# Mh.J S Sumari                1
# Charlotte Well               1
# Agt Church                   1
# Jwtz                         1
# Bfwd                         1
# Name: funder, Length: 1898, dtype: int64

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   amount_tsh             17761 non-null  float64
#  1   date_recorded          59400 non-null  object
#  2   funder                 55765 non-null  object
#  3   gps_height             38962 non-null  float64
#  4   installer              55745 non-null  object
#  5   longitude              57588 non-null  float64
#  6   latitude               59400 non-null  float64
#  7   wpt_name               59400 non-null  object
#  8   num_private            757 non-null    float64
#  9   basin                  59400 non-null  object
#  10  subvillage             59029 non-null  object
#  11  region                 59400 non-null  object
#  12  region_code            59400 non-null  int64
#  13  district_code          59377 non-null  float64
#  14  lga                    59400 non-null  object
#  15  ward                   59400 non-null  object
#  16  population             38019 non-null  float64
#  17  public_meeting         51011 non-null  object
#  18  recorded_by            59400 non-null  object
#  19  scheme_management      55523 non-null  object
#  20  scheme_name            31234 non-null  object
#  21  permit                 38852 non-null  object
#  22  construction_year      38691 non-null  float64
#  23  extraction_type        59400 non-null  object
#  24  extraction_type_group  59400 non-null  object
#  25  extraction_type_class  59400 non-null  object
#  26  management             59400 non-null  object
#  27  management_group       59400 non-null  object
#  28  payment                59400 non-null  object
#  29  payment_type           59400 non-null  object
#  30  water_quality          59400 non-null  object
#  31  quality_group          59400 non-null  object
#  32  quantity               59400 non-null  object
#  33  quantity_group         59400 non-null  object
#  34  source                 59400 non-null  object
#  35  source_type            59400 non-null  object
#  36  source_class           59400 non-null  object
#  37  waterpoint_type        59400 non-null  object
#  38  waterpoint_type_group  59400 non-null  object
#  39  target                 27141 non-null  float64
# dtypes: float64(9), int64(1), object(30)
# memory usage: 18.1+ MB

# %%
df['funder'].value_counts(dropna=False)
# Out:
# Government Of Tanzania    9084
# NaN                       3635
# Danida                    3114
# Hesawa                    2202
# Rwssp                     1374
#                           ...
# Mh.J S Sumari                1
# Charlotte Well               1
# Agt Church                   1
# Jwtz                         1
# Bfwd                         1
# Name: funder, Length: 1898, dtype: int64

# %%
data_d = pd.read_csv('data/water_table.csv')

# %%
len(data_d.loc[data_d['funder']=='0'])
# Out:
# 777

# %%
data_d[data_d['funder']=='0'].sum()
# Out:
# id                                                                28979559
# amount_tsh                                                          189499
# date_recorded            2013-03-212013-03-162013-03-182013-03-222013-0...
# funder                   0000000000000000000000000000000000000000000000...
# gps_height                                                           23052
# installer                0000000000000000000000000000000000000000000000...
# longitude                                                          30474.1
# latitude                                                          -5366.77
# wpt_name                 ChekanaoMsikitiniKwa ChambusoCcm KivuleOfisi Y...
# num_private                                                              0
# basin                    Wami / RuvuWami / RuvuWami / RuvuWami / RuvuWa...
# subvillage               Mtaa Wa Kitunda KatiMadrasaMtaa Wa Mji MpyaMta...
# region                   Dar es SalaamDar es SalaamDar es SalaamDar es ...
# region_code                                                           5439
# district_code                                                         1676
# lga                      IlalaTemekeIlalaIlalaIlalaTemekeIlalaTemekeIla...
# ward                     KitundaKimbijiKitundaMsongolaMsongolaPemba Mna...
# population                                                          187376
# public_meeting                                                         338
# recorded_by              GeoData Consultants LtdGeoData Consultants Ltd...
# permit                                                                   0
# construction_year                                                  1526750
# extraction_type          submersiblemonoothersubmersibleothermonosubmer...
# extraction_type_group    submersiblemonoothersubmersibleothermonosubmer...
# extraction_type_class    submersiblemotorpumpothersubmersibleothermotor...
# management               private operatorvwcunknownwugothervwcprivate o...
# management_group         commercialuser-groupunknownuser-groupotheruser...
# payment                  pay per bucketnever payunknownpay per bucketne...
# payment_type             per bucketnever payunknownper bucketnever payn...
# water_quality            softsaltyunknownsoftunknownsaltysalty abandone...
# quality_group            goodsaltyunknowngoodunknownsaltysaltysaltygood...
# quantity                 enoughdryunknownenoughdrydryenoughdryenoughunk...
# quantity_group           enoughdryunknownenoughdrydryenoughdryenoughunk...
# source                   machine dbhmachine dbhmachine dbhmachine dbhsh...
# source_type              boreholeboreholeboreholeboreholeshallow wellbo...
# source_class             groundwatergroundwatergroundwatergroundwatergr...
# waterpoint_type          communal standpipeotherothercommunal standpipe...
# waterpoint_type_group    communal standpipeotherothercommunal standpipe...
# dtype: object

# %%
for col in data_d:
    my_list = []
    if col == '0':
        my_list.append(data_d[col].columns)
    print(my_list)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []

# %%
data_d.loc[data_d.isin(["0"]).any(axis=1)]
# Out:
#           id  amount_tsh date_recorded funder  gps_height installer  \
# 145    28669        50.0    2013-03-21      0          12         0
# 152    60983         0.0    2013-03-16      0         -15         0
# 393    39749         0.0    2013-03-18      0          28         0
# 417    15832        50.0    2013-03-22      0          30         0
# 428    50233         0.0    2013-03-12      0          30         0
# ...      ...         ...           ...    ...         ...       ...
# 59237   2138        59.0    2013-03-19      0          81         0
# 59243   3396        50.0    2013-03-16      0         -20         0
# 59276  62818        50.0    2013-03-21      0          18         0
# 59351  55322        50.0    2013-03-18      0         -19         0
# 59387  26640       100.0    2013-03-12      0          25         0
#
#        longitude  latitude       wpt_name  num_private        basin  \
# 145    39.185710 -6.892593       Chekanao            0  Wami / Ruvu
# 152    39.527114 -6.988748      Msikitini            0  Wami / Ruvu
# 393    39.159887 -6.902548   Kwa Chambuso            0  Wami / Ruvu
# 417    39.178404 -6.938013     Ccm Kivule            0  Wami / Ruvu
# 428    39.178849 -6.973206  Ofisi Ya Kata            0  Wami / Ruvu
# ...          ...       ...            ...          ...          ...
# 59237  39.119109 -6.898919           Kata            0  Wami / Ruvu
# 59243  39.524021 -6.984802   Kwa Mariwala            0  Wami / Ruvu
# 59276  39.183790 -6.897566   Kwa Mkunduge            0  Wami / Ruvu
# 59351  39.534599 -7.088183      Kwa China            0  Wami / Ruvu
# 59387  39.176480 -6.957098     Kwa Maliba            0  Wami / Ruvu
#
#                  subvillage         region  region_code  district_code  \
# 145    Mtaa Wa Kitunda Kati  Dar es Salaam            7              2
# 152                 Madrasa  Dar es Salaam            7              3
# 393        Mtaa Wa Mji Mpya  Dar es Salaam            7              2
# 417          Mtaa Wa Kivule  Dar es Salaam            7              2
# 428         Mtaa Yangeyange  Dar es Salaam            7              2
# ...                     ...            ...          ...            ...
# 59237       Mtaa Wa Bombani  Dar es Salaam            7              2
# 59243          Miembe Dekwa  Dar es Salaam            7              3
# 59276  Mtaa Wa Kitunda Kati  Dar es Salaam            7              2
# 59351               Bondeni  Dar es Salaam            7              3
# 59387    Mtaa Wa Yangeyange  Dar es Salaam            7              2
#
#           lga         ward  population public_meeting  \
# 145     Ilala      Kitunda         150            NaN
# 152    Temeke      Kimbiji          50           True
# 393     Ilala      Kitunda           1            NaN
# 417     Ilala     Msongola         100            NaN
# 428     Ilala     Msongola        1000           True
# ...       ...          ...         ...            ...
# 59237   Ilala         Pugu         150            NaN
# 59243  Temeke      Kimbiji         210           True
# 59276   Ilala      Kitunda         250            NaN
# 59351  Temeke  Pemba Mnazi          50           True
# 59387   Ilala     Msongola         100            NaN
#
#                    recorded_by scheme_management scheme_name permit  \
# 145    GeoData Consultants Ltd  Private operator         NaN  False
# 152    GeoData Consultants Ltd               VWC         NaN  False
# 393    GeoData Consultants Ltd               NaN         NaN  False
# 417    GeoData Consultants Ltd               WUG           N  False
# 428    GeoData Consultants Ltd             Other         NaN  False
# ...                        ...               ...         ...    ...
# 59237  GeoData Consultants Ltd               WUG         NaN  False
# 59243  GeoData Consultants Ltd               VWC         NaN  False
# 59276  GeoData Consultants Ltd               WUG           J  False
# 59351  GeoData Consultants Ltd               VWC         NaN  False
# 59387  GeoData Consultants Ltd               WUA           M  False
#
#        construction_year extraction_type extraction_type_group  \
# 145                    0     submersible           submersible
# 152                 1970            mono                  mono
# 393                 2010           other                 other
# 417                 2000     submersible           submersible
# 428                 2000           other                 other
# ...                  ...             ...                   ...
# 59237               2000     submersible           submersible
# 59243               2010     nira/tanira           nira/tanira
# 59276               2000     submersible           submersible
# 59351               2000     submersible           submersible
# 59387               2000     submersible           submersible
#
#       extraction_type_class        management management_group  \
# 145             submersible  private operator       commercial
# 152               motorpump               vwc       user-group
# 393                   other           unknown          unknown
# 417             submersible               wug       user-group
# 428                   other             other            other
# ...                     ...               ...              ...
# 59237           submersible               wug       user-group
# 59243              handpump               vwc       user-group
# 59276           submersible               wug       user-group
# 59351           submersible               vwc       user-group
# 59387           submersible               wua       user-group
#
#               payment payment_type    water_quality quality_group  \
# 145    pay per bucket   per bucket             soft          good
# 152         never pay    never pay            salty         salty
# 393           unknown      unknown          unknown       unknown
# 417    pay per bucket   per bucket             soft          good
# 428         never pay    never pay          unknown       unknown
# ...               ...          ...              ...           ...
# 59237  pay per bucket   per bucket  salty abandoned         salty
# 59243  pay per bucket   per bucket             soft          good
# 59276  pay per bucket   per bucket             soft          good
# 59351  pay per bucket   per bucket             soft          good
# 59387  pay per bucket   per bucket             soft          good
#
#            quantity quantity_group        source   source_type source_class  \
# 145          enough         enough   machine dbh      borehole  groundwater
# 152             dry            dry   machine dbh      borehole  groundwater
# 393         unknown        unknown   machine dbh      borehole  groundwater
# 417          enough         enough   machine dbh      borehole  groundwater
# 428             dry            dry  shallow well  shallow well  groundwater
# ...             ...            ...           ...           ...          ...
# 59237  insufficient   insufficient   machine dbh      borehole  groundwater
# 59243        enough         enough  shallow well  shallow well  groundwater
# 59276        enough         enough   machine dbh      borehole  groundwater
# 59351        enough         enough   machine dbh      borehole  groundwater
# 59387        enough         enough   machine dbh      borehole  groundwater
#
#           waterpoint_type waterpoint_type_group
# 145    communal standpipe    communal standpipe
# 152                 other                 other
# 393                 other                 other
# 417    communal standpipe    communal standpipe
# 428                 other                 other
# ...                   ...                   ...
# 59237  communal standpipe    communal standpipe
# 59243           hand pump             hand pump
# 59276  communal standpipe    communal standpipe
# 59351  communal standpipe    communal standpipe
# 59387  communal standpipe    communal standpipe
#
# [777 rows x 40 columns]

# %%
data_d['population'].value_counts()
# Out:
# 0       21381
# 1        7025
# 200      1940
# 150      1892
# 250      1681
#         ...
# 3241        1
# 1960        1
# 1685        1
# 2248        1
# 1439        1
# Name: population, Length: 1049, dtype: int64

# %%
"""
# Prep- convert the zeros in 'funder','installer', and 'population' to NaNs. 
merged_clean = merged.replace({'funder':0, 'installer':0, 'population':0}, np.nan)
merged_clean = merged.replace({'funder':'0', 'installer':'0'}, np.nan)

"""
# Out:
# "\n# Prep- convert the zeros in 'funder','installer', and 'population' to NaNs. \nmerged_clean = merged.replace({'funder':0, 'installer':0, 'population':0}, np.nan)\nmerged_clean = merged.replace({'funder':'0', 'installer':'0'}, np.nan)\n\n"

# %%
"""
# Lump low frequency levels in funder, installer, scheme_name into 'other'
exempt=['amount_tsh',  'gps_height',  'num_private',
       'basin', 'region', 'region_code', 'district_code', 'lga', 'population',
       'public_meeting', 'scheme_management',  'permit',
       'construction_year', 'extraction_type', 'extraction_type_group',
       'extraction_type_class', 'management', 'management_group', 'payment',
       'payment_type', 'water_quality', 'quality_group', 'quantity',
       'quantity_group', 'source', 'source_type', 'source_class',
       'waterpoint_type', 'waterpoint_type_group']

merged_clean = merged_clean.apply(lambda x: x.mask(x.map(x.value_counts())<20, 'other') if x.name not in exempt else x)

"""
# Out:
# "\n# Lump low frequency levels in funder, installer, scheme_name into 'other'\nexempt=['amount_tsh',  'gps_height',  'num_private',\n       'basin', 'region', 'region_code', 'district_code', 'lga', 'population',\n       'public_meeting', 'scheme_management',  'permit',\n       'construction_year', 'extraction_type', 'extraction_type_group',\n       'extraction_type_class', 'management', 'management_group', 'payment',\n       'payment_type', 'water_quality', 'quality_group', 'quantity',\n       'quantity_group', 'source', 'source_type', 'source_class',\n       'waterpoint_type', 'waterpoint_type_group']\n\nmerged_clean = merged_clean.apply(lambda x: x.mask(x.map(x.value_counts())<20, 'other') if x.name not in exempt else x)\n\n"

# %%
"""
merged_clean = merged.replace({'construction_year':0}, np.nan)
merged_clean = merged.replace({'construction_year':'0'}, np.nan)
"""
# Out:
# "\nmerged_clean = merged.replace({'construction_year':0}, np.nan)\nmerged_clean = merged.replace({'construction_year':'0'}, np.nan)\n"

# %%
"""
pd.concat([merged_clean.funder, merged_clean.installer], axis=1)

"""
# Out:
# '\npd.concat([merged_clean.funder, merged_clean.installer], axis=1)\n\n'
