# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import seaborn as sns

import missingno as msno 

dashes = dashes='---'*20

import warnings
warnings.filterwarnings("ignore")

# %%
"""
Your goal is to predict the operating condition of a waterpoint for each record in the dataset. 
You are provided the following set of information about the waterpoints:

Build a classifier to predict the condition of a water well, using information about the sort of pump, when it was installed, etc. 
Note that this is a ternary classification problem.



amount_tsh : Total static head (amount water available to waterpoint)
date_recorded : The date the row was entered
funder : Who funded the well
gps_height : Altitude of the well
installer : Organization that installed the well
longitude : GPS coordinate
latitude : GPS coordinate
wpt_name : Name of the waterpoint if there is one
num_private :Private use or not
basin : Geographic water basin
subvillage : Geographic location
region : Geographic location
region_code : Geographic location (coded)
district_code : Geographic location (coded)
lga : Geographic location
ward : Geographic location
population : Population around the well
public_meeting : True/False
recorded_by : Group entering this row of data
scheme_management : Who operates the waterpoint
scheme_name : Who operates the waterpoint
permit : If the waterpoint is permitted
construction_year : Year the waterpoint was constructed
extraction_type : The kind of extraction the waterpoint uses
extraction_type_group : The kind of extraction the waterpoint uses
extraction_type_class : The kind of extraction the waterpoint uses
management : How the waterpoint is managed
management_group : How the waterpoint is managed
payment : What the water costs
payment_type : What the water costs
water_quality : The quality of the water
quality_group : The quality of the water
quantity : The quantity of water
quantity_group : The quantity of water
source : The source of the water
source_type : The source of the water
source_class : The source of the water
waterpoint_type : The kind of waterpoint
waterpoint_type_group : The kind of waterpoint"""



pd.set_option('display.max_columns', None)  
df_1 = pd.read_csv('data/water_table.csv')
labels = pd.read_csv('data/water_table_labels.csv')
df_1['target'] = labels['status_group']

# %%
df_1['target'] = df_1['target'].map({'functional':0,'non functional':1,'functional needs repair':2})
df_1.drop('id',axis=1, inplace=True)

# %%
df_1.head()
# Out:
#    amount_tsh date_recorded        funder  gps_height     installer  \
# 0      6000.0    2011-03-14         Roman        1390         Roman
# 1         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2        25.0    2013-02-25  Lottery Club         686  World vision
# 3         0.0    2013-01-28        Unicef         263        UNICEF
# 4         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  \
# 0  34.938093  -9.856322                  none            0
# 1  34.698766  -2.147466              Zahanati            0
# 2  37.460664  -3.821329           Kwa Mahundi            0
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4  31.130847  -1.825359               Shuleni            0
#
#                      basin  subvillage   region  region_code  district_code  \
# 0               Lake Nyasa    Mnyusi B   Iringa           11              5
# 1            Lake Victoria     Nyamara     Mara           20              2
# 2                  Pangani     Majengo  Manyara           21              4
# 3  Ruvuma / Southern Coast  Mahakamani   Mtwara           90             63
# 4            Lake Victoria  Kyanyamisa   Kagera           18              1
#
#          lga        ward  population public_meeting              recorded_by  \
# 0     Ludewa    Mundindi         109           True  GeoData Consultants Ltd
# 1  Serengeti       Natta         280            NaN  GeoData Consultants Ltd
# 2  Simanjiro     Ngorika         250           True  GeoData Consultants Ltd
# 3   Nanyumbu    Nanyumbu          58           True  GeoData Consultants Ltd
# 4    Karagwe  Nyakasimbi           0           True  GeoData Consultants Ltd
#
#   scheme_management                  scheme_name permit  construction_year  \
# 0               VWC                        Roman  False               1999
# 1             Other                          NaN   True               2010
# 2               VWC  Nyumba ya mungu pipe scheme   True               2009
# 3               VWC                          NaN   True               1986
# 4               NaN                          NaN   True                  0
#
#   extraction_type extraction_type_group extraction_type_class management  \
# 0         gravity               gravity               gravity        vwc
# 1         gravity               gravity               gravity        wug
# 2         gravity               gravity               gravity        vwc
# 3     submersible           submersible           submersible        vwc
# 4         gravity               gravity               gravity      other
#
#   management_group         payment payment_type water_quality quality_group  \
# 0       user-group    pay annually     annually          soft          good
# 1       user-group       never pay    never pay          soft          good
# 2       user-group  pay per bucket   per bucket          soft          good
# 3       user-group       never pay    never pay          soft          good
# 4            other       never pay    never pay          soft          good
#
#        quantity quantity_group                source           source_type  \
# 0        enough         enough                spring                spring
# 1  insufficient   insufficient  rainwater harvesting  rainwater harvesting
# 2        enough         enough                   dam                   dam
# 3           dry            dry           machine dbh              borehole
# 4      seasonal       seasonal  rainwater harvesting  rainwater harvesting
#
#   source_class              waterpoint_type waterpoint_type_group  target
# 0  groundwater           communal standpipe    communal standpipe       0
# 1      surface           communal standpipe    communal standpipe       0
# 2      surface  communal standpipe multiple    communal standpipe       0
# 3  groundwater  communal standpipe multiple    communal standpipe       1
# 4      surface           communal standpipe    communal standpipe       0

# %% [markdown]
# ### Exploratory Data Analysis

# %%
df_1.shape
# Out:
# (59400, 40)

# %%
df_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   amount_tsh             59400 non-null  float64
#  1   date_recorded          59400 non-null  object
#  2   funder                 55765 non-null  object
#  3   gps_height             59400 non-null  int64
#  4   installer              55745 non-null  object
#  5   longitude              59400 non-null  float64
#  6   latitude               59400 non-null  float64
#  7   wpt_name               59400 non-null  object
#  8   num_private            59400 non-null  int64
#  9   basin                  59400 non-null  object
#  10  subvillage             59029 non-null  object
#  11  region                 59400 non-null  object
#  12  region_code            59400 non-null  int64
#  13  district_code          59400 non-null  int64
#  14  lga                    59400 non-null  object
#  15  ward                   59400 non-null  object
#  16  population             59400 non-null  int64
#  17  public_meeting         56066 non-null  object
#  18  recorded_by            59400 non-null  object
#  19  scheme_management      55523 non-null  object
#  20  scheme_name            31234 non-null  object
#  21  permit                 56344 non-null  object
#  22  construction_year      59400 non-null  int64
#  23  extraction_type        59400 non-null  object
#  24  extraction_type_group  59400 non-null  object
#  25  extraction_type_class  59400 non-null  object
#  26  management             59400 non-null  object
#  27  management_group       59400 non-null  object
#  28  payment                59400 non-null  object
#  29  payment_type           59400 non-null  object
#  30  water_quality          59400 non-null  object
#  31  quality_group          59400 non-null  object
#  32  quantity               59400 non-null  object
#  33  quantity_group         59400 non-null  object
#  34  source                 59400 non-null  object
#  35  source_type            59400 non-null  object
#  36  source_class           59400 non-null  object
#  37  waterpoint_type        59400 non-null  object
#  38  waterpoint_type_group  59400 non-null  object
#  39  target                 59400 non-null  int64
# dtypes: float64(3), int64(7), object(30)
# memory usage: 18.1+ MB

# %%
#df_1.nunique()
def unique_values(df):
    info_df = df.info()
    print(dashes)
    print('\n')
    num_unique = df.nunique()
    print("Number of uniques values in each Feature/Column:")
    
    return num_unique

unique_values(df_1)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 59400 entries, 0 to 59399
# Data columns (total 40 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   amount_tsh             59400 non-null  float64
#  1   date_recorded          59400 non-null  object
#  2   funder                 55765 non-null  object
#  3   gps_height             59400 non-null  int64
#  4   installer              55745 non-null  object
#  5   longitude              59400 non-null  float64
#  6   latitude               59400 non-null  float64
#  7   wpt_name               59400 non-null  object
#  8   num_private            59400 non-null  int64
#  9   basin                  59400 non-null  object
#  10  subvillage             59029 non-null  object
#  11  region                 59400 non-null  object
#  12  region_code            59400 non-null  int64
#  13  district_code          59400 non-null  int64
#  14  lga                    59400 non-null  object
#  15  ward                   59400 non-null  object
#  16  population             59400 non-null  int64
#  17  public_meeting         56066 non-null  object
#  18  recorded_by            59400 non-null  object
#  19  scheme_management      55523 non-null  object
#  20  scheme_name            31234 non-null  object
#  21  permit                 56344 non-null  object
#  22  construction_year      59400 non-null  int64
#  23  extraction_type        59400 non-null  object
#  24  extraction_type_group  59400 non-null  object
#  25  extraction_type_class  59400 non-null  object
#  26  management             59400 non-null  object
#  27  management_group       59400 non-null  object
#  28  payment                59400 non-null  object
#  29  payment_type           59400 non-null  object
#  30  water_quality          59400 non-null  object
#  31  quality_group          59400 non-null  object
#  32  quantity               59400 non-null  object
#  33  quantity_group         59400 non-null  object
#  34  source                 59400 non-null  object
#  35  source_type            59400 non-null  object
#  36  source_class           59400 non-null  object
#  37  waterpoint_type        59400 non-null  object
#  38  waterpoint_type_group  59400 non-null  object
#  39  target                 59400 non-null  int64
# dtypes: float64(3), int64(7), object(30)
# memory usage: 18.1+ MB
# ------------------------------------------------------------
#
#
# Number of uniques values in each Feature/Column:
# amount_tsh                  98
# date_recorded              356
# funder                    1897
# gps_height                2428
# installer                 2145
# longitude                57516
# latitude                 57517
# wpt_name                 37400
# num_private                 65
# basin                        9
# subvillage               19287
# region                      21
# region_code                 27
# district_code               20
# lga                        125
# ward                      2092
# population                1049
# public_meeting               2
# recorded_by                  1
# scheme_management           12
# scheme_name               2696
# permit                       2
# construction_year           55
# extraction_type             18
# extraction_type_group       13
# extraction_type_class        7
# management                  12
# management_group             5
# payment                      7
# payment_type                 7
# water_quality                8
# quality_group                6
# quantity                     5
# quantity_group               5
# source                      10
# source_type                  7
# source_class                 3
# waterpoint_type              7
# waterpoint_type_group        6
# target                       3
# dtype: int64

# %% [markdown]
# #### Null Values

# %%
def nan_more_fifty(df): 
    for column in df:
        if df[column].isnull().sum()*100.0/df.shape[0] > 50:
            df.drop(column,1, inplace=True)
        #else:
    print('There are no columns with more than 50% null values')
    return df

# %%
revised = nan_more_fifty(df_1)
# Out:
# There are no columns with more than 50% null values

# %%
def count_null(df):
    #only features w/null values
    null_columns=df.columns[df.isnull().any()]
    test = df[null_columns].isnull().sum()
    if test.empty:
        print('No nulls')
    else:
        print(f'The following features have null values:\n {null_columns}')
    
    # Visualize missing values as a matrix 
    msno.matrix(df) 
    
    return test
    
nan_values = count_null(df_1)
# Out:
# The following features have null values:
#  Index(['funder', 'installer', 'subvillage', 'public_meeting',
#        'scheme_management', 'scheme_name', 'permit'],
#       dtype='object')

# %% [markdown]
# #### Columns with '0' values

# %%
columns_0 = df_1.columns[df_1.isin(['0']).any()] 
print(f"The following columns have a string with value of '0': {columns_0}")
# Out:
# The following columns have a string with value of '0': Index(['funder', 'installer'], dtype='object')

# %%
df_1.describe()
# Out:
#           amount_tsh    gps_height     longitude      latitude   num_private  \
# count   59400.000000  59400.000000  59400.000000  5.940000e+04  59400.000000
# mean      317.650385    668.297239     34.077427 -5.706033e+00      0.474141
# std      2997.574558    693.116350      6.567432  2.946019e+00     12.236230
# min         0.000000    -90.000000      0.000000 -1.164944e+01      0.000000
# 25%         0.000000      0.000000     33.090347 -8.540621e+00      0.000000
# 50%         0.000000    369.000000     34.908743 -5.021597e+00      0.000000
# 75%        20.000000   1319.250000     37.178387 -3.326156e+00      0.000000
# max    350000.000000   2770.000000     40.345193 -2.000000e-08   1776.000000
#
#         region_code  district_code    population  construction_year  \
# count  59400.000000   59400.000000  59400.000000       59400.000000
# mean      15.297003       5.629747    179.909983        1300.652475
# std       17.587406       9.633649    471.482176         951.620547
# min        1.000000       0.000000      0.000000           0.000000
# 25%        5.000000       2.000000      0.000000           0.000000
# 50%       12.000000       3.000000     25.000000        1986.000000
# 75%       17.000000       5.000000    215.000000        2004.000000
# max       99.000000      80.000000  30500.000000        2013.000000
#
#              target
# count  59400.000000
# mean       0.529596
# std        0.628080
# min        0.000000
# 25%        0.000000
# 50%        0.000000
# 75%        1.000000
# max        2.000000

# %% [markdown]
# ### Visualization

# %%
def feature_distribution(data, col= None, ticklabels=None, figsize=None):
    """
    plots a seaborn countplot for column w/customization
    Args
    df (df)
    col (int or str)
    figsize (dict)
    """
    print(data[col].value_counts(dropna=False))
    print('\n')
    print(round(data[col].value_counts(normalize=True),3))
    dashes = dashes='---'*15
    print(dashes)
    
    fig,ax = plt.subplots(figsize=figsize)
    sns.countplot(data=data, x=col, ax=ax)
    label_font = {'weight':'bold','size':15}
    ax.set_ylabel('Counts',fontdict=label_font)
    ax.set_xlabel(col,fontdict=label_font)
    ax.set_title(f'Distribution of {col.title()}',fontdict=label_font)
    ax.set_xticklabels(ticklabels)

# %%
def feature_w_hue(df, col= None, hue_col=None, rot=None, figsize=None):
    """
    plots a seaborn countplot for column and hue w/customization
    Args
    df (dataframe)
    col (int or str)
    hue_col (int or str)
    rot(rotate x label)
    figsize (dict)
    """
    print(df[col].value_counts(dropna=False))
    print('\n')
    print(round(df[col].value_counts(normalize=True),3))
    dashes = dashes='---'*15
    print(dashes)
    
    fig,ax = plt.subplots(figsize=figsize)
    #sns.countplot(data=data, x=col, ax=ax)
    sns.countplot(data=df, x=col, hue=hue_col, ax=ax)
    label_font = {'weight':'bold','size':15}
    ax.set_ylabel('Counts',fontdict=label_font)
    ax.set_xlabel(col,fontdict=label_font)
    #ax.set_title(f'Distribution of {col.title()}',fontdict=label_font)
    ax.set_title(f'How {col.title()} relates to {hue_col.title()}',fontdict=label_font)
    ax.set_xticklabels(ax.get_xticklabels(), fontdict={'rotation':rot,'ha':'right'}); 
    #ax.set_xticklabels(ticklabels)

# %% [markdown]
# #### target
# The label has 3 categories.  0 stands for wells that are functioning. 1 represents wells that don't work and 2 is for wells that work but need repair.<br>
# <br>
# The feature consists of 54% of wells that function.  38% are wells that don't function and 7% of the wells work but need to be repaired.  The 'target' is imbalanced because there such a big difference in the distrubtion between the categories.

# %%
feature_distribution(df_1, col='target',ticklabels=['functional / 0','non-functional / 1','functional needs repair / 2'],figsize=(8,5))
# Out:
# 0    32259
# 1    22824
# 2     4317
# Name: target, dtype: int64
#
#
# 0    0.543
# 1    0.384
# 2    0.073
# Name: target, dtype: float64
# ---------------------------------------------

# %% [markdown]
# #### amount_tsh
# Feature is defined as the total static head or the amount of water available to waterpoint.  Column 'population' is defined as the population around the well.  I created a new column 'water_per_person' to show how much water is available for population around the well.
# <br>
# Problem with 'amount_tsh' is that 70% of feature doesn't have a reported amount of water.  Also, for 'population' 35% of feature doesn't has a reported value 0f 0 and 12% has a reported value of 1.

# %%
df_1['amount_tsh'].value_counts(normalize=True)
# Out:
# 0.0         0.700993
# 500.0       0.052222
# 50.0        0.041616
# 1000.0      0.025051
# 20.0        0.024630
#               ...
# 8500.0      0.000017
# 6300.0      0.000017
# 220.0       0.000017
# 138000.0    0.000017
# 12.0        0.000017
# Name: amount_tsh, Length: 98, dtype: float64

# %%
df_1['population'].value_counts(normalize=True)
# Out:
# 0       0.359949
# 1       0.118266
# 200     0.032660
# 150     0.031852
# 250     0.028300
#           ...
# 3241    0.000017
# 1960    0.000017
# 1685    0.000017
# 2248    0.000017
# 1439    0.000017
# Name: population, Length: 1049, dtype: float64

# %%
df_1['water_per_person'] = df_1['amount_tsh'] / df_1['population']

# %%
df_1.head(50)
# Out:
#     amount_tsh date_recorded                    funder  gps_height  \
# 0       6000.0    2011-03-14                     Roman        1390
# 1          0.0    2013-03-06                   Grumeti        1399
# 2         25.0    2013-02-25              Lottery Club         686
# 3          0.0    2013-01-28                    Unicef         263
# 4          0.0    2011-07-13               Action In A           0
# 5         20.0    2011-03-13       Mkinga Distric Coun           0
# 6          0.0    2012-10-01                      Dwsp           0
# 7          0.0    2012-10-09                     Rwssp           0
# 8          0.0    2012-11-03                  Wateraid           0
# 9          0.0    2011-08-03               Isingiro Ho           0
# 10         0.0    2011-02-20                   Private          62
# 11       200.0    2013-02-18                    Danida        1062
# 12         0.0    2012-10-14              World Vision           0
# 13         0.0    2013-03-15   Lawatefuka Water Supply        1368
# 14         0.0    2012-10-20                     Biore           0
# 15         0.0    2011-08-04                     Rudep        1645
# 16       500.0    2011-07-04                    Unicef        1703
# 17         0.0    2011-09-04                    Unicef        1656
# 18         0.0    2011-07-22                    Hesawa        1162
# 19       500.0    2011-02-22                    Danida        1763
# 20       200.0    2011-02-27                       Twe        2216
# 21         0.0    2013-02-10                      Dwsp           0
# 22         0.0    2011-10-04                    Unicef        1510
# 23       500.0    2013-11-03                       Isf         672
# 24         0.0    2013-01-21  African Development Bank        1645
# 25         0.0    2013-02-25    Government Of Tanzania        1273
# 26       500.0    2013-01-16                    Sobodo         200
# 27         0.0    2011-07-11                    Hesawa           0
# 28         0.0    2013-03-05    Government Of Tanzania        1443
# 29         0.0    2013-03-16   Lawatefuka Water Supply        1256
# 30         0.0    2011-03-23                     Water           0
# 31        50.0    2011-03-16        Private Individual         180
# 32         0.0    2013-03-19    Government Of Tanzania        1481
# 33         0.0    2011-03-11                      Undp        1638
# 34         0.0    2011-02-23                       NaN         -41
# 35         0.0    2013-03-28                 Not Known        1546
# 36         0.0    2011-07-16                    Danida           0
# 37         0.0    2011-03-27                     Kirde           0
# 38      4000.0    2011-02-20                      Cefa        1955
# 39         0.0    2013-02-11    Government Of Tanzania        1348
# 40        25.0    2013-10-03                 Ces(gmbh)         710
# 41       500.0    2011-03-12    Government Of Tanzania        2469
# 42       500.0    2011-07-07            European Union        1803
# 43         0.0    2013-01-15                       NaN        1642
# 44        20.0    2013-03-18    Government Of Tanzania        1007
# 45         0.0    2012-10-22              World Vision           0
# 46        20.0    2013-02-05                       Lga         240
# 47         0.0    2011-07-27                       NaN           0
# 48      4000.0    2011-02-20                      Cefa        1982
# 49      1500.0    2011-04-04          District Council        2169
#
#                installer  longitude      latitude                wpt_name  \
# 0                  Roman  34.938093 -9.856322e+00                    none
# 1                GRUMETI  34.698766 -2.147466e+00                Zahanati
# 2           World vision  37.460664 -3.821329e+00             Kwa Mahundi
# 3                 UNICEF  38.486161 -1.115530e+01    Zahanati Ya Nanyumbu
# 4                Artisan  31.130847 -1.825359e+00                 Shuleni
# 5                    DWE  39.172796 -4.765587e+00                  Tajiri
# 6                   DWSP  33.362410 -3.766365e+00              Kwa Ngomho
# 7                    DWE  32.620617 -4.226198e+00            Tushirikiane
# 8              Water Aid  32.711100 -5.146712e+00       Kwa Ramadhan Musa
# 9                Artisan  30.626991 -1.257051e+00                 Kwapeto
# 10               Private  39.209518 -7.034139e+00           Mzee Hokororo
# 11                DANIDA  35.770258 -1.057417e+01        Kwa Alid Nchimbi
# 12          World vision  33.798106 -3.290194e+00                   Pamba
# 13  Lawatefuka water sup  37.092574 -3.181783e+00    Kwa John Izack Mmari
# 14                WEDECO  34.364073 -3.629333e+00               Mwabasabi
# 15                   DWE  31.444121 -8.274962e+00  Kwa Juvenal Ching'Ombe
# 16                   DWE  34.642439 -9.106185e+00         Kwa John Mtenzi
# 17                   DWE  34.569266 -9.085515e+00         Kwa Rose Chaula
# 18                   DWE  32.920154 -1.947868e+00                  Ngomee
# 19                 Danid  34.508967 -9.894412e+00                    none
# 20                   TWE  34.473430 -9.594990e+00                    none
# 21                   DWE   0.000000 -2.000000e-08                Muungano
# 22                   DWE  34.586901 -8.980014e+00                 Shuleni
# 23                   ISF  37.940029 -4.125595e+00                 Kinonga
# 24                   DWE  29.747066 -4.495568e+00                 Kamsasa
# 25                   DWE  37.422751 -3.317536e+00               Kwa Tukai
# 26           Kilolo Star  39.370777 -9.942532e+00   Ruhoma Primary School
# 27                   DWE  31.104257 -1.735361e+00              Kwawilliam
# 28      District council  37.611126 -3.263526e+00            Kwa Kibakaya
# 29  Lawatefuka water sup  37.061688 -3.191989e+00       Kwa Willium Kinda
# 30                 Water  36.108312 -5.791000e+00                   Ngosi
# 31                    WU  38.363555 -6.636104e+00        Kituo Cha Maziwa
# 32                   DWE  37.492334 -3.290627e+00        Kwa Philip Lyimo
# 33                   DWE  34.478356 -9.715910e+00                    none
# 34                   NaN  39.812912 -7.889986e+00     Msikitini Wa Ijumaa
# 35             Not known  36.618699 -3.293003e+00               Sekondari
# 36    Central government  33.854345 -9.638520e+00        Office Ya Kijiji
# 37                   DWE  35.858373 -4.647906e+00                   Tangi
# 38                  CEFA  35.890264 -8.224399e+00                    none
# 39                   DWE  30.613305 -3.894561e+00                 Mkuyuni
# 40                   DWE  37.420027 -3.476849e+00              Kwa Lusina
# 41                 Commu  33.927902 -9.204649e+00                    none
# 42                 Accra  34.814574 -9.032503e+00       Zahanati-Misssion
# 43                   NaN  34.967789 -4.628921e+00            Mvae Primary
# 44                   DWE  36.806079 -3.478559e+00              Kwa Bariki
# 45          World Vision  33.345260 -3.838998e+00                 Shimasa
# 46                   LGA  39.087415 -1.100060e+01             Mikoroshini
# 47                   NaN  33.540607 -9.172905e+00              Mahakamani
# 48                  CEFA  35.871413 -8.227563e+00                    none
# 49                   DWE  34.441283 -9.189878e+00       Kwa Bryson Msigwa
#
#     num_private                    basin       subvillage       region  \
# 0             0               Lake Nyasa         Mnyusi B       Iringa
# 1             0            Lake Victoria          Nyamara         Mara
# 2             0                  Pangani          Majengo      Manyara
# 3             0  Ruvuma / Southern Coast       Mahakamani       Mtwara
# 4             0            Lake Victoria       Kyanyamisa       Kagera
# 5             0                  Pangani      Moa/Mwereme        Tanga
# 6             0                 Internal    Ishinabulandi    Shinyanga
# 7             0          Lake Tanganyika  Nyawishi Center    Shinyanga
# 8             0          Lake Tanganyika       Imalauduki       Tabora
# 9             0            Lake Victoria         Mkonomre       Kagera
# 10            0              Wami / Ruvu           Mizugo        Pwani
# 11            0               Lake Nyasa     Ngondombwito       Ruvuma
# 12            0                 Internal          Nkilifa    Shinyanga
# 13            0                  Pangani          Omarini  Kilimanjaro
# 14            0                 Internal        Mwabasabi    Shinyanga
# 15            0          Lake Tanganyika            Tunzi        Rukwa
# 16            0                   Rufiji         Kidudumo       Iringa
# 17            0                   Rufiji           Yeriko       Iringa
# 18            0            Lake Victoria           Center       Mwanza
# 19            0               Lake Nyasa         Manyanya       Iringa
# 20            0               Lake Nyasa          Majengo       Iringa
# 21            0            Lake Victoria       Ibabachegu    Shinyanga
# 22            0                   Rufiji        Mkanivega       Iringa
# 23            0                  Pangani       Mkonga Juu  Kilimanjaro
# 24            0          Lake Tanganyika            Msasa       Kigoma
# 25            0                  Pangani         Kitereni  Kilimanjaro
# 26            0  Ruvuma / Southern Coast          Shuleni        Lindi
# 27            0            Lake Victoria        Chakahaya       Kagera
# 28            0                  Pangani            Kiyao  Kilimanjaro
# 29            0                  Pangani           Merali  Kilimanjaro
# 30            0              Wami / Ruvu           Karume       Dodoma
# 31            0              Wami / Ruvu         Kudipera        Pwani
# 32            0                  Pangani          Mosheni  Kilimanjaro
# 33            0               Lake Nyasa        Lupanga A       Iringa
# 34            0                   Rufiji      Kilombero B        Pwani
# 35            0                  Pangani             Afya       Arusha
# 36            0               Lake Nyasa      Ndanganyika        Mbeya
# 37            0                 Internal            Baura       Dodoma
# 38            0                   Rufiji         Mwanzala       Iringa
# 39            0          Lake Tanganyika        Nyabwai B       Kigoma
# 40            0                  Pangani           Reli B  Kilimanjaro
# 41            0               Lake Nyasa        Kilunduwe       Iringa
# 42            0                   Rufiji           Sokoni       Iringa
# 43            0                 Internal         Mwarufyu      Singida
# 44            0                  Pangani     Marurani Juu       Arusha
# 45            0                 Internal        Isenegeja    Shinyanga
# 46            0  Ruvuma / Southern Coast          Kachulu       Mtwara
# 47            0               Lake Nyasa      Mpandapanda        Mbeya
# 48            0                   Rufiji     Mlandege Juu       Iringa
# 49            0                   Rufiji           Ikanga       Iringa
#
#     region_code  district_code               lga               ward  \
# 0            11              5            Ludewa           Mundindi
# 1            20              2         Serengeti              Natta
# 2            21              4         Simanjiro            Ngorika
# 3            90             63          Nanyumbu           Nanyumbu
# 4            18              1           Karagwe         Nyakasimbi
# 5             4              8            Mkinga                Moa
# 6            17              3   Shinyanga Rural             Samuye
# 7            17              3            Kahama             Chambo
# 8            14              6      Tabora Urban           Itetemia
# 9            18              1           Karagwe             Kaisho
# 10           60             43          Mkuranga            Tambani
# 11           10              5          Namtumbo             Msindo
# 12           17              2             Maswa           Busilili
# 13            3              7              Siha     Siha Kaskazini
# 14           17              6             Meatu              Nkoma
# 15           15              2  Sumbawanga Rural              Mkowe
# 16           11              4            Njombe             Mdandu
# 17           11              4            Njombe              Usuka
# 18           19              1           Ukerewe           Ilangala
# 19           11              5            Ludewa            Mawengi
# 20           11              4            Njombe             Matola
# 21           17              1           Bariadi  Ikungulyabashashi
# 22           11              4            Njombe              Usuka
# 23            3              3              Same           Kisiwani
# 24           16              3      Kigoma Rural              Mkigo
# 25            3              4       Moshi Rural            Kimochi
# 26           80             23       Lindi Rural            Rutamba
# 27           18              1           Karagwe          Nyaishozi
# 28            3              1             Rombo       Mengwe Manda
# 29            3              7              Siha          Siha Kati
# 30            1              4          Chamwino             Dabalo
# 31            6              1          Bagamoyo           Chalinze
# 32            3              4       Moshi Rural       Kilema  Kati
# 33           11              5            Ludewa            Lupanga
# 34           60             63             Mafia             Baleni
# 35            2              2      Arusha Rural           Oltrumet
# 36           12              3             Kyela      Katumbasongwe
# 37            1              1            Kondoa             Mnenia
# 38           11              7            Kilolo    Boma la ng'ombe
# 39           16              1           Kibondo          Rugongowe
# 40            3              4       Moshi Rural               Kahe
# 41           11              3            Makete            Ipelele
# 42           11              4            Njombe            Mtwango
# 43           13              2     Singida Rural              Merya
# 44            2              2      Arusha Rural            Nduruma
# 45           17              3   Shinyanga Rural             Samuye
# 46           90             33            Masasi            Sindano
# 47           12              4            Rungwe             Kiwira
# 48           11              7            Kilolo    Boma la ng'ombe
# 49           11              4            Njombe            Wangama
#
#     population public_meeting              recorded_by scheme_management  \
# 0          109           True  GeoData Consultants Ltd               VWC
# 1          280            NaN  GeoData Consultants Ltd             Other
# 2          250           True  GeoData Consultants Ltd               VWC
# 3           58           True  GeoData Consultants Ltd               VWC
# 4            0           True  GeoData Consultants Ltd               NaN
# 5            1           True  GeoData Consultants Ltd               VWC
# 6            0           True  GeoData Consultants Ltd               VWC
# 7            0           True  GeoData Consultants Ltd               NaN
# 8            0           True  GeoData Consultants Ltd               VWC
# 9            0           True  GeoData Consultants Ltd               NaN
# 10         345           True  GeoData Consultants Ltd  Private operator
# 11         250           True  GeoData Consultants Ltd               WUG
# 12           0           True  GeoData Consultants Ltd               WUG
# 13           1           True  GeoData Consultants Ltd       Water Board
# 14           0           True  GeoData Consultants Ltd               WUG
# 15         200           True  GeoData Consultants Ltd               VWC
# 16          35           True  GeoData Consultants Ltd               WUA
# 17          50           True  GeoData Consultants Ltd               WUA
# 18        1000            NaN  GeoData Consultants Ltd               NaN
# 19           1           True  GeoData Consultants Ltd               VWC
# 20           4           True  GeoData Consultants Ltd               VWC
# 21           0            NaN  GeoData Consultants Ltd               WUG
# 22         350           True  GeoData Consultants Ltd               WUA
# 23         210           True  GeoData Consultants Ltd   Water authority
# 24         156          False  GeoData Consultants Ltd               VWC
# 25         140           True  GeoData Consultants Ltd               VWC
# 26         260          False  GeoData Consultants Ltd               VWC
# 27           0           True  GeoData Consultants Ltd               NaN
# 28           1           True  GeoData Consultants Ltd           Company
# 29           1           True  GeoData Consultants Ltd       Water Board
# 30           0           True  GeoData Consultants Ltd               VWC
# 31         150          False  GeoData Consultants Ltd               WUA
# 32         180          False  GeoData Consultants Ltd             Other
# 33          70           True  GeoData Consultants Ltd               VWC
# 34         100           True  GeoData Consultants Ltd               VWC
# 35         200           True  GeoData Consultants Ltd               NaN
# 36           0           True  GeoData Consultants Ltd               VWC
# 37           0           True  GeoData Consultants Ltd               VWC
# 38         100           True  GeoData Consultants Ltd               VWC
# 39         230           True  GeoData Consultants Ltd               VWC
# 40          50           True  GeoData Consultants Ltd       Water Board
# 41           0           True  GeoData Consultants Ltd               VWC
# 42         250           True  GeoData Consultants Ltd               WUG
# 43           1           True  GeoData Consultants Ltd               VWC
# 44         100           True  GeoData Consultants Ltd               VWC
# 45           0           True  GeoData Consultants Ltd               WUG
# 46          30           True  GeoData Consultants Ltd               VWC
# 47           0           True  GeoData Consultants Ltd               VWC
# 48          70           True  GeoData Consultants Ltd               VWC
# 49          20           True  GeoData Consultants Ltd               VWC
#
#                        scheme_name permit  construction_year extraction_type  \
# 0                            Roman  False               1999         gravity
# 1                              NaN   True               2010         gravity
# 2      Nyumba ya mungu pipe scheme   True               2009         gravity
# 3                              NaN   True               1986     submersible
# 4                              NaN   True                  0         gravity
# 5                        Zingibali   True               2009     submersible
# 6                              NaN   True                  0          swn 80
# 7                              NaN   True                  0     nira/tanira
# 8                              NaN   True                  0   india mark ii
# 9                              NaN   True                  0     nira/tanira
# 10                             NaN  False               2011     submersible
# 11                             NaN  False               1987          swn 80
# 12                             NaN  False                  0     nira/tanira
# 13                      BL Bondeni   True               2009         gravity
# 14                            None   True                  0     nira/tanira
# 15                             NaN  False               1991          swn 80
# 16     wanging'ombe water supply s   True               1978         gravity
# 17     wanging'ombe water supply s   True               1978         gravity
# 18                             NaN   True               1999           other
# 19                          Makanj   True               1992         gravity
# 20                          Kidabu  False               2008         gravity
# 21                             NaN  False                  0          swn 80
# 22     wanging'ombe water supply s   True               1978         gravity
# 23                       Mashangwi   True               2011         gravity
# 24              Quick wins Program   True               2009         gravity
# 25                  Komaka mandaka   True               1974         gravity
# 26          Sobodo Borehole Scheme  False               2011   india mark ii
# 27                             NaN   True                  0     nira/tanira
# 28           Kitukuni water supply   True               2000         gravity
# 29                    BL Mwakikoti   True               2002         gravity
# 30                             NaN   True                  0     nira/tanira
# 31                   Chalinze wate   True               2004             ksb
# 32                    Mae pipeline   True               1972         gravity
# 33                            UNDP  False               1992         gravity
# 34                             NaN  False                  0     nira/tanira
# 35                             NaN   True               2000           other
# 36     Ngana water supplied scheme   True                  0         gravity
# 37                            Itun  False                  0         gravity
# 38                          Bomala   True               2003         gravity
# 39                             NaN  False               2002     nira/tanira
# 40  Kirua kahe pumping water trust   True               2008     submersible
# 41                          Misiwa  False               1986         gravity
# 42     Mtwango water supplied sche   True               2011         gravity
# 43                               K    NaN               1980            mono
# 44       Machumba estate pipe line   True               2000         gravity
# 45                         SHIMASA   True                  0        windmill
# 46                             NaN   True               2004         gravity
# 47                               K    NaN                  0         gravity
# 48                          Bomala   True               2003         gravity
# 49     wangama water supply scheme   True               2007         gravity
#
#    extraction_type_group extraction_type_class        management  \
# 0                gravity               gravity               vwc
# 1                gravity               gravity               wug
# 2                gravity               gravity               vwc
# 3            submersible           submersible               vwc
# 4                gravity               gravity             other
# 5            submersible           submersible               vwc
# 6                 swn 80              handpump               vwc
# 7            nira/tanira              handpump               wug
# 8          india mark ii              handpump               vwc
# 9            nira/tanira              handpump               vwc
# 10           submersible           submersible  private operator
# 11                swn 80              handpump               wug
# 12           nira/tanira              handpump               wug
# 13               gravity               gravity       water board
# 14           nira/tanira              handpump               wug
# 15                swn 80              handpump               vwc
# 16               gravity               gravity               wua
# 17               gravity               gravity               wua
# 18                 other                 other               vwc
# 19               gravity               gravity               vwc
# 20               gravity               gravity               vwc
# 21                swn 80              handpump               wug
# 22               gravity               gravity               wua
# 23               gravity               gravity               vwc
# 24               gravity               gravity               vwc
# 25               gravity               gravity               vwc
# 26         india mark ii              handpump               vwc
# 27           nira/tanira              handpump               vwc
# 28               gravity               gravity           company
# 29               gravity               gravity       water board
# 30           nira/tanira              handpump               vwc
# 31           submersible           submersible  private operator
# 32               gravity               gravity             other
# 33               gravity               gravity               vwc
# 34           nira/tanira              handpump               vwc
# 35                 other                 other               vwc
# 36               gravity               gravity               vwc
# 37               gravity               gravity               vwc
# 38               gravity               gravity               vwc
# 39           nira/tanira              handpump               vwc
# 40           submersible           submersible       water board
# 41               gravity               gravity               vwc
# 42               gravity               gravity               wug
# 43                  mono             motorpump               vwc
# 44               gravity               gravity               vwc
# 45          wind-powered          wind-powered               wug
# 46               gravity               gravity               vwc
# 47               gravity               gravity               vwc
# 48               gravity               gravity               vwc
# 49               gravity               gravity               vwc
#
#    management_group                payment payment_type water_quality  \
# 0        user-group           pay annually     annually          soft
# 1        user-group              never pay    never pay          soft
# 2        user-group         pay per bucket   per bucket          soft
# 3        user-group              never pay    never pay          soft
# 4             other              never pay    never pay          soft
# 5        user-group         pay per bucket   per bucket         salty
# 6        user-group              never pay    never pay          soft
# 7        user-group                unknown      unknown         milky
# 8        user-group              never pay    never pay         salty
# 9        user-group              never pay    never pay          soft
# 10       commercial              never pay    never pay         salty
# 11       user-group  pay when scheme fails   on failure          soft
# 12       user-group                  other        other          soft
# 13       user-group            pay monthly      monthly          soft
# 14       user-group              never pay    never pay          soft
# 15       user-group              never pay    never pay          soft
# 16       user-group            pay monthly      monthly          soft
# 17       user-group  pay when scheme fails   on failure          soft
# 18       user-group              never pay    never pay         milky
# 19       user-group           pay annually     annually          soft
# 20       user-group            pay monthly      monthly          soft
# 21       user-group                unknown      unknown       unknown
# 22       user-group              never pay    never pay          soft
# 23       user-group            pay monthly      monthly          soft
# 24       user-group                unknown      unknown          soft
# 25       user-group                unknown      unknown          soft
# 26       user-group            pay monthly      monthly          soft
# 27       user-group              never pay    never pay          soft
# 28       commercial            pay monthly      monthly          soft
# 29       user-group            pay monthly      monthly          soft
# 30       user-group              never pay    never pay          soft
# 31       commercial         pay per bucket   per bucket          soft
# 32            other              never pay    never pay          soft
# 33       user-group  pay when scheme fails   on failure          soft
# 34       user-group              never pay    never pay         salty
# 35       user-group              never pay    never pay          soft
# 36       user-group              never pay    never pay          soft
# 37       user-group            pay monthly      monthly          soft
# 38       user-group           pay annually     annually          soft
# 39       user-group                unknown      unknown          soft
# 40       user-group         pay per bucket   per bucket          soft
# 41       user-group  pay when scheme fails   on failure          soft
# 42       user-group            pay monthly      monthly          soft
# 43       user-group                unknown      unknown       unknown
# 44       user-group         pay per bucket   per bucket          soft
# 45       user-group  pay when scheme fails   on failure          soft
# 46       user-group         pay per bucket   per bucket          soft
# 47       user-group              never pay    never pay          soft
# 48       user-group           pay annually     annually          soft
# 49       user-group           pay annually     annually          soft
#
#    quality_group      quantity quantity_group                source  \
# 0           good        enough         enough                spring
# 1           good  insufficient   insufficient  rainwater harvesting
# 2           good        enough         enough                   dam
# 3           good           dry            dry           machine dbh
# 4           good      seasonal       seasonal  rainwater harvesting
# 5          salty        enough         enough                 other
# 6           good        enough         enough           machine dbh
# 7          milky        enough         enough          shallow well
# 8          salty      seasonal       seasonal           machine dbh
# 9           good        enough         enough          shallow well
# 10         salty        enough         enough           machine dbh
# 11          good  insufficient   insufficient          shallow well
# 12          good        enough         enough          shallow well
# 13          good        enough         enough                spring
# 14          good        enough         enough          shallow well
# 15          good        enough         enough           machine dbh
# 16          good           dry            dry                 river
# 17          good           dry            dry                 river
# 18         milky  insufficient   insufficient                spring
# 19          good        enough         enough                spring
# 20          good        enough         enough                spring
# 21       unknown       unknown        unknown          shallow well
# 22          good        enough         enough                 river
# 23          good        enough         enough                 river
# 24          good        enough         enough                spring
# 25          good        enough         enough                spring
# 26          good        enough         enough           machine dbh
# 27          good        enough         enough          shallow well
# 28          good  insufficient   insufficient                spring
# 29          good        enough         enough                spring
# 30          good  insufficient   insufficient          shallow well
# 31          good        enough         enough                 river
# 32          good  insufficient   insufficient                 river
# 33          good      seasonal       seasonal                spring
# 34         salty        enough         enough          shallow well
# 35          good      seasonal       seasonal  rainwater harvesting
# 36          good           dry            dry                spring
# 37          good        enough         enough                spring
# 38          good        enough         enough                 river
# 39          good      seasonal       seasonal          shallow well
# 40          good        enough         enough           machine dbh
# 41          good        enough         enough                spring
# 42          good        enough         enough                spring
# 43       unknown           dry            dry           machine dbh
# 44          good  insufficient   insufficient                spring
# 45          good        enough         enough           machine dbh
# 46          good        enough         enough                spring
# 47          good        enough         enough                spring
# 48          good        enough         enough                spring
# 49          good        enough         enough                spring
#
#              source_type source_class              waterpoint_type  \
# 0                 spring  groundwater           communal standpipe
# 1   rainwater harvesting      surface           communal standpipe
# 2                    dam      surface  communal standpipe multiple
# 3               borehole  groundwater  communal standpipe multiple
# 4   rainwater harvesting      surface           communal standpipe
# 5                  other      unknown  communal standpipe multiple
# 6               borehole  groundwater                    hand pump
# 7           shallow well  groundwater                    hand pump
# 8               borehole  groundwater                    hand pump
# 9           shallow well  groundwater                    hand pump
# 10              borehole  groundwater                        other
# 11          shallow well  groundwater                    hand pump
# 12          shallow well  groundwater                    hand pump
# 13                spring  groundwater           communal standpipe
# 14          shallow well  groundwater                    hand pump
# 15              borehole  groundwater                    hand pump
# 16            river/lake      surface           communal standpipe
# 17            river/lake      surface           communal standpipe
# 18                spring  groundwater                        other
# 19                spring  groundwater           communal standpipe
# 20                spring  groundwater           communal standpipe
# 21          shallow well  groundwater                    hand pump
# 22            river/lake      surface           communal standpipe
# 23            river/lake      surface           communal standpipe
# 24                spring  groundwater              improved spring
# 25                spring  groundwater           communal standpipe
# 26              borehole  groundwater                    hand pump
# 27          shallow well  groundwater                    hand pump
# 28                spring  groundwater           communal standpipe
# 29                spring  groundwater           communal standpipe
# 30          shallow well  groundwater                    hand pump
# 31            river/lake      surface           communal standpipe
# 32            river/lake      surface                        other
# 33                spring  groundwater           communal standpipe
# 34          shallow well  groundwater                    hand pump
# 35  rainwater harvesting      surface                        other
# 36                spring  groundwater           communal standpipe
# 37                spring  groundwater           communal standpipe
# 38            river/lake      surface           communal standpipe
# 39          shallow well  groundwater                    hand pump
# 40              borehole  groundwater           communal standpipe
# 41                spring  groundwater           communal standpipe
# 42                spring  groundwater           communal standpipe
# 43              borehole  groundwater           communal standpipe
# 44                spring  groundwater           communal standpipe
# 45              borehole  groundwater           communal standpipe
# 46                spring  groundwater           communal standpipe
# 47                spring  groundwater           communal standpipe
# 48                spring  groundwater           communal standpipe
# 49                spring  groundwater           communal standpipe
#
#    waterpoint_type_group  target  water_per_person
# 0     communal standpipe       0         55.045872
# 1     communal standpipe       0          0.000000
# 2     communal standpipe       0          0.100000
# 3     communal standpipe       1          0.000000
# 4     communal standpipe       0               NaN
# 5     communal standpipe       0         20.000000
# 6              hand pump       1               NaN
# 7              hand pump       1               NaN
# 8              hand pump       1               NaN
# 9              hand pump       0               NaN
# 10                 other       0          0.000000
# 11             hand pump       0          0.800000
# 12             hand pump       0               NaN
# 13    communal standpipe       0          0.000000
# 14             hand pump       0               NaN
# 15             hand pump       0          0.000000
# 16    communal standpipe       1         14.285714
# 17    communal standpipe       1          0.000000
# 18                 other       2          0.000000
# 19    communal standpipe       0        500.000000
# 20    communal standpipe       0         50.000000
# 21             hand pump       0               NaN
# 22    communal standpipe       2          0.000000
# 23    communal standpipe       0          2.380952
# 24       improved spring       0          0.000000
# 25    communal standpipe       2          0.000000
# 26             hand pump       0          1.923077
# 27             hand pump       0               NaN
# 28    communal standpipe       1          0.000000
# 29    communal standpipe       0          0.000000
# 30             hand pump       0               NaN
# 31    communal standpipe       0          0.333333
# 32                 other       2          0.000000
# 33    communal standpipe       0          0.000000
# 34             hand pump       0          0.000000
# 35                 other       1          0.000000
# 36    communal standpipe       1               NaN
# 37    communal standpipe       0               NaN
# 38    communal standpipe       0         40.000000
# 39             hand pump       1          0.000000
# 40    communal standpipe       0          0.500000
# 41    communal standpipe       0               inf
# 42    communal standpipe       0          2.000000
# 43    communal standpipe       1          0.000000
# 44    communal standpipe       2          0.200000
# 45    communal standpipe       1               NaN
# 46    communal standpipe       2          0.666667
# 47    communal standpipe       0               NaN
# 48    communal standpipe       0         57.142857
# 49    communal standpipe       0         75.000000

# %%
df_1['water_per_person'].value_counts(normalize=True)
# Out:
# 0.000000     0.545103
# inf          0.026252
# 0.200000     0.011013
# 50.000000    0.010783
# 3.333333     0.010142
#                ...
# 0.153257     0.000026
# 2.092050     0.000026
# 0.279330     0.000026
# 0.851064     0.000026
# 1.524390     0.000026
# Name: water_per_person, Length: 1915, dtype: float64

# %%
df_1['water_per_person'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### installer
# Feature 'installer' is defined as organization that installed the well.  A question to consider is whether the installer of the wells has any role in whether the wells functions.  The largest category of 'installer' is DWE which constitutes 85% of this category. The second largest is governmen which is 9% of this category.  In DWE, about 9050 wells are functioning. But around 6050 wells are not functioning and around 1075 function but need repairs.  With government the number of non-functioning wells (around 1000) exceed the functioning (around 500).  Consider whether proper installation and whether it can be approved.

# %%
df_1['installer'].value_counts(dropna=False)
# Out:
# DWE                       17402
# NaN                        3655
# Government                 1825
# RWE                        1206
# Commu                      1060
#                           ...
# Eastmeru medium School        1
# Mohamed Ally                  1
# wananchi technicians          1
# Luleka                        1
# Others                        1
# Name: installer, Length: 2146, dtype: int64

# %%
installer = df_1['installer'].value_counts(dropna=False).head(10)

# %%
installer.plot(kind='bar')

# %%
dwe_gov = df_1[(df_1['installer'] == 'DWE') | (df_1['installer']== 'Government') |
                (df_1['installer']== 'RWE')]

# %%
dwe_gov.head()
# Out:
#     amount_tsh date_recorded               funder  gps_height installer  \
# 5         20.0    2011-03-13  Mkinga Distric Coun           0       DWE
# 7          0.0    2012-10-09                Rwssp           0       DWE
# 15         0.0    2011-08-04                Rudep        1645       DWE
# 16       500.0    2011-07-04               Unicef        1703       DWE
# 17         0.0    2011-09-04               Unicef        1656       DWE
#
#     longitude  latitude                wpt_name  num_private            basin  \
# 5   39.172796 -4.765587                  Tajiri            0          Pangani
# 7   32.620617 -4.226198            Tushirikiane            0  Lake Tanganyika
# 15  31.444121 -8.274962  Kwa Juvenal Ching'Ombe            0  Lake Tanganyika
# 16  34.642439 -9.106185         Kwa John Mtenzi            0           Rufiji
# 17  34.569266 -9.085515         Kwa Rose Chaula            0           Rufiji
#
#          subvillage     region  region_code  district_code               lga  \
# 5       Moa/Mwereme      Tanga            4              8            Mkinga
# 7   Nyawishi Center  Shinyanga           17              3            Kahama
# 15            Tunzi      Rukwa           15              2  Sumbawanga Rural
# 16         Kidudumo     Iringa           11              4            Njombe
# 17           Yeriko     Iringa           11              4            Njombe
#
#       ward  population public_meeting              recorded_by  \
# 5      Moa           1           True  GeoData Consultants Ltd
# 7   Chambo           0           True  GeoData Consultants Ltd
# 15   Mkowe         200           True  GeoData Consultants Ltd
# 16  Mdandu          35           True  GeoData Consultants Ltd
# 17   Usuka          50           True  GeoData Consultants Ltd
#
#    scheme_management                  scheme_name permit  construction_year  \
# 5                VWC                    Zingibali   True               2009
# 7                NaN                          NaN   True                  0
# 15               VWC                          NaN  False               1991
# 16               WUA  wanging'ombe water supply s   True               1978
# 17               WUA  wanging'ombe water supply s   True               1978
#
#    extraction_type extraction_type_group extraction_type_class management  \
# 5      submersible           submersible           submersible        vwc
# 7      nira/tanira           nira/tanira              handpump        wug
# 15          swn 80                swn 80              handpump        vwc
# 16         gravity               gravity               gravity        wua
# 17         gravity               gravity               gravity        wua
#
#    management_group                payment payment_type water_quality  \
# 5        user-group         pay per bucket   per bucket         salty
# 7        user-group                unknown      unknown         milky
# 15       user-group              never pay    never pay          soft
# 16       user-group            pay monthly      monthly          soft
# 17       user-group  pay when scheme fails   on failure          soft
#
#    quality_group quantity quantity_group        source   source_type  \
# 5          salty   enough         enough         other         other
# 7          milky   enough         enough  shallow well  shallow well
# 15          good   enough         enough   machine dbh      borehole
# 16          good      dry            dry         river    river/lake
# 17          good      dry            dry         river    river/lake
#
#    source_class              waterpoint_type waterpoint_type_group  target  \
# 5       unknown  communal standpipe multiple    communal standpipe       0
# 7   groundwater                    hand pump             hand pump       1
# 15  groundwater                    hand pump             hand pump       0
# 16      surface           communal standpipe    communal standpipe       1
# 17      surface           communal standpipe    communal standpipe       1
#
#     water_per_person
# 5          20.000000
# 7                NaN
# 15          0.000000
# 16         14.285714
# 17          0.000000

# %%
feature_w_hue(dwe_gov, col='installer', hue_col='target',rot=40,figsize=(10,5))
# Out:
# DWE           17402
# Government     1825
# RWE            1206
# Name: installer, dtype: int64
#
#
# DWE           0.852
# Government    0.089
# RWE           0.059
# Name: installer, dtype: float64
# ---------------------------------------------

# %% [markdown]
# #### basin

# %% [markdown]
# basin is defined as geographic water basin. Lake Victoria, Pangani, Rufiji and Internal have the highest number of wells. Lake Victoria is 17% of the category.  Lake Victoria has a little over 5,000 funcitoning wells and over 4,000 non-functionig wells.  Rufiji is 13% of the category and has a little over 5,000 wells that work and approximately 2,500 number non-functioning wells.  This is important so that the differences in the basins can be explored, ie, why does Rufiji have a higher number of functioning wells and fewer non-fucntioning compared to the others.  What are the differnces and similarities in these wells.

# %%
feature_w_hue(df_1, col='basin', hue_col='target',rot=40,figsize=(10,5))
# Out:
# Lake Victoria              10248
# Pangani                     8940
# Rufiji                      7976
# Internal                    7785
# Lake Tanganyika             6432
# Wami / Ruvu                 5987
# Lake Nyasa                  5085
# Ruvuma / Southern Coast     4493
# Lake Rukwa                  2454
# Name: basin, dtype: int64
#
#
# Lake Victoria              0.173
# Pangani                    0.151
# Rufiji                     0.134
# Internal                   0.131
# Lake Tanganyika            0.108
# Wami / Ruvu                0.101
# Lake Nyasa                 0.086
# Ruvuma / Southern Coast    0.076
# Lake Rukwa                 0.041
# Name: basin, dtype: float64
# ---------------------------------------------

# %%
basin = pd.crosstab(df_1['basin'],df_1['target'])
basin
# Out:
# target                      0     1    2
# basin
# Internal                 4482  2746  557
# Lake Nyasa               3324  1511  250
# Lake Rukwa               1000  1184  270
# Lake Tanganyika          3107  2583  742
# Lake Victoria            5100  4159  989
# Pangani                  5372  3091  477
# Rufiji                   5068  2471  437
# Ruvuma / Southern Coast  1670  2497  326
# Wami / Ruvu              3136  2582  269

# %% [markdown]
# #### region
# Feature 'region' is defined as the geographic location.  Iringa, Shinaya, Mbeya are the largest categories in this feature.  Iringa also has the largest number of functioning wells with over 4,000 wells and a little over 1,000 non-fucntioning wells. In contrast regions like Mbeya have close to the same amount of wells that function and do not function.  Need to investigate what Iringa is doing correctly for insights to be applied in other basins.  Also, more concentration on other regions with higher numbers of non-fucntioning wells.

# %%
feature_w_hue(df_1, col='region', hue_col='target',rot=40,figsize=(13,5))
# Out:
# Iringa           5294
# Shinyanga        4982
# Mbeya            4639
# Kilimanjaro      4379
# Morogoro         4006
# Arusha           3350
# Kagera           3316
# Mwanza           3102
# Kigoma           2816
# Ruvuma           2640
# Pwani            2635
# Tanga            2547
# Dodoma           2201
# Singida          2093
# Mara             1969
# Tabora           1959
# Rukwa            1808
# Mtwara           1730
# Manyara          1583
# Lindi            1546
# Dar es Salaam     805
# Name: region, dtype: int64
#
#
# Iringa           0.089
# Shinyanga        0.084
# Mbeya            0.078
# Kilimanjaro      0.074
# Morogoro         0.067
# Arusha           0.056
# Kagera           0.056
# Mwanza           0.052
# Kigoma           0.047
# Ruvuma           0.044
# Pwani            0.044
# Tanga            0.043
# Dodoma           0.037
# Singida          0.035
# Mara             0.033
# Tabora           0.033
# Rukwa            0.030
# Mtwara           0.029
# Manyara          0.027
# Lindi            0.026
# Dar es Salaam    0.014
# Name: region, dtype: float64
# ---------------------------------------------

# %% [markdown]
# #### permit
# Whether a permit was taken out does it have an impact on whether the wells is non-funcitoning. The category of taking out a permit is 69% of the category. Over 20,000 wells that were built with permits function but 15,000 don't function. There 2,500 that funciton but need repairs. Around 9,000 fucntioning wells with no permit and around 7,000 are non-functiong.  With permits thee are higher number of wells that function but there is also a high number that don't function.

# %%
feature_w_hue(df_1, col='permit', hue_col='target',rot=40,figsize=(13,5))
# Out:
# True     38852
# False    17492
# NaN       3056
# Name: permit, dtype: int64
#
#
# True     0.69
# False    0.31
# Name: permit, dtype: float64
# ---------------------------------------------

# %% [markdown]
# #### construction_year
# Feature 'construction_year' is defined as the year the waterpoint was constructed. Feature is an int datatype. Data is from 1960 to 2013.  An issue is that 35% of the feature has a value of 0. The next largest category is year 2010 with 4% and then year 2008 with 4%.

# %%
#feature_distribution(df_1, col='construction_year',ticklabels=['construction_year'.index],figsize=(8,5))
fig,ax = plt.subplots(figsize=(15,6))
sns.countplot(x='construction_year',data=df_1);
ax.set_xticklabels(ax.get_xticklabels(), fontdict={'rotation':40,'ha':'right'});

# %%
df_1['no_construct_yr'] = df_1['construction_year']== 0

# %%
df_1.head()
# Out:
#    amount_tsh date_recorded        funder  gps_height     installer  \
# 0      6000.0    2011-03-14         Roman        1390         Roman
# 1         0.0    2013-03-06       Grumeti        1399       GRUMETI
# 2        25.0    2013-02-25  Lottery Club         686  World vision
# 3         0.0    2013-01-28        Unicef         263        UNICEF
# 4         0.0    2011-07-13   Action In A           0       Artisan
#
#    longitude   latitude              wpt_name  num_private  \
# 0  34.938093  -9.856322                  none            0
# 1  34.698766  -2.147466              Zahanati            0
# 2  37.460664  -3.821329           Kwa Mahundi            0
# 3  38.486161 -11.155298  Zahanati Ya Nanyumbu            0
# 4  31.130847  -1.825359               Shuleni            0
#
#                      basin  subvillage   region  region_code  district_code  \
# 0               Lake Nyasa    Mnyusi B   Iringa           11              5
# 1            Lake Victoria     Nyamara     Mara           20              2
# 2                  Pangani     Majengo  Manyara           21              4
# 3  Ruvuma / Southern Coast  Mahakamani   Mtwara           90             63
# 4            Lake Victoria  Kyanyamisa   Kagera           18              1
#
#          lga        ward  population public_meeting              recorded_by  \
# 0     Ludewa    Mundindi         109           True  GeoData Consultants Ltd
# 1  Serengeti       Natta         280            NaN  GeoData Consultants Ltd
# 2  Simanjiro     Ngorika         250           True  GeoData Consultants Ltd
# 3   Nanyumbu    Nanyumbu          58           True  GeoData Consultants Ltd
# 4    Karagwe  Nyakasimbi           0           True  GeoData Consultants Ltd
#
#   scheme_management                  scheme_name permit  construction_year  \
# 0               VWC                        Roman  False               1999
# 1             Other                          NaN   True               2010
# 2               VWC  Nyumba ya mungu pipe scheme   True               2009
# 3               VWC                          NaN   True               1986
# 4               NaN                          NaN   True                  0
#
#   extraction_type extraction_type_group extraction_type_class management  \
# 0         gravity               gravity               gravity        vwc
# 1         gravity               gravity               gravity        wug
# 2         gravity               gravity               gravity        vwc
# 3     submersible           submersible           submersible        vwc
# 4         gravity               gravity               gravity      other
#
#   management_group         payment payment_type water_quality quality_group  \
# 0       user-group    pay annually     annually          soft          good
# 1       user-group       never pay    never pay          soft          good
# 2       user-group  pay per bucket   per bucket          soft          good
# 3       user-group       never pay    never pay          soft          good
# 4            other       never pay    never pay          soft          good
#
#        quantity quantity_group                source           source_type  \
# 0        enough         enough                spring                spring
# 1  insufficient   insufficient  rainwater harvesting  rainwater harvesting
# 2        enough         enough                   dam                   dam
# 3           dry            dry           machine dbh              borehole
# 4      seasonal       seasonal  rainwater harvesting  rainwater harvesting
#
#   source_class              waterpoint_type waterpoint_type_group  target  \
# 0  groundwater           communal standpipe    communal standpipe       0
# 1      surface           communal standpipe    communal standpipe       0
# 2      surface  communal standpipe multiple    communal standpipe       0
# 3  groundwater  communal standpipe multiple    communal standpipe       1
# 4      surface           communal standpipe    communal standpipe       0
#
#    water_per_person  no_construct_yr
# 0         55.045872            False
# 1          0.000000            False
# 2          0.100000            False
# 3          0.000000            False
# 4               NaN             True

# %%
sns.distplot(df_1['construction_year'][df_1['construction_year']>0]);
plt.title("Water Pump Construction by Years", fontsize=16, fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Water Pump Construction by Years')

# %% [markdown]
# #### quantity

# %%
feature_w_hue(df_1, col='quantity', hue_col='target',rot=None,figsize=(8,5))
# Out:
# enough          33186
# insufficient    15129
# dry              6246
# seasonal         4050
# unknown           789
# Name: quantity, dtype: int64
#
#
# enough          0.559
# insufficient    0.255
# dry             0.105
# seasonal        0.068
# unknown         0.013
# Name: quantity, dtype: float64
# ---------------------------------------------

# %% [markdown]
# #### management_group

# %%
"""
usergroup is the largest entites/management groups involved in water wells.  
vwc is the largest in hte management_group. 

"""
df_1.groupby(['management_group','management']).count()
# Out:
#                                    amount_tsh  date_recorded  funder  \
# management_group management
# commercial       company                  685            685     663
#                  private operator        1971           1971    1957
#                  trust                     78             78      78
#                  water authority          904            904     836
# other            other                    844            844     837
#                  other - school            99             99      99
# parastatal       parastatal              1768           1768    1624
# unknown          unknown                  561            561     533
# user-group       vwc                    40507          40507   37632
#                  water board             2933           2933    2715
#                  wua                     2535           2535    2308
#                  wug                     6515           6515    6483
#
#                                    gps_height  installer  longitude  latitude  \
# management_group management
# commercial       company                  685        663        685       685
#                  private operator        1971       1959       1971      1971
#                  trust                     78         78         78        78
#                  water authority          904        836        904       904
# other            other                    844        831        844       844
#                  other - school            99         99         99        99
# parastatal       parastatal              1768       1626       1768      1768
# unknown          unknown                  561        527        561       561
# user-group       vwc                    40507      37630      40507     40507
#                  water board             2933       2714       2933      2933
#                  wua                     2535       2309       2535      2535
#                  wug                     6515       6473       6515      6515
#
#                                    wpt_name  num_private  basin  subvillage  \
# management_group management
# commercial       company                685          685    685         685
#                  private operator      1971         1971   1971        1932
#                  trust                   78           78     78          78
#                  water authority        904          904    904         895
# other            other                  844          844    844         839
#                  other - school          99           99     99          99
# parastatal       parastatal            1768         1768   1768        1768
# unknown          unknown                561          561    561         561
# user-group       vwc                  40507        40507  40507       40189
#                  water board           2933         2933   2933        2933
#                  wua                   2535         2535   2535        2535
#                  wug                   6515         6515   6515        6515
#
#                                    region  region_code  district_code    lga  \
# management_group management
# commercial       company              685          685            685    685
#                  private operator    1971         1971           1971   1971
#                  trust                 78           78             78     78
#                  water authority      904          904            904    904
# other            other                844          844            844    844
#                  other - school        99           99             99     99
# parastatal       parastatal          1768         1768           1768   1768
# unknown          unknown              561          561            561    561
# user-group       vwc                40507        40507          40507  40507
#                  water board         2933         2933           2933   2933
#                  wua                 2535         2535           2535   2535
#                  wug                 6515         6515           6515   6515
#
#                                     ward  population  public_meeting  \
# management_group management
# commercial       company             685         685             684
#                  private operator   1971        1971            1660
#                  trust                78          78              77
#                  water authority     904         904             878
# other            other               844         844             689
#                  other - school       99          99              99
# parastatal       parastatal         1768        1768            1518
# unknown          unknown             561         561             301
# user-group       vwc               40507       40507           39208
#                  water board        2933        2933            2893
#                  wua                2535        2535            2522
#                  wug                6515        6515            5537
#
#                                    recorded_by  scheme_management  \
# management_group management
# commercial       company                   685                684
#                  private operator         1971               1852
#                  trust                      78                 77
#                  water authority           904                902
# other            other                     844                658
#                  other - school             99                 99
# parastatal       parastatal               1768               1757
# unknown          unknown                   561                 93
# user-group       vwc                     40507              38057
#                  water board              2933               2933
#                  wua                      2535               2529
#                  wug                      6515               5882
#
#                                    scheme_name  permit  construction_year  \
# management_group management
# commercial       company                   655     658                685
#                  private operator          992    1893               1971
#                  trust                      26      77                 78
#                  water authority           624     825                904
# other            other                     270     744                844
#                  other - school              0      99                 99
# parastatal       parastatal                604    1595               1768
# unknown          unknown                   240     519                561
# user-group       vwc                     22083   38296              40507
#                  water board              2579    2830               2933
#                  wua                      2006    2468               2535
#                  wug                      1155    6340               6515
#
#                                    extraction_type  extraction_type_group  \
# management_group management
# commercial       company                       685                    685
#                  private operator             1971                   1971
#                  trust                          78                     78
#                  water authority               904                    904
# other            other                         844                    844
#                  other - school                 99                     99
# parastatal       parastatal                   1768                   1768
# unknown          unknown                       561                    561
# user-group       vwc                         40507                  40507
#                  water board                  2933                   2933
#                  wua                          2535                   2535
#                  wug                          6515                   6515
#
#                                    extraction_type_class  payment  \
# management_group management
# commercial       company                             685      685
#                  private operator                   1971     1971
#                  trust                                78       78
#                  water authority                     904      904
# other            other                               844      844
#                  other - school                       99       99
# parastatal       parastatal                         1768     1768
# unknown          unknown                             561      561
# user-group       vwc                               40507    40507
#                  water board                        2933     2933
#                  wua                                2535     2535
#                  wug                                6515     6515
#
#                                    payment_type  water_quality  quality_group  \
# management_group management
# commercial       company                    685            685            685
#                  private operator          1971           1971           1971
#                  trust                       78             78             78
#                  water authority            904            904            904
# other            other                      844            844            844
#                  other - school              99             99             99
# parastatal       parastatal                1768           1768           1768
# unknown          unknown                    561            561            561
# user-group       vwc                      40507          40507          40507
#                  water board               2933           2933           2933
#                  wua                       2535           2535           2535
#                  wug                       6515           6515           6515
#
#                                    quantity  quantity_group  source  \
# management_group management
# commercial       company                685             685     685
#                  private operator      1971            1971    1971
#                  trust                   78              78      78
#                  water authority        904             904     904
# other            other                  844             844     844
#                  other - school          99              99      99
# parastatal       parastatal            1768            1768    1768
# unknown          unknown                561             561     561
# user-group       vwc                  40507           40507   40507
#                  water board           2933            2933    2933
#                  wua                   2535            2535    2535
#                  wug                   6515            6515    6515
#
#                                    source_type  source_class  waterpoint_type  \
# management_group management
# commercial       company                   685           685              685
#                  private operator         1971          1971             1971
#                  trust                      78            78               78
#                  water authority           904           904              904
# other            other                     844           844              844
#                  other - school             99            99               99
# parastatal       parastatal               1768          1768             1768
# unknown          unknown                   561           561              561
# user-group       vwc                     40507         40507            40507
#                  water board              2933          2933             2933
#                  wua                      2535          2535             2535
#                  wug                      6515          6515             6515
#
#                                    waterpoint_type_group  target  \
# management_group management
# commercial       company                             685     685
#                  private operator                   1971    1971
#                  trust                                78      78
#                  water authority                     904     904
# other            other                               844     844
#                  other - school                       99      99
# parastatal       parastatal                         1768    1768
# unknown          unknown                             561     561
# user-group       vwc                               40507   40507
#                  water board                        2933    2933
#                  wua                                2535    2535
#                  wug                                6515    6515
#
#                                    water_per_person  no_construct_yr
# management_group management
# commercial       company                        656              685
#                  private operator              1644             1971
#                  trust                           77               78
#                  water authority                589              904
# other            other                          567              844
#                  other - school                  99               99
# parastatal       parastatal                    1110             1768
# unknown          unknown                        385              561
# user-group       vwc                          26666            40507
#                  water board                   2782             2933
#                  wua                           2196             2535
#                  wug                           2273             6515

# %%
sns.countplot(x='management_group',data=df_1, hue='target');

# %%
df_1.groupby(['management_group','management']).count()['target'].plot(kind='bar')

# %% [markdown]
# #### payment
# payment is defined as what the water cost.  The largest category in the feature is never pay which is 42% of the feature.  The next largest categories are pay per bucket which 15% of feature and pay monthly which is 14% of the feature.<br>
# <br>
# A question is whether paying for water impacts the liklihood of whether a well works or not. For wells where no payment is made, 48% wells didn't work, 45% wells worked and 8% work but need repairs.  So when the water is not paid for there is almost an equal chance that it will work on not work.

# %%
df_1['payment_type'].value_counts(dropna=False)
# Out:
# never pay     25348
# per bucket     8985
# monthly        8300
# unknown        8157
# on failure     3914
# annually       3642
# other          1054
# Name: payment_type, dtype: int64

# %%
feature_w_hue(df_1, col='payment', hue_col='target',rot=40)
# Out:
# never pay                25348
# pay per bucket            8985
# pay monthly               8300
# unknown                   8157
# pay when scheme fails     3914
# pay annually              3642
# other                     1054
# Name: payment, dtype: int64
#
#
# never pay                0.427
# pay per bucket           0.151
# pay monthly              0.140
# unknown                  0.137
# pay when scheme fails    0.066
# pay annually             0.061
# other                    0.018
# Name: payment, dtype: float64
# ---------------------------------------------

# %%
never_pay = df_1[df_1['payment']== 'never pay']
never_pay.head(3)
# Out:
#    amount_tsh date_recorded       funder  gps_height installer  longitude  \
# 1         0.0    2013-03-06      Grumeti        1399   GRUMETI  34.698766
# 3         0.0    2013-01-28       Unicef         263    UNICEF  38.486161
# 4         0.0    2011-07-13  Action In A           0   Artisan  31.130847
#
#     latitude              wpt_name  num_private                    basin  \
# 1  -2.147466              Zahanati            0            Lake Victoria
# 3 -11.155298  Zahanati Ya Nanyumbu            0  Ruvuma / Southern Coast
# 4  -1.825359               Shuleni            0            Lake Victoria
#
#    subvillage  region  region_code  district_code        lga        ward  \
# 1     Nyamara    Mara           20              2  Serengeti       Natta
# 3  Mahakamani  Mtwara           90             63   Nanyumbu    Nanyumbu
# 4  Kyanyamisa  Kagera           18              1    Karagwe  Nyakasimbi
#
#    population public_meeting              recorded_by scheme_management  \
# 1         280            NaN  GeoData Consultants Ltd             Other
# 3          58           True  GeoData Consultants Ltd               VWC
# 4           0           True  GeoData Consultants Ltd               NaN
#
#   scheme_name permit  construction_year extraction_type extraction_type_group  \
# 1         NaN   True               2010         gravity               gravity
# 3         NaN   True               1986     submersible           submersible
# 4         NaN   True                  0         gravity               gravity
#
#   extraction_type_class management management_group    payment payment_type  \
# 1               gravity        wug       user-group  never pay    never pay
# 3           submersible        vwc       user-group  never pay    never pay
# 4               gravity      other            other  never pay    never pay
#
#   water_quality quality_group      quantity quantity_group  \
# 1          soft          good  insufficient   insufficient
# 3          soft          good           dry            dry
# 4          soft          good      seasonal       seasonal
#
#                  source           source_type source_class  \
# 1  rainwater harvesting  rainwater harvesting      surface
# 3           machine dbh              borehole  groundwater
# 4  rainwater harvesting  rainwater harvesting      surface
#
#                waterpoint_type waterpoint_type_group  target  \
# 1           communal standpipe    communal standpipe       0
# 3  communal standpipe multiple    communal standpipe       1
# 4           communal standpipe    communal standpipe       0
#
#    water_per_person  no_construct_yr
# 1               0.0            False
# 3               0.0            False
# 4               NaN             True

# %%
never_pay['target'].value_counts(normalize=True)
# Out:
# 1    0.475856
# 0    0.448911
# 2    0.075233
# Name: target, dtype: float64

# %% [markdown]
# #### quality_group
# This feature is defined as the quality of the water. The largest category is good which is 85% of the category. There are almost 30,000 wells that have good water that are functional, but there are also almost 20,000 wells that aren't functioning.<br>
# <br>
# This is a crucal factor to work with because the water is considered good and now concentrate on getting the wells working.<br>

# %%
#ax = sns.countplot(x='quality_group', hue="target", data=df_1)
#countplot_w_hue(df_1, col='quality_group', hue_col='target',rot=40)  
feature_w_hue(df_1, col='quality_group', hue_col='target',rot=40)
# Out:
# good        50818
# salty        5195
# unknown      1876
# milky         804
# colored       490
# fluoride      217
# Name: quality_group, dtype: int64
#
#
# good        0.856
# salty       0.087
# unknown     0.032
# milky       0.014
# colored     0.008
# fluoride    0.004
# Name: quality_group, dtype: float64
# ---------------------------------------------

# %% [markdown]
# ### Preprocessing

# %%
"""
Feature contain similar representation of data:
extraction_type
extraction_type_group
extraction_type_class 

(payment, payment_type),

(water_quality, quality_group), 

(source, source_class), 

(subvillage, region, region_code, district_code, lga, ward), 

(waterpoint_type, waterpoint_type_group)  
Risk overfitting our data during training by including all the features in our analysis, which can be dropped.

id can be droped because it is unique for each instance.
num_private is ~99% zeros



"""
print('Features which may be duplicative')
# Out:
# Features which may be duplicative

# %%
"""
some of the features that seemed would impact predcition of whethe wells functions based on intuition. 
amount_tsh (amount of water available to water point)
gps_height, basin, installer, population, scheme_management, construction year, extraction_type, management_group, water_quality, payment type, source, and waterpoint_type seemed like they could be extremely important in identifying the pump status.



"""
# Out:
# '\nsome of the features that seemed would impact predcition of whethe wells functions based on intuition. \namount_tsh (amount of water available to water point)\ngps_height, basin, installer, population, scheme_management, construction year, extraction_type, management_group, water_quality, payment type, source, and waterpoint_type seemed like they could be extremely important in identifying the pump status.\n\n\n\n'

# %% [markdown]
# #### funder
# Column 'funder' is defined as who funded the well.<br>
# Nan values: 3635<br>
# '0': 777<br>
# categories that have unique values of 10 or less: 3001<br>
# <br>
# Categories with unique values of 10 or less were grouped in category titled 'other'<br>

# %%
"""
funder                    1897
installer                 2145


NaN: 3635
'0': 777
"""
df_1['funder'].value_counts(dropna=False)
# Out:
# Government Of Tanzania    9084
# NaN                       3635
# Danida                    3114
# Hesawa                    2202
# Rwssp                     1374
#                           ...
# Noeli Mahobokela             1
# People Of Sweden             1
# Jamal Abdallah               1
# Songa Hospi                  1
# Raramataki                   1
# Name: funder, Length: 1898, dtype: int64

# %%
len(df_1[df_1['funder']== '0'])
# Out:
# 777

# %%
#df_a = df_a.apply(lambda x: x.mask(x.map(x.value_counts())< 10, np.NaN) if x.name=='funder' else x)
#funder
#df_1['funder'].loc[(df_1['funder'] == '0')] = np.NaN
df_1.loc[(df_1['funder'] == '0'),'funder'] = np.NaN

# %%
"""
NaN: 3635
"""
df_1['funder'].value_counts(dropna=False)
# Out:
# Government Of Tanzania          9084
# NaN                             4412
# Danida                          3114
# Hesawa                          2202
# Rwssp                           1374
#                                 ...
# Village Council/ Rose Kawala       1
# People Of Sweden                   1
# Jamal Abdallah                     1
# Songa Hospi                        1
# Raramataki                         1
# Name: funder, Length: 1897, dtype: int64

# %%
df_1[df_1['funder']== '0']
# Out:
# Empty DataFrame
# Columns: [amount_tsh, date_recorded, funder, gps_height, installer, longitude, latitude, wpt_name, num_private, basin, subvillage, region, region_code, district_code, lga, ward, population, public_meeting, recorded_by, scheme_management, scheme_name, permit, construction_year, extraction_type, extraction_type_group, extraction_type_class, management, management_group, payment, payment_type, water_quality, quality_group, quantity, quantity_group, source, source_type, source_class, waterpoint_type, waterpoint_type_group, target, water_per_person, no_construct_yr]
# Index: []

# %%
df_1 = df_1.apply(lambda x: x.mask(x.map(x.value_counts())< 10, 'other') if x.name=='funder' else x)

# %%
df_1['funder'].value_counts(dropna=False)
# Out:
# Government Of Tanzania    9084
# NaN                       4412
# Danida                    3114
# other                     3001
# Hesawa                    2202
#                           ...
# Auwasa                      10
# Tasafu                      10
# De                          10
# Nado                        10
# Millenium                   10
# Name: funder, Length: 407, dtype: int64

# %% [markdown]
# #### installer
# Column 'installer' is defined as the organization that installed the well.<br>
# unique values: 2145<br>
# NaN: 3655<br>
# '0': 777<br>
# <br>
# categories of unique values with a count of 10 or less were grouped in a category called 'other'.<br>

# %%
"""
installer unique: 2145

NaN: 3655
0:   777

"""
df_1['installer'].value_counts(dropna=False)
# Out:
# DWE                       17402
# NaN                        3655
# Government                 1825
# RWE                        1206
# Commu                      1060
#                           ...
# Eastmeru medium School        1
# Mohamed Ally                  1
# wananchi technicians          1
# Luleka                        1
# Others                        1
# Name: installer, Length: 2146, dtype: int64

# %%
len(df_1[df_1['installer']=='0'])
# Out:
# 777

# %%
df_1['installer'].loc[(df_1['installer'] == '0')] = np.NaN

# %%
#pd.set_option('display.max_rows', None)
#counting = df_1['installer'].value_counts()
df_1 = df_1.apply(lambda x: x.mask(x.map(x.value_counts())< 10, 'other') if x.name=='installer' else x)

# %%
df_1['installer'].value_counts()
# Out:
# DWE                 17402
# other                3533
# Government           1825
# RWE                  1206
# Commu                1060
#                     ...
# Maswi                  10
# RUDEP/                 10
# SUWASA                 10
# IDEA                   10
# Ardhi water well       10
# Name: installer, Length: 423, dtype: int64

# %% [markdown]
# #### region / region_code
# region and region_code are essentially the same columns. region_code is numeric.<br>
# NaN: 0

# %%
df_1['region'].value_counts(dropna=False)
# Out:
# Iringa           5294
# Shinyanga        4982
# Mbeya            4639
# Kilimanjaro      4379
# Morogoro         4006
# Arusha           3350
# Kagera           3316
# Mwanza           3102
# Kigoma           2816
# Ruvuma           2640
# Pwani            2635
# Tanga            2547
# Dodoma           2201
# Singida          2093
# Mara             1969
# Tabora           1959
# Rukwa            1808
# Mtwara           1730
# Manyara          1583
# Lindi            1546
# Dar es Salaam     805
# Name: region, dtype: int64

# %%
df_1['region_code'].value_counts(dropna=False)
# Out:
# 11    5300
# 17    5011
# 12    4639
# 3     4379
# 5     4040
# 18    3324
# 19    3047
# 2     3024
# 16    2816
# 10    2640
# 4     2513
# 1     2201
# 13    2093
# 14    1979
# 20    1969
# 15    1808
# 6     1609
# 21    1583
# 80    1238
# 60    1025
# 90     917
# 7      805
# 99     423
# 9      390
# 24     326
# 8      300
# 40       1
# Name: region_code, dtype: int64

# %% [markdown]
# #### scheme_managemnt / scheme_name
# scheme_management : Who operates the waterpoint<br>
# scheme_name : Who operates the waterpoint<br>

# %%
"""
scheme_management           12
scheme_name               2696

NaN: 3877
"""
df_1['scheme_management'].value_counts(dropna=False)
# Out:
# VWC                 36793
# WUG                  5206
# NaN                  3877
# Water authority      3153
# WUA                  2883
# Water Board          2748
# Parastatal           1680
# Private operator     1063
# Company              1061
# Other                 766
# SWC                    97
# Trust                  72
# None                    1
# Name: scheme_management, dtype: int64

# %%
df_1['scheme_name'].value_counts(dropna=False)
# Out:
# NaN                           28166
# K                               682
# None                            644
# Borehole                        546
# Chalinze wate                   405
#                               ...
# Ushara lawate water supply        1
# Matiganjola hydram Scheme         1
# water supply in Mwanza            1
# Nguj                              1
# Kwawameku water suply             1
# Name: scheme_name, Length: 2697, dtype: int64

# %%
df_1.loc[df_1['scheme_name']== '0']
# Out:
# Empty DataFrame
# Columns: [amount_tsh, date_recorded, funder, gps_height, installer, longitude, latitude, wpt_name, num_private, basin, subvillage, region, region_code, district_code, lga, ward, population, public_meeting, recorded_by, scheme_management, scheme_name, permit, construction_year, extraction_type, extraction_type_group, extraction_type_class, management, management_group, payment, payment_type, water_quality, quality_group, quantity, quantity_group, source, source_type, source_class, waterpoint_type, waterpoint_type_group, target, water_per_person, no_construct_yr]
# Index: []

# %% [markdown]
# #### extraction_type / extraction_type_group / extraction_type_class
# Defined as The kind of extraction the waterpoint uses.

# %%
"""
extraction_type        59400 non-null  object 
extraction_type_group  59400 non-null  object 
extraction_type_class  59400 non-null  object 

"""
df_1['extraction_type'].value_counts(dropna=False)
# Out:
# gravity                      26780
# nira/tanira                   8154
# other                         6430
# submersible                   4764
# swn 80                        3670
# mono                          2865
# india mark ii                 2400
# afridev                       1770
# ksb                           1415
# other - rope pump              451
# other - swn 81                 229
# windmill                       117
# india mark iii                  98
# cemo                            90
# other - play pump               85
# walimi                          48
# climax                          32
# other - mkulima/shinyanga        2
# Name: extraction_type, dtype: int64

# %%
df_1['extraction_type_group'].value_counts(dropna=False)
# Out:
# gravity            26780
# nira/tanira         8154
# other               6430
# submersible         6179
# swn 80              3670
# mono                2865
# india mark ii       2400
# afridev             1770
# rope pump            451
# other handpump       364
# other motorpump      122
# wind-powered         117
# india mark iii        98
# Name: extraction_type_group, dtype: int64

# %%
df_1['extraction_type_class'].value_counts(dropna=False)
# Out:
# gravity         26780
# handpump        16456
# other            6430
# submersible      6179
# motorpump        2987
# rope pump         451
# wind-powered      117
# Name: extraction_type_class, dtype: int64

# %%
# #problems: 'scheme_management','lga'
# cols = ['amount_tsh','longitude','latitude','num_private','basin','region','district_code','population',
#         'public_meeting','recorded_by','permit','construction_year','extraction_type_group','management','management_group','payment',
#         'payment_type', 'quality_group','quantity','source','waterpoint_type','target']   
# data_df = df_1[cols]

# %% [markdown]
# #### managmeent / management_group

# %%
df_1['management'].value_counts(dropna=False)
# Out:
# vwc                 40507
# wug                  6515
# water board          2933
# wua                  2535
# private operator     1971
# parastatal           1768
# water authority       904
# other                 844
# company               685
# unknown               561
# other - school         99
# trust                  78
# Name: management, dtype: int64

# %%
"""
NaN: 0
"""
df_1['management_group'].value_counts(dropna=False)
# Out:
# user-group    52490
# commercial     3638
# parastatal     1768
# other           943
# unknown         561
# Name: management_group, dtype: int64

# %% [markdown]
# #### payment / payment_type

# %%
df_1['payment'].value_counts(dropna=False)
# Out:
# never pay                25348
# pay per bucket            8985
# pay monthly               8300
# unknown                   8157
# pay when scheme fails     3914
# pay annually              3642
# other                     1054
# Name: payment, dtype: int64

# %%
df_1['payment_type'].value_counts(dropna=False)
# Out:
# never pay     25348
# per bucket     8985
# monthly        8300
# unknown        8157
# on failure     3914
# annually       3642
# other          1054
# Name: payment_type, dtype: int64

# %% [markdown]
# #### water_quality / quality_group
# Both columns are defined as the quality of the water. Both columns have an category 'unknown' which constitutes 3% of the feature.<br>
# I kept quality_group becuase it more specifically defines water quality.

# %%
df_1['water_quality'].value_counts(normalize=True)
# Out:
# soft                  0.855522
# salty                 0.081751
# unknown               0.031582
# milky                 0.013535
# coloured              0.008249
# salty abandoned       0.005707
# fluoride              0.003367
# fluoride abandoned    0.000286
# Name: water_quality, dtype: float64

# %%
df_1['quality_group'].value_counts(dropna=False)
# Out:
# good        50818
# salty        5195
# unknown      1876
# milky         804
# colored       490
# fluoride      217
# Name: quality_group, dtype: int64

# %% [markdown]
# #### quantity / quantity_group
# Both columns are defined as the quantity of water.  The columns are duplicative.  I kept the column 'quantity'.

# %%
df_1['quantity'].value_counts(dropna=False)
# Out:
# enough          33186
# insufficient    15129
# dry              6246
# seasonal         4050
# unknown           789
# Name: quantity, dtype: int64

# %%
df_1['quantity_group'].value_counts(dropna=False)
# Out:
# enough          33186
# insufficient    15129
# dry              6246
# seasonal         4050
# unknown           789
# Name: quantity_group, dtype: int64

# %% [markdown]
# #### source / source_type / source_class
# Columns 'source', 'source_type' and 'source_class' are  defined as the source of the water.<br>
# Only keep 'source' b/c it includes the categories of hte others.<br>

# %%
"""
source : The source of the water
source_type : The source of the water
source_class : The source of the water

"""
df_1['source'].value_counts(dropna=False)
# Out:
# spring                  17021
# shallow well            16824
# machine dbh             11075
# river                    9612
# rainwater harvesting     2295
# hand dtw                  874
# lake                      765
# dam                       656
# other                     212
# unknown                    66
# Name: source, dtype: int64

# %%
df_1['source_type'].value_counts(dropna=False)
# Out:
# spring                  17021
# shallow well            16824
# borehole                11949
# river/lake              10377
# rainwater harvesting     2295
# dam                       656
# other                     278
# Name: source_type, dtype: int64

# %%
df_1['source_class'].value_counts(dropna=False)
# Out:
# groundwater    45794
# surface        13328
# unknown          278
# Name: source_class, dtype: int64

# %% [markdown]
# #### waterpoint_type / waterpoint_type_group
# Both columns 'waterpoint_type' and 'waterpoint_type_group' are defined as the kind of waterpoint.  Both columns appear to be duplicative.  I am keeping waterpoint_type because it breaks down the categories a little more.<br>

# %%
"""
waterpoint_type              7
waterpoint_type_group        6
"""
df_1['waterpoint_type'].value_counts(dropna=False)
# Out:
# communal standpipe             28522
# hand pump                      17488
# other                           6380
# communal standpipe multiple     6103
# improved spring                  784
# cattle trough                    116
# dam                                7
# Name: waterpoint_type, dtype: int64

# %%
df_1['waterpoint_type_group'].value_counts(dropna=False)
# Out:
# communal standpipe    34625
# hand pump             17488
# other                  6380
# improved spring         784
# cattle trough           116
# dam                       7
# Name: waterpoint_type_group, dtype: int64

# %%
df_1['longitude'].value_counts(dropna=False)
# Out:
# 0.000000     1812
# 37.540901       2
# 33.010510       2
# 39.093484       2
# 32.972719       2
#              ...
# 37.579803       1
# 33.196490       1
# 34.017119       1
# 33.788326       1
# 30.163579       1
# Name: longitude, Length: 57516, dtype: int64

# %%
df_2 = df_1.copy()

# %%
"""
amount_tsh : Total static head (amount water available to waterpoint)
features['water/person'] = features['amount_tsh'] / features['population']
"""
#df_2['water/person'] = df_2['amount_tsh'] / df_2['population']
# Out:
# "\namount_tsh : Total static head (amount water available to waterpoint)\nfeatures['water/person'] = features['amount_tsh'] / features['population']\n"

# %%
df_2.head()
# Out:
#    amount_tsh date_recorded   funder  gps_height     installer  longitude  \
# 0      6000.0    2011-03-14    Roman        1390         Roman  34.938093
# 1         0.0    2013-03-06  Grumeti        1399       GRUMETI  34.698766
# 2        25.0    2013-02-25    other         686  World vision  37.460664
# 3         0.0    2013-01-28   Unicef         263        UNICEF  38.486161
# 4         0.0    2011-07-13    other           0       Artisan  31.130847
#
#     latitude              wpt_name  num_private                    basin  \
# 0  -9.856322                  none            0               Lake Nyasa
# 1  -2.147466              Zahanati            0            Lake Victoria
# 2  -3.821329           Kwa Mahundi            0                  Pangani
# 3 -11.155298  Zahanati Ya Nanyumbu            0  Ruvuma / Southern Coast
# 4  -1.825359               Shuleni            0            Lake Victoria
#
#    subvillage   region  region_code  district_code        lga        ward  \
# 0    Mnyusi B   Iringa           11              5     Ludewa    Mundindi
# 1     Nyamara     Mara           20              2  Serengeti       Natta
# 2     Majengo  Manyara           21              4  Simanjiro     Ngorika
# 3  Mahakamani   Mtwara           90             63   Nanyumbu    Nanyumbu
# 4  Kyanyamisa   Kagera           18              1    Karagwe  Nyakasimbi
#
#    population public_meeting              recorded_by scheme_management  \
# 0         109           True  GeoData Consultants Ltd               VWC
# 1         280            NaN  GeoData Consultants Ltd             Other
# 2         250           True  GeoData Consultants Ltd               VWC
# 3          58           True  GeoData Consultants Ltd               VWC
# 4           0           True  GeoData Consultants Ltd               NaN
#
#                    scheme_name permit  construction_year extraction_type  \
# 0                        Roman  False               1999         gravity
# 1                          NaN   True               2010         gravity
# 2  Nyumba ya mungu pipe scheme   True               2009         gravity
# 3                          NaN   True               1986     submersible
# 4                          NaN   True                  0         gravity
#
#   extraction_type_group extraction_type_class management management_group  \
# 0               gravity               gravity        vwc       user-group
# 1               gravity               gravity        wug       user-group
# 2               gravity               gravity        vwc       user-group
# 3           submersible           submersible        vwc       user-group
# 4               gravity               gravity      other            other
#
#           payment payment_type water_quality quality_group      quantity  \
# 0    pay annually     annually          soft          good        enough
# 1       never pay    never pay          soft          good  insufficient
# 2  pay per bucket   per bucket          soft          good        enough
# 3       never pay    never pay          soft          good           dry
# 4       never pay    never pay          soft          good      seasonal
#
#   quantity_group                source           source_type source_class  \
# 0         enough                spring                spring  groundwater
# 1   insufficient  rainwater harvesting  rainwater harvesting      surface
# 2         enough                   dam                   dam      surface
# 3            dry           machine dbh              borehole  groundwater
# 4       seasonal  rainwater harvesting  rainwater harvesting      surface
#
#                waterpoint_type waterpoint_type_group  target  \
# 0           communal standpipe    communal standpipe       0
# 1           communal standpipe    communal standpipe       0
# 2  communal standpipe multiple    communal standpipe       0
# 3  communal standpipe multiple    communal standpipe       1
# 4           communal standpipe    communal standpipe       0
#
#    water_per_person  no_construct_yr
# 0         55.045872            False
# 1          0.000000            False
# 2          0.100000            False
# 3          0.000000            False
# 4               NaN             True

# %%
#problems: 'scheme_management','lga'
cols = ['amount_tsh','longitude','latitude','num_private','basin','region','district_code','population',
        'public_meeting','recorded_by','permit','construction_year','extraction_type_group','management','management_group','payment',
        'payment_type', 'quality_group','quantity','source','waterpoint_type','no_construct_yr','target']   
data_df = df_1[cols]

# %% [markdown]
# #### Train Test Split

# %%
from sklearn.model_selection import train_test_split

# %%
y = data_df['target']
X = data_df.drop('target',axis=1)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size= 0.25, random_state=42)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (44550, 22)
# (44550,)
# (14850, 22)
# (14850,)

# %% [markdown]
# #### Address Null Values

# %%
from sklearn.impute import SimpleImputer

# %%
nan_values.index
# Out:
# Index(['funder', 'installer', 'subvillage', 'public_meeting',
#        'scheme_management', 'scheme_name', 'permit'],
#       dtype='object')

# %%
nan_col = ['public_meeting', 'permit']
X_train_nan = X_train[nan_col]
X_test_nan = X_test[nan_col]

# %%
from sklearn.impute import SimpleImputer

def remake(X_train_cln,X_train):
       return pd.DataFrame(X_train_cln,columns=X_train.columns, index=X_train.index)

def impute(X_train, X_test):
    imputer = SimpleImputer(strategy='most_frequent')
    X_train_cln = remake(imputer.fit_transform(X_train), X_train) #remake function
    X_test_cln = remake(imputer.transform(X_test ), X_test)
    X_test_cln
    #X_train_cln = X_train_cln.astype(float)
    #X_test_cln = X_test_cln.astype(float)
    
    return X_train_cln, X_test_cln

# %%
X_train_cln, X_test_cln = impute(X_train_nan,X_test_nan)

# %%
# X_train_cln.head()

# %%
X_train.isna().sum()
# Out:
# amount_tsh                  0
# longitude                   0
# latitude                    0
# num_private                 0
# basin                       0
# region                      0
# district_code               0
# population                  0
# public_meeting           2525
# recorded_by                 0
# permit                   2285
# construction_year           0
# extraction_type_group       0
# management                  0
# management_group            0
# payment                     0
# payment_type                0
# quality_group               0
# quantity                    0
# source                      0
# waterpoint_type             0
# no_construct_yr             0
# dtype: int64

# %%
X_train.shape, X_test.shape
# Out:
# ((44550, 22), (14850, 22))

# %%
X_train_no_nan = X_train.drop(nan_col, axis=1)
X_test_no_nan = X_test.drop(nan_col, axis=1)

# %%
"""
(44550, 29)
(44550,)
(14850, 29)
(14850,)

"""

# print(X_train_no_nan.shape)
# print(y_train.shape)
# print(X_test_no_nan.shape)
# print(y_test.shape)
# Out:
# '\n(44550, 29)\n(44550,)\n(14850, 29)\n(14850,)\n\n'

# %%
X_train_1 = pd.concat([X_train_no_nan,X_train_cln],axis=1)
X_test_1 = pd.concat([X_test_no_nan,X_test_cln],axis=1)

# %%
# print(X_train_1.shape)
# print(X_test_1.shape)

# %%
#X_train_1.head()

# %%
#X_test_1.isna().sum()

# %%
print(count_null(X_train_1))
print(dashes)
print(count_null(X_test_1))
# Out:
# No nulls
# Series([], dtype: float64)
# ------------------------------------------------------------
# No nulls
# Series([], dtype: float64)

# %% [markdown]
# #### One-Hot Encode Categoricals

# %%
X_train_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 44550 entries, 24947 to 56422
# Data columns (total 22 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   amount_tsh             44550 non-null  float64
#  1   longitude              44550 non-null  float64
#  2   latitude               44550 non-null  float64
#  3   num_private            44550 non-null  int64
#  4   basin                  44550 non-null  object
#  5   region                 44550 non-null  object
#  6   district_code          44550 non-null  int64
#  7   population             44550 non-null  int64
#  8   recorded_by            44550 non-null  object
#  9   construction_year      44550 non-null  int64
#  10  extraction_type_group  44550 non-null  object
#  11  management             44550 non-null  object
#  12  management_group       44550 non-null  object
#  13  payment                44550 non-null  object
#  14  payment_type           44550 non-null  object
#  15  quality_group          44550 non-null  object
#  16  quantity               44550 non-null  object
#  17  source                 44550 non-null  object
#  18  waterpoint_type        44550 non-null  object
#  19  no_construct_yr        44550 non-null  bool
#  20  public_meeting         44550 non-null  object
#  21  permit                 44550 non-null  object
# dtypes: bool(1), float64(3), int64(4), object(14)
# memory usage: 7.5+ MB

# %%
cat_cols = X_train_1.select_dtypes('O')
cat_cols.head()
# Out:
#                basin   region              recorded_by extraction_type_group  \
# 24947    Wami / Ruvu    Pwani  GeoData Consultants Ltd           submersible
# 22630  Lake Victoria   Mwanza  GeoData Consultants Ltd           nira/tanira
# 13789  Lake Victoria   Mwanza  GeoData Consultants Ltd         india mark ii
# 15697       Internal  Singida  GeoData Consultants Ltd               gravity
# 22613     Lake Nyasa   Ruvuma  GeoData Consultants Ltd               gravity
#
#       management management_group         payment payment_type quality_group  \
# 24947        vwc       user-group  pay per bucket   per bucket         salty
# 22630        wug       user-group         unknown      unknown          good
# 13789        vwc       user-group       never pay    never pay          good
# 15697        wua       user-group       never pay    never pay          good
# 22613        vwc       user-group         unknown      unknown          good
#
#            quantity                source     waterpoint_type public_meeting  \
# 24947  insufficient           machine dbh  communal standpipe           True
# 22630        enough          shallow well           hand pump           True
# 13789        enough           machine dbh           hand pump           True
# 15697      seasonal  rainwater harvesting  communal standpipe           True
# 22613           dry                spring  communal standpipe           True
#
#       permit
# 24947   True
# 22630  False
# 13789   True
# 15697   True
# 22613   True

# %%
#len(cat_cols.columns)

# %%
num_cols = X_train_1.select_dtypes('number')
len(num_cols.columns)
# Out:
# 7

# %%
cat_cols.columns
# Out:
# Index(['basin', 'region', 'recorded_by', 'extraction_type_group', 'management',
#        'management_group', 'payment', 'payment_type', 'quality_group',
#        'quantity', 'source', 'waterpoint_type', 'public_meeting', 'permit'],
#       dtype='object')

# %%
#'region','region_code','district_code'

cols_hot = ['basin', 'region', 'recorded_by', 'extraction_type_group',
       'management', 'management_group', 'payment',
       'payment_type', 'quality_group', 'quantity',
       'source', 'waterpoint_type', 'public_meeting', 'permit','no_construct_yr']

def one_hot(df_train, df_test, columns=cols_hot):
    one_hot_train = pd.get_dummies(df_train, columns=cols_hot, drop_first=True)
    one_hot_test = pd.get_dummies(df_test, columns=cols_hot, drop_first=True)
    
    return one_hot_train, one_hot_test

# %%
one_hot_train, one_hot_test = one_hot(X_train, X_test, cols_hot)

# %%
one_hot_train.shape, one_hot_test.shape
# Out:
# ((44550, 101), (14850, 101))

# %% [markdown]
# #### Scale Data

# %%
from sklearn.preprocessing import StandardScaler

# %%
def scale_data(sscaler, X_train_int, X_test_int,y_train):
    #scaler = sscaler
    #transform the training and test sets
    scaled_data_train = sscaler.fit_transform(X_train_int, y_train)
    scaled_data_test = sscaler.transform(X_test_int)
    #convert into a dataframe
    scaled_df_tra = pd.DataFrame(scaled_data_train, columns=X_train_int.columns)
    scaled_df_tes = pd.DataFrame(scaled_data_test, columns=X_test_int.columns)
    
    return scaled_df_tra, scaled_df_tes

# %%
train_scale, test_scale = scale_data(StandardScaler(),  one_hot_train, one_hot_test,y_train)

# %%
train_scale.shape, test_scale.shape
# Out:
# ((44550, 101), (14850, 101))

# %%
train_scale.head()
# Out:
#    amount_tsh  longitude  latitude  num_private  district_code  population  \
# 0   -0.093074   0.616411 -0.129019    -0.037802      -0.479998   -0.209732
# 1   -0.099150  -5.221778  1.940133    -0.037802      -0.479998   -0.379567
# 2   -0.099150  -0.120413  0.983559    -0.037802      -0.170408   -0.379567
# 3   -0.099150   0.104811  0.294199    -0.037802      -0.170408   -0.330739
# 4   -0.099150   0.086112 -1.699526    -0.037802      -0.273604   -0.377444
#
#    construction_year  basin_Lake Nyasa  basin_Lake Rukwa  \
# 0           0.702954         -0.302772         -0.209144
# 1          -1.371444         -0.302772         -0.209144
# 2          -1.371444         -0.302772         -0.209144
# 3           0.742927         -0.302772         -0.209144
# 4           0.746083          3.302814         -0.209144
#
#    basin_Lake Tanganyika  basin_Lake Victoria  basin_Pangani  basin_Rufiji  \
# 0              -0.349442            -0.455788      -0.420435     -0.393527
# 1              -0.349442             2.194003      -0.420435     -0.393527
# 2              -0.349442             2.194003      -0.420435     -0.393527
# 3              -0.349442            -0.455788      -0.420435     -0.393527
# 4              -0.349442            -0.455788      -0.420435     -0.393527
#
#    basin_Ruvuma / Southern Coast  basin_Wami / Ruvu  region_Dar es Salaam  \
# 0                      -0.287445           2.976669             -0.118313
# 1                      -0.287445          -0.335946             -0.118313
# 2                      -0.287445          -0.335946             -0.118313
# 3                      -0.287445          -0.335946             -0.118313
# 4                      -0.287445          -0.335946             -0.118313
#
#    region_Dodoma  region_Iringa  region_Kagera  region_Kigoma  \
# 0      -0.196301      -0.313688      -0.243158      -0.222307
# 1      -0.196301      -0.313688      -0.243158      -0.222307
# 2      -0.196301      -0.313688      -0.243158      -0.222307
# 3      -0.196301      -0.313688      -0.243158      -0.222307
# 4      -0.196301      -0.313688      -0.243158      -0.222307
#
#    region_Kilimanjaro  region_Lindi  region_Manyara  region_Mara  \
# 0           -0.280103     -0.165019       -0.166236    -0.185695
# 1           -0.280103     -0.165019       -0.166236    -0.185695
# 2           -0.280103     -0.165019       -0.166236    -0.185695
# 3           -0.280103     -0.165019       -0.166236    -0.185695
# 4           -0.280103     -0.165019       -0.166236    -0.185695
#
#    region_Mbeya  region_Morogoro  region_Mtwara  region_Mwanza  region_Pwani  \
# 0     -0.288222        -0.269328      -0.173372      -0.234014       4.63436
# 1     -0.288222        -0.269328      -0.173372       4.273254      -0.21578
# 2     -0.288222        -0.269328      -0.173372       4.273254      -0.21578
# 3     -0.288222        -0.269328      -0.173372      -0.234014      -0.21578
# 4     -0.288222        -0.269328      -0.173372      -0.234014      -0.21578
#
#    region_Rukwa  region_Ruvuma  region_Shinyanga  region_Singida  \
# 0     -0.178458      -0.214580         -0.302551       -0.191188
# 1     -0.178458      -0.214580         -0.302551       -0.191188
# 2     -0.178458      -0.214580         -0.302551       -0.191188
# 3     -0.178458      -0.214580         -0.302551        5.230462
# 4     -0.178458       4.660258         -0.302551       -0.191188
#
#    region_Tabora  region_Tanga  extraction_type_group_gravity  \
# 0      -0.185889     -0.212454                      -0.901196
# 1      -0.185889     -0.212454                      -0.901196
# 2      -0.185889     -0.212454                      -0.901196
# 3      -0.185889     -0.212454                       1.109637
# 4      -0.185889     -0.212454                       1.109637
#
#    extraction_type_group_india mark ii  extraction_type_group_india mark iii  \
# 0                            -0.205730                              -0.03793
# 1                            -0.205730                              -0.03793
# 2                             4.860747                              -0.03793
# 3                            -0.205730                              -0.03793
# 4                            -0.205730                              -0.03793
#
#    extraction_type_group_mono  extraction_type_group_nira/tanira  \
# 0                   -0.225183                          -0.401025
# 1                   -0.225183                           2.493608
# 2                   -0.225183                          -0.401025
# 3                   -0.225183                          -0.401025
# 4                   -0.225183                          -0.401025
#
#    extraction_type_group_other  extraction_type_group_other handpump  \
# 0                    -0.348471                             -0.078955
# 1                    -0.348471                             -0.078955
# 2                    -0.348471                             -0.078955
# 3                    -0.348471                             -0.078955
# 4                    -0.348471                             -0.078955
#
#    extraction_type_group_other motorpump  extraction_type_group_rope pump  \
# 0                              -0.045737                        -0.089242
# 1                              -0.045737                        -0.089242
# 2                              -0.045737                        -0.089242
# 3                              -0.045737                        -0.089242
# 4                              -0.045737                        -0.089242
#
#    extraction_type_group_submersible  extraction_type_group_swn 80  \
# 0                           2.921563                     -0.256991
# 1                          -0.342283                     -0.256991
# 2                          -0.342283                     -0.256991
# 3                          -0.342283                     -0.256991
# 4                          -0.342283                     -0.256991
#
#    extraction_type_group_wind-powered  management_other  \
# 0                           -0.042679         -0.120441
# 1                           -0.042679         -0.120441
# 2                           -0.042679         -0.120441
# 3                           -0.042679         -0.120441
# 4                           -0.042679         -0.120441
#
#    management_other - school  management_parastatal  \
# 0                  -0.042148              -0.174194
# 1                  -0.042148              -0.174194
# 2                  -0.042148              -0.174194
# 3                  -0.042148              -0.174194
# 4                  -0.042148              -0.174194
#
#    management_private operator  management_trust  management_unknown  \
# 0                    -0.185307         -0.036724           -0.099185
# 1                    -0.185307         -0.036724           -0.099185
# 2                    -0.185307         -0.036724           -0.099185
# 3                    -0.185307         -0.036724           -0.099185
# 4                    -0.185307         -0.036724           -0.099185
#
#    management_vwc  management_water authority  management_water board  \
# 0        0.681752                   -0.123941                -0.22661
# 1       -1.466809                   -0.123941                -0.22661
# 2        0.681752                   -0.123941                -0.22661
# 3       -1.466809                   -0.123941                -0.22661
# 4        0.681752                   -0.123941                -0.22661
#
#    management_wua  management_wug  management_group_other  \
# 0       -0.211876       -0.351058               -0.127806
# 1       -0.211876        2.848536               -0.127806
# 2       -0.211876       -0.351058               -0.127806
# 3        4.719731       -0.351058               -0.127806
# 4       -0.211876       -0.351058               -0.127806
#
#    management_group_parastatal  management_group_unknown  \
# 0                    -0.174194                 -0.099185
# 1                    -0.174194                 -0.099185
# 2                    -0.174194                 -0.099185
# 3                    -0.174194                 -0.099185
# 4                    -0.174194                 -0.099185
#
#    management_group_user-group  payment_other  payment_pay annually  \
# 0                     0.361857      -0.134188             -0.254501
# 1                     0.361857      -0.134188             -0.254501
# 2                     0.361857      -0.134188             -0.254501
# 3                     0.361857      -0.134188             -0.254501
# 4                     0.361857      -0.134188             -0.254501
#
#    payment_pay monthly  payment_pay per bucket  payment_pay when scheme fails  \
# 0            -0.399969                2.360664                      -0.266779
# 1            -0.399969               -0.423610                      -0.266779
# 2            -0.399969               -0.423610                      -0.266779
# 3            -0.399969               -0.423610                      -0.266779
# 4            -0.399969               -0.423610                      -0.266779
#
#    payment_unknown  payment_type_monthly  payment_type_never pay  \
# 0        -0.398608             -0.399969               -0.864801
# 1         2.508727             -0.399969               -0.864801
# 2        -0.398608             -0.399969                1.156335
# 3        -0.398608             -0.399969                1.156335
# 4         2.508727             -0.399969               -0.864801
#
#    payment_type_on failure  payment_type_other  payment_type_per bucket  \
# 0                -0.266779           -0.134188                 2.360664
# 1                -0.266779           -0.134188                -0.423610
# 2                -0.266779           -0.134188                -0.423610
# 3                -0.266779           -0.134188                -0.423610
# 4                -0.266779           -0.134188                -0.423610
#
#    payment_type_unknown  quality_group_fluoride  quality_group_good  \
# 0             -0.398608               -0.062256           -2.422528
# 1              2.508727               -0.062256            0.412792
# 2             -0.398608               -0.062256            0.412792
# 3             -0.398608               -0.062256            0.412792
# 4              2.508727               -0.062256            0.412792
#
#    quality_group_milky  quality_group_salty  quality_group_unknown  \
# 0              -0.1188             3.218090              -0.179992
# 1              -0.1188            -0.310743              -0.179992
# 2              -0.1188            -0.310743              -0.179992
# 3              -0.1188            -0.310743              -0.179992
# 4              -0.1188            -0.310743              -0.179992
#
#    quantity_enough  quantity_insufficient  quantity_seasonal  \
# 0        -1.124921               1.711914          -0.269376
# 1         0.888952              -0.584141          -0.269376
# 2         0.888952              -0.584141          -0.269376
# 3        -1.124921              -0.584141           3.712280
# 4        -1.124921              -0.584141          -0.269376
#
#    quantity_unknown  source_hand dtw  source_lake  source_machine dbh  \
# 0          -0.11595        -0.122628    -0.113743            2.085065
# 1          -0.11595        -0.122628    -0.113743           -0.479601
# 2          -0.11595        -0.122628    -0.113743            2.085065
# 3          -0.11595        -0.122628    -0.113743           -0.479601
# 4          -0.11595        -0.122628    -0.113743           -0.479601
#
#    source_other  source_rainwater harvesting  source_river  \
# 0     -0.062437                    -0.199242     -0.439821
# 1     -0.062437                    -0.199242     -0.439821
# 2     -0.062437                    -0.199242     -0.439821
# 3     -0.062437                     5.019011     -0.439821
# 4     -0.062437                    -0.199242     -0.439821
#
#    source_shallow well  source_spring  source_unknown  \
# 0            -0.630801      -0.630975       -0.034185
# 1             1.585285      -0.630975       -0.034185
# 2            -0.630801      -0.630975       -0.034185
# 3            -0.630801      -0.630975       -0.034185
# 4            -0.630801       1.584849       -0.034185
#
#    waterpoint_type_communal standpipe  \
# 0                            1.042285
# 1                           -0.959431
# 2                           -0.959431
# 3                            1.042285
# 4                            1.042285
#
#    waterpoint_type_communal standpipe multiple  waterpoint_type_dam  \
# 0                                    -0.336484            -0.008206
# 1                                    -0.336484            -0.008206
# 2                                    -0.336484            -0.008206
# 3                                    -0.336484            -0.008206
# 4                                    -0.336484            -0.008206
#
#    waterpoint_type_hand pump  waterpoint_type_improved spring  \
# 0                  -0.648606                        -0.116644
# 1                   1.541767                        -0.116644
# 2                   1.541767                        -0.116644
# 3                  -0.648606                        -0.116644
# 4                  -0.648606                        -0.116644
#
#    waterpoint_type_other  public_meeting_True  permit_True  \
# 0              -0.346889             0.408462     0.729442
# 1              -0.346889            -2.448208    -1.370910
# 2              -0.346889             0.408462     0.729442
# 3              -0.346889             0.408462     0.729442
# 4              -0.346889            -2.448208     0.729442
#
#    no_construct_yr_True
# 0             -0.729117
# 1              1.371521
# 2              1.371521
# 3             -0.729117
# 4             -0.729117

# %% [markdown]
# #### Imbalance

# %%
from imblearn.over_sampling import SMOTE

# %%
def smote_resample(y, X_train, y_train):
    # Previous original class distribution
    print('Original class distribution: \n')
    print(y.value_counts())
    smote = SMOTE()
    X_train_resampled, y_train_resampled = smote.fit_sample(X_train, y_train) 
    # Preview synthetic sample class distribution
    print('-----------------------------------------')
    print('Synthetic sample class distribution: \n')
    print(pd.Series(y_train_resampled).value_counts()) 
    
    return X_train_resampled, y_train_resampled

# %%
train_resampled, y_train_resampled = smote_resample(y, train_scale, y_train)
# Out:
# Original class distribution:
#
# 0    32259
# 1    22824
# 2     4317
# Name: target, dtype: int64
# -----------------------------------------
# Synthetic sample class distribution:
#
# 2    24161
# 1    24161
# 0    24161
# Name: target, dtype: int64

# %%
#df_1['lga'].value_counts(dropna=False)
train_resampled.head()
# Out:
#    amount_tsh  longitude  latitude  num_private  district_code  population  \
# 0   -0.093074   0.616411 -0.129019    -0.037802      -0.479998   -0.209732
# 1   -0.099150  -5.221778  1.940133    -0.037802      -0.479998   -0.379567
# 2   -0.099150  -0.120413  0.983559    -0.037802      -0.170408   -0.379567
# 3   -0.099150   0.104811  0.294199    -0.037802      -0.170408   -0.330739
# 4   -0.099150   0.086112 -1.699526    -0.037802      -0.273604   -0.377444
#
#    construction_year  basin_Lake Nyasa  basin_Lake Rukwa  \
# 0           0.702954         -0.302772         -0.209144
# 1          -1.371444         -0.302772         -0.209144
# 2          -1.371444         -0.302772         -0.209144
# 3           0.742927         -0.302772         -0.209144
# 4           0.746083          3.302814         -0.209144
#
#    basin_Lake Tanganyika  basin_Lake Victoria  basin_Pangani  basin_Rufiji  \
# 0              -0.349442            -0.455788      -0.420435     -0.393527
# 1              -0.349442             2.194003      -0.420435     -0.393527
# 2              -0.349442             2.194003      -0.420435     -0.393527
# 3              -0.349442            -0.455788      -0.420435     -0.393527
# 4              -0.349442            -0.455788      -0.420435     -0.393527
#
#    basin_Ruvuma / Southern Coast  basin_Wami / Ruvu  region_Dar es Salaam  \
# 0                      -0.287445           2.976669             -0.118313
# 1                      -0.287445          -0.335946             -0.118313
# 2                      -0.287445          -0.335946             -0.118313
# 3                      -0.287445          -0.335946             -0.118313
# 4                      -0.287445          -0.335946             -0.118313
#
#    region_Dodoma  region_Iringa  region_Kagera  region_Kigoma  \
# 0      -0.196301      -0.313688      -0.243158      -0.222307
# 1      -0.196301      -0.313688      -0.243158      -0.222307
# 2      -0.196301      -0.313688      -0.243158      -0.222307
# 3      -0.196301      -0.313688      -0.243158      -0.222307
# 4      -0.196301      -0.313688      -0.243158      -0.222307
#
#    region_Kilimanjaro  region_Lindi  region_Manyara  region_Mara  \
# 0           -0.280103     -0.165019       -0.166236    -0.185695
# 1           -0.280103     -0.165019       -0.166236    -0.185695
# 2           -0.280103     -0.165019       -0.166236    -0.185695
# 3           -0.280103     -0.165019       -0.166236    -0.185695
# 4           -0.280103     -0.165019       -0.166236    -0.185695
#
#    region_Mbeya  region_Morogoro  region_Mtwara  region_Mwanza  region_Pwani  \
# 0     -0.288222        -0.269328      -0.173372      -0.234014       4.63436
# 1     -0.288222        -0.269328      -0.173372       4.273254      -0.21578
# 2     -0.288222        -0.269328      -0.173372       4.273254      -0.21578
# 3     -0.288222        -0.269328      -0.173372      -0.234014      -0.21578
# 4     -0.288222        -0.269328      -0.173372      -0.234014      -0.21578
#
#    region_Rukwa  region_Ruvuma  region_Shinyanga  region_Singida  \
# 0     -0.178458      -0.214580         -0.302551       -0.191188
# 1     -0.178458      -0.214580         -0.302551       -0.191188
# 2     -0.178458      -0.214580         -0.302551       -0.191188
# 3     -0.178458      -0.214580         -0.302551        5.230462
# 4     -0.178458       4.660258         -0.302551       -0.191188
#
#    region_Tabora  region_Tanga  extraction_type_group_gravity  \
# 0      -0.185889     -0.212454                      -0.901196
# 1      -0.185889     -0.212454                      -0.901196
# 2      -0.185889     -0.212454                      -0.901196
# 3      -0.185889     -0.212454                       1.109637
# 4      -0.185889     -0.212454                       1.109637
#
#    extraction_type_group_india mark ii  extraction_type_group_india mark iii  \
# 0                            -0.205730                              -0.03793
# 1                            -0.205730                              -0.03793
# 2                             4.860747                              -0.03793
# 3                            -0.205730                              -0.03793
# 4                            -0.205730                              -0.03793
#
#    extraction_type_group_mono  extraction_type_group_nira/tanira  \
# 0                   -0.225183                          -0.401025
# 1                   -0.225183                           2.493608
# 2                   -0.225183                          -0.401025
# 3                   -0.225183                          -0.401025
# 4                   -0.225183                          -0.401025
#
#    extraction_type_group_other  extraction_type_group_other handpump  \
# 0                    -0.348471                             -0.078955
# 1                    -0.348471                             -0.078955
# 2                    -0.348471                             -0.078955
# 3                    -0.348471                             -0.078955
# 4                    -0.348471                             -0.078955
#
#    extraction_type_group_other motorpump  extraction_type_group_rope pump  \
# 0                              -0.045737                        -0.089242
# 1                              -0.045737                        -0.089242
# 2                              -0.045737                        -0.089242
# 3                              -0.045737                        -0.089242
# 4                              -0.045737                        -0.089242
#
#    extraction_type_group_submersible  extraction_type_group_swn 80  \
# 0                           2.921563                     -0.256991
# 1                          -0.342283                     -0.256991
# 2                          -0.342283                     -0.256991
# 3                          -0.342283                     -0.256991
# 4                          -0.342283                     -0.256991
#
#    extraction_type_group_wind-powered  management_other  \
# 0                           -0.042679         -0.120441
# 1                           -0.042679         -0.120441
# 2                           -0.042679         -0.120441
# 3                           -0.042679         -0.120441
# 4                           -0.042679         -0.120441
#
#    management_other - school  management_parastatal  \
# 0                  -0.042148              -0.174194
# 1                  -0.042148              -0.174194
# 2                  -0.042148              -0.174194
# 3                  -0.042148              -0.174194
# 4                  -0.042148              -0.174194
#
#    management_private operator  management_trust  management_unknown  \
# 0                    -0.185307         -0.036724           -0.099185
# 1                    -0.185307         -0.036724           -0.099185
# 2                    -0.185307         -0.036724           -0.099185
# 3                    -0.185307         -0.036724           -0.099185
# 4                    -0.185307         -0.036724           -0.099185
#
#    management_vwc  management_water authority  management_water board  \
# 0        0.681752                   -0.123941                -0.22661
# 1       -1.466809                   -0.123941                -0.22661
# 2        0.681752                   -0.123941                -0.22661
# 3       -1.466809                   -0.123941                -0.22661
# 4        0.681752                   -0.123941                -0.22661
#
#    management_wua  management_wug  management_group_other  \
# 0       -0.211876       -0.351058               -0.127806
# 1       -0.211876        2.848536               -0.127806
# 2       -0.211876       -0.351058               -0.127806
# 3        4.719731       -0.351058               -0.127806
# 4       -0.211876       -0.351058               -0.127806
#
#    management_group_parastatal  management_group_unknown  \
# 0                    -0.174194                 -0.099185
# 1                    -0.174194                 -0.099185
# 2                    -0.174194                 -0.099185
# 3                    -0.174194                 -0.099185
# 4                    -0.174194                 -0.099185
#
#    management_group_user-group  payment_other  payment_pay annually  \
# 0                     0.361857      -0.134188             -0.254501
# 1                     0.361857      -0.134188             -0.254501
# 2                     0.361857      -0.134188             -0.254501
# 3                     0.361857      -0.134188             -0.254501
# 4                     0.361857      -0.134188             -0.254501
#
#    payment_pay monthly  payment_pay per bucket  payment_pay when scheme fails  \
# 0            -0.399969                2.360664                      -0.266779
# 1            -0.399969               -0.423610                      -0.266779
# 2            -0.399969               -0.423610                      -0.266779
# 3            -0.399969               -0.423610                      -0.266779
# 4            -0.399969               -0.423610                      -0.266779
#
#    payment_unknown  payment_type_monthly  payment_type_never pay  \
# 0        -0.398608             -0.399969               -0.864801
# 1         2.508727             -0.399969               -0.864801
# 2        -0.398608             -0.399969                1.156335
# 3        -0.398608             -0.399969                1.156335
# 4         2.508727             -0.399969               -0.864801
#
#    payment_type_on failure  payment_type_other  payment_type_per bucket  \
# 0                -0.266779           -0.134188                 2.360664
# 1                -0.266779           -0.134188                -0.423610
# 2                -0.266779           -0.134188                -0.423610
# 3                -0.266779           -0.134188                -0.423610
# 4                -0.266779           -0.134188                -0.423610
#
#    payment_type_unknown  quality_group_fluoride  quality_group_good  \
# 0             -0.398608               -0.062256           -2.422528
# 1              2.508727               -0.062256            0.412792
# 2             -0.398608               -0.062256            0.412792
# 3             -0.398608               -0.062256            0.412792
# 4              2.508727               -0.062256            0.412792
#
#    quality_group_milky  quality_group_salty  quality_group_unknown  \
# 0              -0.1188             3.218090              -0.179992
# 1              -0.1188            -0.310743              -0.179992
# 2              -0.1188            -0.310743              -0.179992
# 3              -0.1188            -0.310743              -0.179992
# 4              -0.1188            -0.310743              -0.179992
#
#    quantity_enough  quantity_insufficient  quantity_seasonal  \
# 0        -1.124921               1.711914          -0.269376
# 1         0.888952              -0.584141          -0.269376
# 2         0.888952              -0.584141          -0.269376
# 3        -1.124921              -0.584141           3.712280
# 4        -1.124921              -0.584141          -0.269376
#
#    quantity_unknown  source_hand dtw  source_lake  source_machine dbh  \
# 0          -0.11595        -0.122628    -0.113743            2.085065
# 1          -0.11595        -0.122628    -0.113743           -0.479601
# 2          -0.11595        -0.122628    -0.113743            2.085065
# 3          -0.11595        -0.122628    -0.113743           -0.479601
# 4          -0.11595        -0.122628    -0.113743           -0.479601
#
#    source_other  source_rainwater harvesting  source_river  \
# 0     -0.062437                    -0.199242     -0.439821
# 1     -0.062437                    -0.199242     -0.439821
# 2     -0.062437                    -0.199242     -0.439821
# 3     -0.062437                     5.019011     -0.439821
# 4     -0.062437                    -0.199242     -0.439821
#
#    source_shallow well  source_spring  source_unknown  \
# 0            -0.630801      -0.630975       -0.034185
# 1             1.585285      -0.630975       -0.034185
# 2            -0.630801      -0.630975       -0.034185
# 3            -0.630801      -0.630975       -0.034185
# 4            -0.630801       1.584849       -0.034185
#
#    waterpoint_type_communal standpipe  \
# 0                            1.042285
# 1                           -0.959431
# 2                           -0.959431
# 3                            1.042285
# 4                            1.042285
#
#    waterpoint_type_communal standpipe multiple  waterpoint_type_dam  \
# 0                                    -0.336484            -0.008206
# 1                                    -0.336484            -0.008206
# 2                                    -0.336484            -0.008206
# 3                                    -0.336484            -0.008206
# 4                                    -0.336484            -0.008206
#
#    waterpoint_type_hand pump  waterpoint_type_improved spring  \
# 0                  -0.648606                        -0.116644
# 1                   1.541767                        -0.116644
# 2                   1.541767                        -0.116644
# 3                  -0.648606                        -0.116644
# 4                  -0.648606                        -0.116644
#
#    waterpoint_type_other  public_meeting_True  permit_True  \
# 0              -0.346889             0.408462     0.729442
# 1              -0.346889            -2.448208    -1.370910
# 2              -0.346889             0.408462     0.729442
# 3              -0.346889             0.408462     0.729442
# 4              -0.346889            -2.448208     0.729442
#
#    no_construct_yr_True
# 0             -0.729117
# 1              1.371521
# 2              1.371521
# 3             -0.729117
# 4             -0.729117

# %%
y_train_resampled.head()
# Out:
# 0    1
# 1    0
# 2    0
# 3    0
# 4    1
# Name: target, dtype: int64

# %%
from sklearn.linear_model import LogisticRegression

from sklearn import metrics
from sklearn.metrics import roc_curve
from sklearn.metrics import roc_auc_score,auc
#from sklearn.metrics import recall_score
#from sklearn.metrics import f1_score
from sklearn.metrics import accuracy_score, recall_score,f1_score, confusion_matrix,classification_report
from sklearn.metrics import precision_score

from yellowbrick.classifier import ROCAUC

from sklearn.model_selection import cross_val_score

# %%
y_train.dtype
# Out:
# dtype('int64')

# %% [markdown]
# ### Create Model
# recall-How good is our model at finding wells that don't work. Of postive class, what percentage did we find.

# %%
y_test.value_counts()
# Out:
# 0    8098
# 1    5678
# 2    1074
# Name: target, dtype: int64

# %%
y_train_resampled.value_counts()
# Out:
# 2    24161
# 1    24161
# 0    24161
# Name: target, dtype: int64

# %%
y_test.value_counts(normalize=True)
# Out:
# 0    0.545320
# 1    0.382357
# 2    0.072323
# Name: target, dtype: float64

# %% [markdown]
# #### Baseline Model

# %%
from sklearn.dummy import DummyClassifier

dummy_clf = DummyClassifier(strategy="most_frequent")
dummy_clf.fit(X, y)

dummy_clf.score(train_scale, y_train)
# Out:
# 0.542334455667789

# %%
import tzlocal
import datetime as dt#to get current time
tz = tzlocal.get_localzone()
print(tz)
start = dt.datetime.now(tz)
print(start.strftime("%m/%d/%y - %I:%m %p"))
# Out:
# America/New_York
# 10/03/20 - 10:10 AM

# %%
class Timer() :

    def __init__(self, format_="%m/%d/%y - %I:%m %p"): #when we intialize class its going to perform these actions
        import tzlocal
        import datetime as dt#to get current time
        self.tz = tzlocal.get_localzone() #save and can call out whenever we want
        self.fmt = format_
        
        self.created_at =self.get_time()
        
    def get_time(self): 
        import datetime as dt
        return dt.datetime.now(self.tz)
    
    def start(self): #need to get the time
        time = self.get_time()
        self.start= time
        print(f"[i]Timer started at {self.start.strftime(self.fmt)}")
        
    def stop(self):
        time = self.get_time()
        self.end = time
        print(f"[i]Timer ended at {self.end.strftime(self.fmt)}")
        print(f"- Total Time= {self.end - self.start}")

# %%
def eval_classification_model(class_model, X_train,X_test, y_train, y_test,
                              normalize='true',cmap='Blues',figsize=[10,5]):
    """
    Algorithm for classification model
    Args
    df (df)
    X_train (int)
    X_test ()
    y_train ()
    y_test ()
    figsize (dict)
    """
    #Classification Model
    
    timer = Timer()
    timer.start()
    print('\n')
    class_model.fit(X_train, y_train)
    
    
    # get Predictions
    y_hat_train = class_model.predict(X_train)
    y_hat_test =  class_model.predict(X_test)
    #evaluate model
    print("Training Accuracy on  Model: {}".format(accuracy_score(y_train, y_hat_train)))
    print("Testing Accuracy on  Model: {}".format(accuracy_score(y_test, y_hat_test)))
    # recall_score(y, lr.predict(X), average=None)
    print('Recall: {}'.format(recall_score(y_test, y_hat_test, average=None))) #average='micro'
    print('Recall: {}'.format(recall_score(y_test, y_hat_test, average=None)[1]))
    scores = cross_val_score(class_model,X_test, y_test,cv=5)
    print('Cross-validation scores on testing set: {}'.format(scores))
    print('Average cross-validation score on testing set: {:.2f}'.format(scores.mean()))
    
    #print("Precision Score on  Model: {}".format(precision_score(y_test, y_hat_test, average=None)))
    #print('Precision: {}'.format(recall_score(y_test, y_hat_test,average='None')))
    print(dashes)
    print('\n')
    #adaboost_confusion_matrix = confusion_matrix(y_test, adaboost_test_preds)
    ada_cf_matrix = confusion_matrix(y_hat_test,y_test)  #axes[0]
    print(ada_cf_matrix)
    print('\n')
    
    # Classification Report / Accuracy Score 
    print(dashes)
    print("Classification Report")
    print(dashes)
    classes = ['0/Functional','1/Non-functioning','2/Needs Repair']
    print(metrics.classification_report(y_test,y_hat_test,target_names=classes))  
    print(dashes)
    print('\n')

    fig, axes = plt.subplots(ncols=2,figsize= figsize)   #ncols=2,
    #Confusion Matrix
    metrics.plot_confusion_matrix(class_model,X_test,y_test,normalize=normalize,
                                  cmap=cmap, ax=axes[0])  #axes[0]
    
#     metrics.plot_confusion_matrix(class_model,X_test,y_test,normalize=None,
#                                   cmap=cmap, ax=axes[1])  #axes[0]

# p1, = plt.plot([1, 2, 3], label='Line 1')
# p2, = plt.plot([3, 2, 1], label='Line 2')
# plt.legend(handles=[p1, p2], title='title', bbox_to_anchor=(1.05, 1), loc='upper left', prop=fontP)
    visualizer = ROCAUC(class_model, classes=["functioning", "non-functioning",'functioning needs repair'],ax=axes[1])
 #   plt.legend(handles=[visualizer], title='title', bbox_to_anchor=(1.05, 1), loc='upper left')
 #   plt.legend((bbox_to_anchor=(0.4,0.8), loc="upper right")
    """
    visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
    visualizer.score(X_test, y_test)        # Evaluate the model on the test data
    """
    visualizer.fit(X_train, y_train)        # Fit the training data to the visualizer
    visualizer.score(X_test, y_test)        # Evaluate the model on the test data
    #plt.legend(visualizer,loc='center left', bbox_to_anchor=(1, 0.5))
    visualizer.show() 
    
    timer.stop()
    return class_model

# %% [markdown]
# #### Logistic Regression

# %%
model = eval_classification_model(LogisticRegression(), train_resampled, test_scale, 
                 y_train_resampled,y_test)
# Out:
# [i]Timer started at 10/03/20 - 10:10 AM
#
#
# Training Accuracy on  Model: 0.6396120469627361
# Testing Accuracy on  Model: 0.6259259259259259
# Recall: [0.62645098 0.62046495 0.65083799]
# Recall: 0.6204649524480451
# Cross-validation scores on testing set: [0.73030303 0.72895623 0.71919192 0.72323232 0.71986532]
# Average cross-validation score on testing set: 0.72
# ------------------------------------------------------------
#
#
# [[5073 1187  246]
#  [ 930 3523  129]
#  [2095  968  699]]
#
#
# ------------------------------------------------------------
# Classification Report
# ------------------------------------------------------------
#                    precision    recall  f1-score   support
#
#      0/Functional       0.78      0.63      0.69      8098
# 1/Non-functioning       0.77      0.62      0.69      5678
#    2/Needs Repair       0.19      0.65      0.29      1074
#
#          accuracy                           0.63     14850
#         macro avg       0.58      0.63      0.56     14850
#      weighted avg       0.73      0.63      0.66     14850
#
# ------------------------------------------------------------
# [i]Timer ended at 10/03/20 - 10:10 AM
# - Total Time= 0:00:06.986154

# %%
# train_resampled, y_train_resampled
# functional':0,'non functional':1,'functional needs repair':2})
#, classes={0:'functional',1:'non functional',2:'functional needs repair'}

model = eval_classification_model(LogisticRegression(fit_intercept=False, C=1e12, solver='liblinear'), train_resampled, test_scale, 
                 y_train_resampled,y_test)
# Out:
# [i]Timer started at 10/03/20 - 09:10 AM
#
#
# Training Accuracy on  Model: 0.6358318502269498
# Testing Accuracy on  Model: 0.5820875420875421
# Recall: [0.58977525 0.54473406 0.72160149]
# Recall: 0.5447340612891863
# Cross-validation scores on testing set: [0.69090909 0.6976431  0.68215488 0.6989899  0.67710438]
# Average cross-validation score on testing set: 0.69
# ------------------------------------------------------------
#
#
# [[4776 1157  212]
#  [ 501 3093   87]
#  [2821 1428  775]]
#
#
# ------------------------------------------------------------
# Classification Report
# ------------------------------------------------------------
#                    precision    recall  f1-score   support
#
#      0/Functional       0.78      0.59      0.67      8098
# 1/Non-functioning       0.84      0.54      0.66      5678
#    2/Needs Repair       0.15      0.72      0.25      1074
#
#          accuracy                           0.58     14850
#         macro avg       0.59      0.62      0.53     14850
#      weighted avg       0.76      0.58      0.64     14850
#
# ------------------------------------------------------------
# [i]Timer ended at 10/03/20 - 09:10 AM
# - Total Time= 0:03:04.726545

# %% [markdown]
# #### GridsearchCV

# %%
from sklearn.model_selection import GridSearchCV
#f1 score-averaging
model = LogisticRegression()
params = {'C':[1e12, 0.001, 0.01, 0.1, 1,10, 100], 'fit_intercept':[True,False]}
gridsearch = GridSearchCV(model,params, scoring='recall_macro')

# %%
# train_resampled, y_train_resampled
gridsearch.fit(train_resampled, y_train_resampled)
# Out:
# GridSearchCV(estimator=LogisticRegression(),
#              param_grid={'C': [1000000000000.0, 0.001, 0.01, 0.1, 1, 10, 100],
#                          'fit_intercept': [True, False]},
#              scoring='recall_macro')

# %%
#of all params it tried thi gave it hte highest score
best_params = gridsearch.best_params_
best_params
# Out:
# {'C': 100, 'fit_intercept': False}

# %%
#this is hte actual model it trained
best_model = gridsearch.best_estimator_
best_model
# Out:
# LogisticRegression(C=100, fit_intercept=False)

# %%
# accuracy      0.63     14850
model = eval_classification_model(best_model,train_resampled, test_scale,y_train_resampled, y_test) #,classes=['Died','Survived']
# Out:
# [i]Timer started at 10/02/20 - 12:10 AM
#
#
# Training Accuracy on  Model: 0.6408123284080405
# Testing Accuracy on  Model: 0.6146801346801347
# Recall: [0.61583107 0.59985911 0.68435754]
# Recall: 0.5998591053187742
# Cross-validation scores on testing set: [0.73030303 0.72087542 0.72087542 0.72996633 0.71346801]
# Average cross-validation score on testing set: 0.72
# ------------------------------------------------------------
#
#
# [[4987 1181  226]
#  [ 776 3406  113]
#  [2335 1091  735]]
#
#
# ------------------------------------------------------------
# Classification Report
# ------------------------------------------------------------
#                    precision    recall  f1-score   support
#
#      0/Functional       0.78      0.62      0.69      8098
# 1/Non-functioning       0.79      0.60      0.68      5678
#    2/Needs Repair       0.18      0.68      0.28      1074
#
#          accuracy                           0.61     14850
#         macro avg       0.58      0.63      0.55     14850
#      weighted avg       0.74      0.61      0.66     14850
#
# ------------------------------------------------------------
# [i]Timer ended at 10/02/20 - 12:10 AM
# - Total Time= 0:00:06.520150

# %% [markdown]
# #### K Nearest Neighbors Classifier

# %%
from sklearn.neighbors import KNeighborsClassifier

# %%
#train_resampled, test_scale,y_train_resampled, y_test
model = eval_classification_model(KNeighborsClassifier(), 
                                                    train_resampled, test_scale, y_train_resampled,y_test)
# Out:
# [i]Timer started at 10/02/20 - 12:10 AM
#
#
# Training Accuracy on  Model: 0.8653753293875805
# Testing Accuracy on  Model: 0.7220875420875421
# Recall: [0.73610768 0.73793589 0.53258845]
# Recall: 0.7379358929200422
# Cross-validation scores on testing set: [0.71515152 0.72188552 0.71952862 0.71144781 0.71144781]
# Average cross-validation score on testing set: 0.72
# ------------------------------------------------------------
#
#
# [[5961 1073  340]
#  [1191 4190  162]
#  [ 946  415  572]]
#
#
# ------------------------------------------------------------
# Classification Report
# ------------------------------------------------------------
#                    precision    recall  f1-score   support
#
#      0/Functional       0.81      0.74      0.77      8098
# 1/Non-functioning       0.76      0.74      0.75      5678
#    2/Needs Repair       0.30      0.53      0.38      1074
#
#          accuracy                           0.72     14850
#         macro avg       0.62      0.67      0.63     14850
#      weighted avg       0.75      0.72      0.73     14850
#
# ------------------------------------------------------------
# [i]Timer ended at 10/02/20 - 08:10 AM
# - Total Time= 7:22:40.408236

# %% [markdown]
# #### KNN / Gridsearch

# %%
model = KNeighborsClassifier()
params = {'n_neighbors':range(1, 26, 2)} #1,26,2

gridsearch = GridSearchCV(model,params, scoring='recall_macro',cv=3) #f1_macro
gridsearch.fit(train_resampled, y_train_resampled)
# Out:
# GridSearchCV(cv=3, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': range(1, 26, 2)},
#              scoring='recall_macro')

# %%
best_params_k6 = gridsearch.best_params_
best_params_k6
# Out:
# {'n_neighbors': 1}

# %%
best_model_k6 = gridsearch.best_estimator_
best_model_k6
# Out:
# KNeighborsClassifier(n_neighbors=1)

# %%
knn_model = eval_classification_model(best_model_k6,train_resampled, test_scale,y_train_resampled, y_test) #,classes=['Died','Survived']
# Out:
# [i]Timer started at 10/02/20 - 10:10 AM
#
#
# Training Accuracy on  Model: 0.9927017369590111
# Testing Accuracy on  Model: 0.7326599326599327
# Recall: [0.76204001 0.74392392 0.45158287]
# Recall: 0.7439239168721381
# Cross-validation scores on testing set: [0.69494949 0.70606061 0.6986532  0.70673401 0.7037037 ]
# Average cross-validation score on testing set: 0.70
# ------------------------------------------------------------
#
#
# [[6171 1165  413]
#  [1247 4224  176]
#  [ 680  289  485]]
#
#
# ------------------------------------------------------------
# Classification Report
# ------------------------------------------------------------
#                    precision    recall  f1-score   support
#
#      0/Functional       0.80      0.76      0.78      8098
# 1/Non-functioning       0.75      0.74      0.75      5678
#    2/Needs Repair       0.33      0.45      0.38      1074
#
#          accuracy                           0.73     14850
#         macro avg       0.63      0.65      0.64     14850
#      weighted avg       0.74      0.73      0.74     14850
#
# ------------------------------------------------------------
# [i]Timer ended at 10/02/20 - 10:10 AM
# - Total Time= 0:39:19.082132

# %% [markdown]
# #### Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
"""
(n_estimators=100, random_state=42, n_jobs=-1,
                            criterion= 'entropy',max_features= 'sqrt',
                             min_samples_split= 10,class_weight='balanced'

"""
rforest = eval_classification_model(RandomForestClassifier(n_estimators=100, random_state=42, n_jobs=-1), 
                                            train_resampled, test_scale, y_train_resampled,y_test)
# Out:
# [i]Timer started at 10/02/20 - 10:10 AM
#
#
# Training Accuracy on  Model: 0.9955989680338838
# Testing Accuracy on  Model: 0.7776430976430977
# Recall: [0.81526303 0.78090877 0.47672253]
# Recall: 0.7809087706939063
# Cross-validation scores on testing set: [0.76026936 0.76228956 0.76026936 0.76936027 0.75589226]
# Average cross-validation score on testing set: 0.76
# ------------------------------------------------------------
#
#
# [[6602 1033  409]
#  [ 915 4434  153]
#  [ 581  211  512]]
#
#
# ------------------------------------------------------------
# Classification Report
# ------------------------------------------------------------
#                    precision    recall  f1-score   support
#
#      0/Functional       0.82      0.82      0.82      8098
# 1/Non-functioning       0.81      0.78      0.79      5678
#    2/Needs Repair       0.39      0.48      0.43      1074
#
#          accuracy                           0.78     14850
#         macro avg       0.67      0.69      0.68     14850
#      weighted avg       0.78      0.78      0.78     14850
#
# ------------------------------------------------------------
# [i]Timer ended at 10/02/20 - 10:10 AM
# - Total Time= 0:00:33.334585

# %%
rforest
# Out:
# RandomForestClassifier(n_jobs=-1, random_state=42)

# %%
df_import = pd.Series(rforest.feature_importances_,index=train_resampled.columns, name='Importance')
df_import.sort_values()
# Out:
# waterpoint_type_dam                      0.000011
# management_other - school                0.000086
# source_unknown                           0.000172
# extraction_type_group_other motorpump    0.000245
# extraction_type_group_india mark iii     0.000273
#                                            ...
# quantity_enough                          0.043615
# population                               0.055320
# construction_year                        0.063326
# latitude                                 0.151597
# longitude                                0.161450
# Name: Importance, Length: 101, dtype: float64

# %%
def plot_importance(forest, top_n=10, figsize=(10,10)):
    df_importance = pd.Series(forest.feature_importances_,index=train_resampled.columns)
    df_importance.sort_values(ascending=True).tail(top_n).plot(kind='barh', figsize=figsize)
    
    return df_importance

# %%
plot_importance(rforest)
# Out:
# amount_tsh                         0.024157
# longitude                          0.161450
# latitude                           0.151597
# num_private                        0.001999
# district_code                      0.042647
#                                      ...
# waterpoint_type_improved spring    0.002354
# waterpoint_type_other              0.019835
# public_meeting_True                0.011318
# permit_True                        0.017256
# no_construct_yr_True               0.005710
# Length: 101, dtype: float64

# %%
def ensemble_features(forest, top_n=10, figsize=(10,10)):
    df_importance = pd.Series(forest.feature_importances_,index=train_resampled.columns)
    df_importance.sort_values(ascending=True).tail(top_n).plot(kind='barh', figsize=figsize)
    
    return df_importance

# %%
#top 10 imporant features as determined by our model
#what were most important things in determing the output
forest_1 = ensemble_features(rforest)

# %%
"""
model = LogisticRegression()
params = {'C':[0.001, 0.01, 0.1, 1,10, 100]}
gridsearch = GridSearchCV(model,params, scoring='f1_macro')

gridsearch.fit(train_resampled, y_train_resampled)
----------------
timer = Timer()
#     #print(timer.created_at)
    timer.start()
    
    grid_clf.fit(X_train, y_train)
    #timer.stop()
    timer.stop()
    
    #grid_clf.best_params_
    
    return grid_clf.best_params_
"""
param_grid = {"criterion":["gini",'entropy'],
                 'max_depth':[None,3],#[None,5,3,8,10]
                 'max_features':['auto','sqrt',3,5]}#list of options

forest_2 = RandomForestClassifier()
grid_clf = GridSearchCV(forest_2, param_grid)

timer = Timer()
timer.start()

grid_clf.fit(train_resampled, y_train_resampled)

timer.stop()
# Out:
# [i]Timer started at 10/02/20 - 10:10 AM
# [i]Timer ended at 10/02/20 - 10:10 AM
# - Total Time= 0:11:18.105249

# %%
grid_clf.best_params_
# Out:
# {'criterion': 'gini', 'max_depth': None, 'max_features': 'sqrt'}

# %%
"""
(n_estimators=200,min_samples_leaf=3 ,n_jobs=-1,max_features=0.25

"""
rforest = eval_classification_model(RandomForestClassifier(n_estimators=200,min_samples_leaf=3 ,n_jobs=-1,max_features=0.25), 
                                            train_resampled, test_scale, y_train_resampled,y_test)
# Out:
# [i]Timer started at 10/02/20 - 10:10 AM
#
#
# Training Accuracy on  Model: 0.9277899645434102
# Testing Accuracy on  Model: 0.7793939393939394
# Recall: [0.8126698  0.77773864 0.53724395]
# Recall: 0.7777386403663261
# Cross-validation scores on testing set: [0.78047138 0.77777778 0.77239057 0.78653199 0.76868687]
# Average cross-validation score on testing set: 0.78
# ------------------------------------------------------------
#
#
# [[6581  995  364]
#  [ 803 4416  133]
#  [ 714  267  577]]
#
#
# ------------------------------------------------------------
# Classification Report
# ------------------------------------------------------------
#                    precision    recall  f1-score   support
#
#      0/Functional       0.83      0.81      0.82      8098
# 1/Non-functioning       0.83      0.78      0.80      5678
#    2/Needs Repair       0.37      0.54      0.44      1074
#
#          accuracy                           0.78     14850
#         macro avg       0.67      0.71      0.69     14850
#      weighted avg       0.79      0.78      0.79     14850
#
# ------------------------------------------------------------
# [i]Timer ended at 10/02/20 - 10:10 AM
# - Total Time= 0:00:56.053957

# %% [markdown]
# #### Adaboost and Gradient Boosting classifiers

# %%
from sklearn.ensemble import AdaBoostClassifier, GradientBoostingClassifier

# %%
adaboost = eval_classification_model(AdaBoostClassifier(random_state=42), 
                                            train_resampled, test_scale, y_train_resampled,y_test)
# Out:
# [i]Timer started at 10/02/20 - 10:10 AM
#
#
# Training Accuracy on  Model: 0.6453651200971262
# Testing Accuracy on  Model: 0.6247138047138047
# Recall: [0.63657693 0.61782318 0.5716946 ]
# Recall: 0.6178231771750616
# Cross-validation scores on testing set: [0.71919192 0.71178451 0.71010101 0.72188552 0.71043771]
# Average cross-validation score on testing set: 0.71
# ------------------------------------------------------------
#
#
# [[5155 1196  300]
#  [1133 3508  160]
#  [1810  974  614]]
#
#
# ------------------------------------------------------------
# Classification Report
# ------------------------------------------------------------
#                    precision    recall  f1-score   support
#
#      0/Functional       0.78      0.64      0.70      8098
# 1/Non-functioning       0.73      0.62      0.67      5678
#    2/Needs Repair       0.18      0.57      0.27      1074
#
#          accuracy                           0.62     14850
#         macro avg       0.56      0.61      0.55     14850
#      weighted avg       0.72      0.62      0.66     14850
#
# ------------------------------------------------------------
# [i]Timer ended at 10/02/20 - 10:10 AM
# - Total Time= 0:00:16.808162

# %%
#gbt_clf = GradientBoostingClassifier(random_state=42)
gbt_clf = eval_classification_model(GradientBoostingClassifier(random_state=42), 
                                            train_resampled, test_scale, y_train_resampled,y_test)
# Out:
# [i]Timer started at 10/02/20 - 10:10 AM
#
#
# Training Accuracy on  Model: 0.7262530524398825
# Testing Accuracy on  Model: 0.6756902356902357
# Recall: [0.70782909 0.64635435 0.58845438]
# Recall: 0.6463543501232828
# Cross-validation scores on testing set: [0.75387205 0.75420875 0.74006734 0.74882155 0.73703704]
# Average cross-validation score on testing set: 0.75
# ------------------------------------------------------------
#
#
# [[5732 1339  298]
#  [ 789 3670  144]
#  [1577  669  632]]
#
#
# ------------------------------------------------------------
# Classification Report
# ------------------------------------------------------------
#                    precision    recall  f1-score   support
#
#      0/Functional       0.78      0.71      0.74      8098
# 1/Non-functioning       0.80      0.65      0.71      5678
#    2/Needs Repair       0.22      0.59      0.32      1074
#
#          accuracy                           0.68     14850
#         macro avg       0.60      0.65      0.59     14850
#      weighted avg       0.74      0.68      0.70     14850
#
# ------------------------------------------------------------
# [i]Timer ended at 10/02/20 - 10:10 AM
# - Total Time= 0:03:56.487008

# %% [markdown]
# #### XGBoost

# %%
import xgboost as xgb

# %%
#xgb.XGBClassifier()
xgb_clf = eval_classification_model(xgb.XGBClassifier(), 
                                            train_resampled, test_scale, y_train_resampled,y_test)
# Out:
# [i]Timer started at 10/02/20 - 10:10 AM
#
#
# Training Accuracy on  Model: 0.8560352082557289
# Testing Accuracy on  Model: 0.7587878787878788
# Recall: [0.79278834 0.74392392 0.58100559]
# Recall: 0.7439239168721381
# Cross-validation scores on testing set: [0.78282828 0.76868687 0.77205387 0.77306397 0.76397306]
# Average cross-validation score on testing set: 0.77
# ------------------------------------------------------------
#
#
# [[6420 1101  328]
#  [ 765 4224  122]
#  [ 913  353  624]]
#
#
# ------------------------------------------------------------
# Classification Report
# ------------------------------------------------------------
#                    precision    recall  f1-score   support
#
#      0/Functional       0.82      0.79      0.81      8098
# 1/Non-functioning       0.83      0.74      0.78      5678
#    2/Needs Repair       0.33      0.58      0.42      1074
#
#          accuracy                           0.76     14850
#         macro avg       0.66      0.71      0.67     14850
#      weighted avg       0.79      0.76      0.77     14850
#
# ------------------------------------------------------------
# [i]Timer ended at 10/02/20 - 11:10 AM
# - Total Time= 0:02:47.807771

# %% [markdown]
# #### Geospatial Visualization

# %%
"""
df_1[df_1['longitude']>0] [df_1['latitude']<0][df_1['construction_year']>0].plot\
(kind='scatter', x="longitude", y="latitude", alpha=0.4,
s=df_1["population"]/10, label="population", figsize=(14,10),

c="construction_year", cmap=plt.get_cmap("jet"), colorbar=True,
sharex=False);
plt.title("Population Size, Construction Years, & Locations of Waterpumps in Tanzania", 
         fontsize =16, fontweight='bold')
plt.legend;
"""
# df_1[df_1['longitude']>0] [df_1['latitude']<0].plot\
# (kind='scatter', x="longitude", y="latitude", alpha=0.4,
# s=df_1["population"]/10, label="population", figsize=(14,10),

# c= cmap=plt.get_cmap("jet"), colorbar=True,
# sharex=False);
# plt.title("Population Size, Construction Years, & Locations of Waterpumps in Tanzania", 
#          fontsize =16, fontweight='bold')
# plt.legend;
# Out:
# '\ndf_1[df_1[\'longitude\']>0] [df_1[\'latitude\']<0][df_1[\'construction_year\']>0].plot(kind=\'scatter\', x="longitude", y="latitude", alpha=0.4,\ns=df_1["population"]/10, label="population", figsize=(14,10),\n\nc="construction_year", cmap=plt.get_cmap("jet"), colorbar=True,\nsharex=False);\nplt.title("Population Size, Construction Years, & Locations of Waterpumps in Tanzania", \n         fontsize =16, fontweight=\'bold\')\nplt.legend;\n'

# %%
def get_center_latlong(df_1):
    # get the center of my map for plotting
    centerlat = (df_1['latitude'].max() + df_1['latitude'].min()) / 2
    centerlong = (df_1['longitude'].max() + df_1['longitude'].min()) / 2
    return centerlat, centerlong

# %%
# import geopandas

# gdf = geopandas.GeoDataFrame(
#         df, geometry=geopandas.points_from_xy(df_1.longitude, df_1.latitude))

# functional = gdf.where(gdf['target'] == 'functional')
# repair = gdf.where(gdf['target'] == 'functional needs repair')
# broken = gdf.where(gdf['target'] == 'non functional')

# world = geopandas.read_file(geopandas.datasets.get_path('naturalearth_lowres'))

# # We restrict to Africa
# ax = world[world.continent == 'Africa'].plot(
#     color='white', edgecolor='gray')

# ax.scatter(functional['longitude'], functional['latitude'],
#            c='green',alpha=.5, s=1)

# ax.scatter(repair['longitude'], repair['latitude'],
#            c='yellow', alpha=.5, s=1)

# ax.scatter(broken['longitude'], broken['latitude'],
#            c='red', alpha=.5, s=1)

# plt.ylim(-12, 0)
# plt.xlim(28,41)

# plt.show()
import folium

# grab the center of our map using our cool function
center = get_center_latlong(df_1)

# create a new map object
m = folium.Map(location=center, zoom_start=10)

# save our map to an interactive html file
m.save('circle_map.html')

# %%
# Same as before, we get the center and make the map object
center = get_center_latlong(df_1)
m = folium.Map(location=center, zoom_start=10)

# go through each home in set, make circle, and add to map.
for i in range(len(df_1)):
    folium.Circle(
        location=[df_1.iloc[i]['latitude'], df_1.iloc[i]['longitude']],
        radius=10,
    ).add_to(m)

# Same as before, we save it to file
m.save('circle_map.html')

# %%
df_2 = pd.read_csv('data/water_table.csv')
labels = pd.read_csv('data/water_table_labels.csv')
df_2['target'] = labels['status_group']

# %%
df_2.columns[df_2.isin(['0']).any()]
# Out:
# Index(['funder', 'installer'], dtype='object')
